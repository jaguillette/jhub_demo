# %% [markdown]
# # Working with APIs in Python
#
# Making API requests in Python can be really simple. There's a low-level module called `urllib` that can also make the kinds of web requests that we want, but it's not as friendly as the `requests` module, which we'll be using.

# %%
import requests

# %% [markdown]
# ## Authentication
#
# You'll have to authenticate each request to the Harvard Art Museum API with an API key. Other APIs may require different kinds of authentication (sometimes very complicated auth! Look for libraries at that point), but HAM has some pretty simple authentication, which makes things easy for us.
#
# You can sign up for a key [here](https://www.harvardartmuseums.org/collections/api). Documentation for the entire API is hosted on GitHub and can be viewed [here](https://github.com/harvardartmuseums/api-docs).

# %%
APIKEY = "622b6240-e14a-11e8-9234-6f5a1db33697" # Enter your API key here

# %% [markdown]
# ## Basic request
#
# We're going to start off with a basic request to the API. This API, like many others, has a variety of endpoints, each with their own url, slightly modified from a base url. We'll worry about the general case in a bit, for now let's look at a basic API request.
#
# In this example, we'll re-create the first example in the [Object endpoint documentation](https://github.com/harvardartmuseums/api-docs/blob/master/sections/object.md), which will give each of you the records for 10 objects that have never been viewed online in the museum's collections.

# %%
url = "https://api.harvardartmuseums.org/object"
parameters = {
    "q":"verificationlevel:4",
    "size":10,
    "apikey":APIKEY,
    "sort":'totalpageviews'
}
R = requests.get(url,params=parameters)
R.json()
# Out:
# {'info': {'next': 'https://api.harvardartmuseums.org/object?q=verificationlevel%3A4&size=10&apikey=622b6240-e14a-11e8-9234-6f5a1db33697&sort=totalpageviews&page=2',
#   'page': 1,
#   'pages': 1582,
#   'totalrecords': 15817,
#   'totalrecordsperquery': 10},
#  'records': [{'accessionmethod': 'Bequest',
#    'accessionyear': 1936,
#    'accesslevel': 1,
#    'century': '19th-20th century',
#    'classification': 'Paintings',
#    'classificationid': 26,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest of Denman W. Ross, Class of 1875',
#    'culture': 'American',
#    'datebegin': 0,
#    'dated': '19th-20th century',
#    'dateend': 0,
#    'dateoffirstpageview': None,
#    'dateoflastpageview': None,
#    'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#    'description': None,
#    'dimensions': '35.2 x 25.4 cm (13 7/8 x 10 in.)\r\nframed: 38.7 x 28.3 x 1.3 cm (15 1/4 x 11 1/8 x 1/2 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 1,
#    'groupcount': 0,
#    'id': 232815,
#    'imagecount': 1,
#    'imagepermissionlevel': 1,
#    'images': [],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:16:14-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Oil on canvasboard',
#    'objectid': 232815,
#    'objectnumber': '1936.150.157',
#    'people': [{'alphasort': 'Ross, Denman Waldo',
#      'birthplace': 'Cincinnati, OH',
#      'culture': 'American',
#      'deathplace': 'London, England',
#      'displaydate': '1853 - 1935',
#      'displayname': 'Denman Waldo Ross',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Denman Waldo Ross',
#      'personid': 28370,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': None,
#    'provenance': 'Bequest of the artist to the Fogg Art Museum, 1936.',
#    'publicationcount': 0,
#    'rank': 60863,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/232815',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Landscape with Church and Figures',
#    'titlescount': 1,
#    'totalpageviews': 0,
#    'totaluniquepageviews': 0,
#    'url': 'https://www.harvardartmuseums.org/collections/object/232815',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]},
#   {'accessionmethod': 'Purchase',
#    'accessionyear': 1994,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Drawings',
#    'classificationid': 21,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Purchase through the generosity of Sarah-Ann and Werner H. Kramarsky',
#    'culture': 'American',
#    'datebegin': 1994,
#    'dated': '1994',
#    'dateend': 1994,
#    'dateoffirstpageview': None,
#    'dateoflastpageview': None,
#    'department': 'Department of Drawings',
#    'description': None,
#    'dimensions': '18.3 x 18.2 cm (7 3/16 x 7 3/16 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 51982,
#    'imagecount': 1,
#    'imagepermissionlevel': 1,
#    'images': [],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:11:40-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Charcoal, oil stick, acrylic, and Liquid Paper on white wove paper',
#    'objectid': 51982,
#    'objectnumber': '1994.47.46',
#    'people': [{'alphasort': 'Sosnowy, Sara',
#      'birthplace': 'Texas City,Texas',
#      'culture': 'American',
#      'deathplace': None,
#      'displaydate': 'born 1957',
#      'displayname': 'Sara Sosnowy',
#      'displayorder': 1,
#      'gender': 'female',
#      'name': 'Sara Sosnowy',
#      'personid': 33971,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': None,
#    'provenance': '[John Weber Gallery, New York, New York], sold; to Harvard University Art Museums, 1994.\r\n',
#    'publicationcount': 0,
#    'rank': 114239,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/51982',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': "verso, graphite: Sosnowy '94",
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Variations on a Theme (No. 144)',
#    'titlescount': 1,
#    'totalpageviews': 0,
#    'totaluniquepageviews': 0,
#    'url': 'https://www.harvardartmuseums.org/collections/object/51982',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'drawing', 'worktypeid': '125'}]},
#   {'accessionmethod': 'Purchase',
#    'accessionyear': 1994,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Drawings',
#    'classificationid': 21,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Purchase through the generosity of Sarah-Ann and Werner H. Kramarsky',
#    'culture': 'American',
#    'datebegin': 1994,
#    'dated': '1994',
#    'dateend': 1994,
#    'dateoffirstpageview': None,
#    'dateoflastpageview': None,
#    'department': 'Department of Drawings',
#    'description': None,
#    'dimensions': '18.4 x 18.2 cm (7 1/4 x 7 3/16 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 54281,
#    'imagecount': 1,
#    'imagepermissionlevel': 1,
#    'images': [],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:11:44-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Charcoal, oil stick, acrylic, and Liquid Paper on white wove paper',
#    'objectid': 54281,
#    'objectnumber': '1994.47.15',
#    'people': [{'alphasort': 'Sosnowy, Sara',
#      'birthplace': 'Texas City,Texas',
#      'culture': 'American',
#      'deathplace': None,
#      'displaydate': 'born 1957',
#      'displayname': 'Sara Sosnowy',
#      'displayorder': 1,
#      'gender': 'female',
#      'name': 'Sara Sosnowy',
#      'personid': 33971,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': None,
#    'provenance': '[John Weber Gallery, New York, New York], sold; to Harvard University Art Museums, 1994.\r\n',
#    'publicationcount': 0,
#    'rank': 114208,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/54281',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': "verso, graphite: Sosnowy '94",
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Variations on a Theme (No. 113)',
#    'titlescount': 2,
#    'totalpageviews': 0,
#    'totaluniquepageviews': 0,
#    'url': 'https://www.harvardartmuseums.org/collections/object/54281',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'drawing', 'worktypeid': '125'}]},
#   {'accessionmethod': 'Purchase',
#    'accessionyear': 1994,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Drawings',
#    'classificationid': 21,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Purchase through the generosity of Sarah-Ann and Werner H. Kramarsky',
#    'culture': 'American',
#    'datebegin': 1994,
#    'dated': '1994',
#    'dateend': 1994,
#    'dateoffirstpageview': None,
#    'dateoflastpageview': None,
#    'department': 'Department of Drawings',
#    'description': None,
#    'dimensions': '18.3 x 18.2 cm (7 3/16 x 7 3/16 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 54479,
#    'imagecount': 1,
#    'imagepermissionlevel': 1,
#    'images': [],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:11:44-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Charcoal, oil stick, acrylic, and Liquid Paper on white wove paper',
#    'objectid': 54479,
#    'objectnumber': '1994.47.39',
#    'people': [{'alphasort': 'Sosnowy, Sara',
#      'birthplace': 'Texas City,Texas',
#      'culture': 'American',
#      'deathplace': None,
#      'displaydate': 'born 1957',
#      'displayname': 'Sara Sosnowy',
#      'displayorder': 1,
#      'gender': 'female',
#      'name': 'Sara Sosnowy',
#      'personid': 33971,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': None,
#    'provenance': '[John Weber Gallery, New York, New York], sold; to Harvard University Art Museums, 1994.\r\n',
#    'publicationcount': 0,
#    'rank': 114232,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/54479',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': "verso, graphite: Sosnowy '94",
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Variations on a Theme (No. 137)',
#    'titlescount': 2,
#    'totalpageviews': 0,
#    'totaluniquepageviews': 0,
#    'url': 'https://www.harvardartmuseums.org/collections/object/54479',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'drawing', 'worktypeid': '125'}]},
#   {'accessionmethod': 'Purchase',
#    'accessionyear': 1994,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Drawings',
#    'classificationid': 21,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Purchase through the generosity of Sarah-Ann and Werner H. Kramarsky',
#    'culture': 'American',
#    'datebegin': 1994,
#    'dated': '1994',
#    'dateend': 1994,
#    'dateoffirstpageview': None,
#    'dateoflastpageview': None,
#    'department': 'Department of Drawings',
#    'description': None,
#    'dimensions': '18 x 17.8 cm (7 1/16 x 7 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 54543,
#    'imagecount': 1,
#    'imagepermissionlevel': 1,
#    'images': [],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:11:44-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Charcoal, oil stick, acrylic, and Liquid Paper on white wove paper',
#    'objectid': 54543,
#    'objectnumber': '1994.47.17',
#    'people': [{'alphasort': 'Sosnowy, Sara',
#      'birthplace': 'Texas City,Texas',
#      'culture': 'American',
#      'deathplace': None,
#      'displaydate': 'born 1957',
#      'displayname': 'Sara Sosnowy',
#      'displayorder': 1,
#      'gender': 'female',
#      'name': 'Sara Sosnowy',
#      'personid': 33971,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': None,
#    'provenance': '[John Weber Gallery, New York, New York], sold; to Harvard University Art Museums, 1994.\r\n',
#    'publicationcount': 0,
#    'rank': 114210,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/54543',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': "verso, graphite: Sosnowy '94",
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Variations on a Theme (No. 115)',
#    'titlescount': 2,
#    'totalpageviews': 0,
#    'totaluniquepageviews': 0,
#    'url': 'https://www.harvardartmuseums.org/collections/object/54543',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'drawing', 'worktypeid': '125'}]},
#   {'accessionmethod': 'Purchase',
#    'accessionyear': 1994,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Drawings',
#    'classificationid': 21,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Purchase through the generosity of Sarah-Ann and Werner H. Kramarsky',
#    'culture': 'American',
#    'datebegin': 1994,
#    'dated': '1994',
#    'dateend': 1994,
#    'dateoffirstpageview': None,
#    'dateoflastpageview': None,
#    'department': 'Department of Drawings',
#    'description': None,
#    'dimensions': '18.2 x 18.3 cm (7 3/16 x 7 3/16 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 54545,
#    'imagecount': 1,
#    'imagepermissionlevel': 1,
#    'images': [],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:11:44-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Charcoal, oil stick, acrylic, and Liquid Paper on white wove paper',
#    'objectid': 54545,
#    'objectnumber': '1994.47.14',
#    'people': [{'alphasort': 'Sosnowy, Sara',
#      'birthplace': 'Texas City,Texas',
#      'culture': 'American',
#      'deathplace': None,
#      'displaydate': 'born 1957',
#      'displayname': 'Sara Sosnowy',
#      'displayorder': 1,
#      'gender': 'female',
#      'name': 'Sara Sosnowy',
#      'personid': 33971,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': None,
#    'provenance': '[John Weber Gallery, New York, New York], sold; to Harvard University Art Museums, 1994.\r\n',
#    'publicationcount': 0,
#    'rank': 114207,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/54545',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': "verso, graphite: Sosnowy '94",
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Variations on a Theme (No. 112)',
#    'titlescount': 2,
#    'totalpageviews': 0,
#    'totaluniquepageviews': 0,
#    'url': 'https://www.harvardartmuseums.org/collections/object/54545',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'drawing', 'worktypeid': '125'}]},
#   {'accessionmethod': 'Purchase',
#    'accessionyear': 1994,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Drawings',
#    'classificationid': 21,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Purchase through the generosity of Sarah-Ann and Werner H. Kramarsky',
#    'culture': 'American',
#    'datebegin': 1994,
#    'dated': '1994',
#    'dateend': 1994,
#    'dateoffirstpageview': None,
#    'dateoflastpageview': None,
#    'department': 'Department of Drawings',
#    'description': None,
#    'dimensions': '18.1 x 17.9 cm (7 1/8 x 7 1/16 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 54547,
#    'imagecount': 1,
#    'imagepermissionlevel': 1,
#    'images': [],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:11:44-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Charcoal, oil stick, acrylic, and Liquid Paper on white wove paper',
#    'objectid': 54547,
#    'objectnumber': '1994.47.9',
#    'people': [{'alphasort': 'Sosnowy, Sara',
#      'birthplace': 'Texas City,Texas',
#      'culture': 'American',
#      'deathplace': None,
#      'displaydate': 'born 1957',
#      'displayname': 'Sara Sosnowy',
#      'displayorder': 1,
#      'gender': 'female',
#      'name': 'Sara Sosnowy',
#      'personid': 33971,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': None,
#    'provenance': '[John Weber Gallery, New York, New York], sold; to Harvard University Art Museums, 1994.\r\n',
#    'publicationcount': 0,
#    'rank': 114202,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/54547',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': "verso, graphite: Sosnowy '94",
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Variations on a Theme (No. 107)',
#    'titlescount': 2,
#    'totalpageviews': 0,
#    'totaluniquepageviews': 0,
#    'url': 'https://www.harvardartmuseums.org/collections/object/54547',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'drawing', 'worktypeid': '125'}]},
#   {'accessionmethod': 'Purchase',
#    'accessionyear': 1994,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Drawings',
#    'classificationid': 21,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Purchase through the generosity of Sarah-Ann and Werner H. Kramarsky',
#    'culture': 'American',
#    'datebegin': 1994,
#    'dated': '1994',
#    'dateend': 1994,
#    'dateoffirstpageview': None,
#    'dateoflastpageview': None,
#    'department': 'Department of Drawings',
#    'description': None,
#    'dimensions': '18.1 x 18.3 cm (7 1/8 x 7 3/16 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 54590,
#    'imagecount': 1,
#    'imagepermissionlevel': 1,
#    'images': [],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:11:44-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Charcoal, oil stick, acrylic, and Liquid Paper on white wove paper',
#    'objectid': 54590,
#    'objectnumber': '1994.47.35',
#    'people': [{'alphasort': 'Sosnowy, Sara',
#      'birthplace': 'Texas City,Texas',
#      'culture': 'American',
#      'deathplace': None,
#      'displaydate': 'born 1957',
#      'displayname': 'Sara Sosnowy',
#      'displayorder': 1,
#      'gender': 'female',
#      'name': 'Sara Sosnowy',
#      'personid': 33971,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': None,
#    'provenance': '[John Weber Gallery, New York, New York], sold; to Harvard University Art Museums, 1994.\r\n',
#    'publicationcount': 0,
#    'rank': 114228,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/54590',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': "verso, graphite: Sosnowy '94",
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Variations on a Theme (No. 133)',
#    'titlescount': 2,
#    'totalpageviews': 0,
#    'totaluniquepageviews': 0,
#    'url': 'https://www.harvardartmuseums.org/collections/object/54590',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'drawing', 'worktypeid': '125'}]},
#   {'accessionmethod': 'Purchase',
#    'accessionyear': 1994,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Drawings',
#    'classificationid': 21,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Purchase through the generosity of Sarah-Ann and Werner H. Kramarsky',
#    'culture': 'American',
#    'datebegin': 1994,
#    'dated': '1994',
#    'dateend': 1994,
#    'dateoffirstpageview': None,
#    'dateoflastpageview': None,
#    'department': 'Department of Drawings',
#    'description': None,
#    'dimensions': '18.2 x 18.2 cm (7 3/16 x 7 3/16 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 54627,
#    'imagecount': 1,
#    'imagepermissionlevel': 1,
#    'images': [],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:11:44-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Charcoal, oil stick, acrylic, and Liquid Paper on white wove paper',
#    'objectid': 54627,
#    'objectnumber': '1994.47.11',
#    'people': [{'alphasort': 'Sosnowy, Sara',
#      'birthplace': 'Texas City,Texas',
#      'culture': 'American',
#      'deathplace': None,
#      'displaydate': 'born 1957',
#      'displayname': 'Sara Sosnowy',
#      'displayorder': 1,
#      'gender': 'female',
#      'name': 'Sara Sosnowy',
#      'personid': 33971,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': None,
#    'provenance': '[John Weber Gallery, New York, New York], sold; to Harvard University Art Museums, 1994.\r\n',
#    'publicationcount': 0,
#    'rank': 114204,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/54627',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': "verso, graphite: Sosnowy '94",
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Variations on a Theme (No. 109)',
#    'titlescount': 2,
#    'totalpageviews': 0,
#    'totaluniquepageviews': 0,
#    'url': 'https://www.harvardartmuseums.org/collections/object/54627',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'drawing', 'worktypeid': '125'}]},
#   {'accessionmethod': 'Bequest',
#    'accessionyear': 1936,
#    'accesslevel': 1,
#    'century': '19th-20th century',
#    'classification': 'Drawings',
#    'classificationid': 21,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest of Denman W. Ross, Class of 1875',
#    'culture': 'American',
#    'datebegin': 0,
#    'dated': '19th-20th century',
#    'dateend': 0,
#    'dateoffirstpageview': None,
#    'dateoflastpageview': None,
#    'department': 'Department of Drawings',
#    'description': None,
#    'dimensions': 'actual: 35.5 x 28 cm (14 x 11 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 306718,
#    'imagecount': 0,
#    'imagepermissionlevel': 1,
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:18:38-0500',
#    'markscount': 1,
#    'mediacount': 0,
#    'medium': 'Watercolor over graphite on modern laid paper',
#    'objectid': 306718,
#    'objectnumber': '1936.71.15',
#    'people': [{'alphasort': 'Ross, Denman Waldo',
#      'birthplace': 'Cincinnati, OH',
#      'culture': 'American',
#      'deathplace': 'London, England',
#      'displaydate': '1853 - 1935',
#      'displayname': 'Denman Waldo Ross',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Denman Waldo Ross',
#      'personid': 28370,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'provenance': 'Bequest of the artist to the Fogg Art Museum, 1936.\r\n',
#    'publicationcount': 0,
#    'rank': 60371,
#    'relatedcount': 0,
#    'signed': "graphite, verso: DWR [per registrars' card]",
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Mexican Street',
#    'titlescount': 1,
#    'totalpageviews': 0,
#    'totaluniquepageviews': 0,
#    'url': 'https://www.harvardartmuseums.org/collections/object/306718',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'drawing', 'worktypeid': '125'}]}]}

# %%
from IPython.core.display import display, HTML

records = R.json()['records']
htmlOutput = "<table><tr><th>Views</th><th>Title</th></tr>"
for record in records:
    htmlOutput += f"<tr><td>{record['totalpageviews']}</td><td><a href=\"{record['url']}\" target='blank'>{record['title']}</a></td></tr>"
htmlOutput += "</table>"
display(HTML(htmlOutput))
# Out:
# <table><tr><th>Views</th><th>Title</th></tr><tr><td>0</td><td><a href="https://www.harvardartmuseums.org/collections/object/232815" target='blank'>Landscape with Church and Figures</a></td></tr><tr><td>0</td><td><a href="https://www.harvardartmuseums.org/collections/object/51982" target='blank'>Variations on a Theme (No. 144)</a></td></tr><tr><td>0</td><td><a href="https://www.harvardartmuseums.org/collections/object/54281" target='blank'>Variations on a Theme (No. 113)</a></td></tr><tr><td>0</td><td><a href="https://www.harvardartmuseums.org/collections/object/54479" target='blank'>Variations on a Theme (No. 137)</a></td></tr><tr><td>0</td><td><a href="https://www.harvardartmuseums.org/collections/object/54543" target='blank'>Variations on a Theme (No. 115)</a></td></tr><tr><td>0</td><td><a href="https://www.harvardartmuseums.org/collections/object/54545" target='blank'>Variations on a Theme (No. 112)</a></td></tr><tr><td>0</td><td><a href="https://www.harvardartmuseums.org/collections/object/54547" target='blank'>Variations on a Theme (No. 107)</a></td></tr><tr><td>0</td><td><a href="https://www.harvardartmuseums.org/collections/object/54590" target='blank'>Variations on a Theme (No. 133)</a></td></tr><tr><td>0</td><td><a href="https://www.harvardartmuseums.org/collections/object/54627" target='blank'>Variations on a Theme (No. 109)</a></td></tr><tr><td>0</td><td><a href="https://www.harvardartmuseums.org/collections/object/306718" target='blank'>Mexican Street</a></td></tr></table>

# %% [markdown]
# ### Refresher on Dictionaries
#
# Python dictionaries are sets of key / value pairs, where a value can be accessed by its key. You're essentially naming a value in a container, so you can easily call it up later. In the example above, `"size"` is a key which returns the value `10`.
#
# Dictionaries have very fast lookups - usually `O(1)` - so you can get a value from its key very quickly, no matter how large the dictionary is. However, they are also unordered, so if you iterate through all of the key / value pairs in the dictionary, there's no guarantee that they'll be in the same order. If you're coming from Java, you may know dictionaries as Maps (HashMaps, etc). In Javascript, the closest equivalent is JSON (Javascript Object Notation). The general abstract data type is also referred to as an associative array.
#
# We're going to be looking up data in dictionaries as well as setting key-value pairs, so here's a quick refresher on the syntax:

# %%
parameters['q']
# Out:
# 'totalpageviews:0'

# %%
x = 'apikey'
parameters[x] # This also works when we've set the key string to another variable
# Out:
# '622b6240-e14a-11e8-9234-6f5a1db33697'

# %%
parameters['q'] = "totalpageviews:1" # You can also set the value of a key like you would a variable

# %% [markdown]
# ## Making a Request
#
# The request syntax is so simple, you might have missed it. Let's query again for objects with only one pageview, and take a closer look.

# %%
R = requests.get(url,params=parameters)

# %% [markdown]
# ### Formatted parameters
#
# That request has created a request object, which contains not only the data that we get from the Harvard Art Museums, but information on the request we sent, like the URL that it used. Notice that requests has turned our query parameter dictionary into a GET request at the end of our URL.
#
# If you've been working with API requests or web scraping before, you might be used to seeing URLs get constructed like this:
#
# ```python
# url = "https://api.harvardartmuseums.org/object?q=" + query + "&apikey=" + apikey
# ```
#
# If you have, I'm sure you'll appreciate how much simpler this is, especially when dealing with more query parameters.

# %%
R.url
# Out:
# 'https://api.harvardartmuseums.org/object?q=totalpageviews%3A1&size=10&apikey=622b6240-e14a-11e8-9234-6f5a1db33697&sort=random%3A8675309'

# %% [markdown]
# ### Taking a look at the results
#
# Request objects have a built-in method, `.json()`, which converts a JSON file received as a response to a request from a string of text that happens to be in this data format into Python native data structures, like lists, dictionaries, numbers and strings. We can use this method to see a dictionary representation of what we've gotten from the API request.

# %%
R.json()
# Out:
# {'info': {'next': 'https://api.harvardartmuseums.org/object?q=totalpageviews%3A1&size=10&apikey=622b6240-e14a-11e8-9234-6f5a1db33697&sort=random%3A8675309&page=2',
#   'page': 1,
#   'pages': 2352,
#   'totalrecords': 23512,
#   'totalrecordsperquery': 10},
#  'records': [{'accessionmethod': 'Gift',
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': '18th century',
#    'classification': 'Prints',
#    'classificationid': 23,
#    'colorcount': 7,
#    'colors': [{'color': '#7d7d64',
#      'css3': '#808080',
#      'hue': 'Yellow',
#      'percent': 0.18415204678363,
#      'spectrum': '#6cbd45'},
#     {'color': '#e1e1c8',
#      'css3': '#dcdcdc',
#      'hue': 'Green',
#      'percent': 0.18391812865497,
#      'spectrum': '#e9715f'},
#     {'color': '#64644b',
#      'css3': '#696969',
#      'hue': 'Green',
#      'percent': 0.17479532163743,
#      'spectrum': '#59ba4a'},
#     {'color': '#96967d',
#      'css3': '#808080',
#      'hue': 'Green',
#      'percent': 0.16625730994152,
#      'spectrum': '#8e5ea7'},
#     {'color': '#afaf96',
#      'css3': '#a9a9a9',
#      'hue': 'Green',
#      'percent': 0.13140350877193,
#      'spectrum': '#8e5ea7'},
#     {'color': '#c8c8af',
#      'css3': '#c0c0c0',
#      'hue': 'Green',
#      'percent': 0.11444444444444,
#      'spectrum': '#b55592'},
#     {'color': '#4b4b32',
#      'css3': '#556b2f',
#      'hue': 'Green',
#      'percent': 0.045029239766082,
#      'spectrum': '#4ab851'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Belinda L. Randall from the collection of John Witt Randall',
#    'culture': 'German',
#    'datebegin': 0,
#    'dated': '18th century',
#    'dateend': 0,
#    'dateoffirstpageview': '2015-03-17',
#    'dateoflastpageview': '2015-03-17',
#    'department': 'Department of Prints',
#    'description': None,
#    'dimensions': None,
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 242371,
#    'imagecount': 1,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV195697_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 784,
#      'idsid': 20460275,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20460275',
#      'imageid': 312292,
#      'publiccaption': None,
#      'renditionnumber': 'INV195697',
#      'width': 1024}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:16:34-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 242371,
#    'objectnumber': 'R8729',
#    'people': [{'alphasort': 'Gebhardt, Wolfgang Magnus',
#      'birthplace': None,
#      'culture': 'German',
#      'deathplace': None,
#      'displaydate': 'actual dates unknown; active 1720-50',
#      'displayname': 'Wolfgang Magnus Gebhardt',
#      'displayorder': 1,
#      'gender': 'unknown',
#      'name': 'Wolfgang Magnus Gebhardt',
#      'personid': 30060,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV195697_dynmc',
#    'provenance': 'John Witt Randall, bequest to his sister.\r\nBelinda Lull Randall, gift to Harvard University, 1892. sister of John Witt Randall\r\n',
#    'publicationcount': 0,
#    'rank': 249420,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/242371',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': 'Etching',
#    'techniqueid': 116,
#    'title': 'River with Two Waterfalls',
#    'titlescount': 2,
#    'totalpageviews': 1,
#    'totaluniquepageviews': 1,
#    'url': 'https://www.harvardartmuseums.org/collections/object/242371',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'print', 'worktypeid': '278'}]},
#   {'accessionmethod': 'Transfer',
#    'accessionyear': 2011,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Transfer from the Carpenter Center for the Visual Arts, American Professional Photographers Collection',
#    'culture': 'American',
#    'datebegin': 1955,
#    'dated': '1955',
#    'dateend': 1955,
#    'dateoffirstpageview': '2013-01-23',
#    'dateoflastpageview': '2013-01-23',
#    'department': 'Department of Photographs',
#    'description': None,
#    'dimensions': 'image: 10.16 x 12.7 cm (4 x 5 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 132798,
#    'imagecount': 2,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV054453N_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 816,
#      'idsid': 20223123,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20223123',
#      'imageid': 244772,
#      'publiccaption': None,
#      'renditionnumber': 'INV054453N',
#      'width': 1024},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV054453P_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 816,
#      'idsid': 42940834,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/42940834',
#      'imageid': 181086,
#      'publiccaption': None,
#      'renditionnumber': 'INV054453P',
#      'width': 1024}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:12:52-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 132798,
#    'objectnumber': '4.2002.9550',
#    'people': [{'alphasort': 'Schweig, Martin',
#      'birthplace': None,
#      'culture': 'American',
#      'deathplace': None,
#      'displaydate': '20th century',
#      'displayname': 'Martin Schweig',
#      'displayorder': 1,
#      'gender': 'unknown',
#      'name': 'Martin Schweig',
#      'personid': 22265,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV054453N_dynmc',
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 28620,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/132798',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': 'Negative, gelatin silver (film)',
#    'techniqueid': 107,
#    'title': 'Untitled (bride walking up steps to church with helpers carrying dress train)',
#    'titlescount': 2,
#    'totalpageviews': 1,
#    'totaluniquepageviews': 1,
#    'url': 'https://www.harvardartmuseums.org/collections/object/132798',
#    'verificationlevel': 3,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'worktypes': [{'worktype': 'negative', 'worktypeid': '235'},
#     {'worktype': 'photograph', 'worktypeid': '259'}]},
#   {'accessionmethod': 'Gift',
#    'accessionyear': 1992,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Drawings',
#    'classificationid': 21,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Busch-Reisinger Museum, Gift of the Artist through the German Art Dealers Association',
#    'culture': 'German',
#    'datebegin': 1968,
#    'dated': '1968',
#    'dateend': 1968,
#    'dateoffirstpageview': '2015-03-25',
#    'dateoflastpageview': '2015-03-25',
#    'department': 'Busch-Reisinger Museum',
#    'description': None,
#    'dimensions': '51.1 x 73 cm (20 1/8 x 28 3/4 in.)\r\nindividual sketches: 22 x 13 cm (8 11/16 x 5 1/8 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 221261,
#    'imagecount': 1,
#    'imagepermissionlevel': 1,
#    'images': [],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:15:50-0500',
#    'markscount': 1,
#    'mediacount': 0,
#    'medium': 'black ink and gray wash on off-white laid paper, 6 sheets mounted to off-white wove paper',
#    'objectid': 221261,
#    'objectnumber': '1992.220.A-F',
#    'people': [{'alphasort': 'Szymanski, Rolf',
#      'birthplace': 'Leipzig, Germany',
#      'culture': 'German',
#      'deathplace': 'Berlin, Germany',
#      'displaydate': '1928 - 2013',
#      'displayname': 'Rolf Szymanski',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Rolf Szymanski',
#      'personid': 28930,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': None,
#    'provenance': None,
#    'publicationcount': 1,
#    'rank': 113210,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/221261',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': 'on each sheet in graphite at l.r.: Szymanski',
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Six Sketches for "Le Corps clairvoyant"',
#    'titlescount': 2,
#    'totalpageviews': 1,
#    'totaluniquepageviews': 1,
#    'url': 'https://www.harvardartmuseums.org/collections/object/221261',
#    'verificationlevel': 3,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'worktypes': [{'worktype': 'drawing', 'worktypeid': '125'}]},
#   {'accessionmethod': 'Purchase',
#    'accessionyear': 2000,
#    'accesslevel': 1,
#    'century': '1st century CE',
#    'classification': 'Vessels',
#    'classificationid': 57,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_asianmediterranean@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Marian H. Phinney Fund',
#    'culture': 'Roman',
#    'datebegin': 1,
#    'dated': '1st century CE',
#    'dateend': 100,
#    'dateoffirstpageview': '2013-06-06',
#    'dateoflastpageview': '2013-06-06',
#    'department': 'Department of Ancient and Byzantine Art & Numismatics',
#    'description': 'Bowl with slight foot and two decorative incised lines on rim exterior.',
#    'dimensions': '4 x 13.5 cm (1 9/16 x 5 5/16 in.)',
#    'division': 'Asian and Mediterranean Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 1,
#    'id': 188353,
#    'imagecount': 1,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV108145_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 790,
#      'idsid': 20231308,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20231308',
#      'imageid': 195807,
#      'publiccaption': None,
#      'renditionnumber': 'INV108145',
#      'width': 1024}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:14:40-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Terracotta',
#    'objectid': 188353,
#    'objectnumber': '2000.41',
#    'peoplecount': 0,
#    'period': 'Hellenistic period to Early Roman Imperial',
#    'periodid': 1128,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV108145_dynmc',
#    'provenance': 'Richard C. Brockway, Acquired this object in the early 1960s.\r\n',
#    'publicationcount': 0,
#    'rank': 119980,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/188353',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': 'Redware',
#    'techniqueid': 2704,
#    'title': 'Footed Redware Bowl',
#    'titlescount': 1,
#    'totalpageviews': 1,
#    'totaluniquepageviews': 1,
#    'url': 'https://www.harvardartmuseums.org/collections/object/188353',
#    'verificationlevel': 0,
#    'verificationleveldescription': 'Unchecked. Object information has not been verified for completeness and has not been vetted',
#    'worktypes': [{'worktype': 'vessel', 'worktypeid': '389'}]},
#   {'accessionmethod': 'Purchase',
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': '19th century',
#    'classification': 'Prints',
#    'classificationid': 23,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, John Witt Randall Fund',
#    'culture': 'British',
#    'datebegin': 0,
#    'dated': '19th century',
#    'dateend': 0,
#    'dateoffirstpageview': '2019-01-08',
#    'dateoflastpageview': '2019-01-08',
#    'department': 'Department of Prints',
#    'description': None,
#    'dimensions': None,
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 246077,
#    'imagecount': 0,
#    'imagepermissionlevel': 0,
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:16:41-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 246077,
#    'objectnumber': 'R393NA',
#    'people': [{'alphasort': 'Armytage, James Charles',
#      'birthplace': None,
#      'culture': 'British',
#      'deathplace': None,
#      'displaydate': 'c. 1820 - 1897',
#      'displayname': 'James Charles Armytage',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'James Charles Armytage',
#      'personid': 33686,
#      'prefix': None,
#      'role': 'Artist'},
#     {'alphasort': 'Turner, Joseph Mallord William',
#      'birthplace': 'London, England',
#      'culture': 'British',
#      'deathplace': 'Chelsea, England',
#      'displaydate': '1775 - 1851',
#      'displayname': 'After Joseph Mallord William Turner',
#      'displayorder': 2,
#      'gender': 'male',
#      'name': 'Joseph Mallord William Turner',
#      'personid': 29118,
#      'prefix': 'After',
#      'role': 'Artist after'}],
#    'peoplecount': 2,
#    'period': None,
#    'periodid': None,
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 241676,
#    'relatedcount': 1,
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': 'Engraving',
#    'techniqueid': 98,
#    'title': 'Confluence of the Seine and Marne',
#    'titlescount': 2,
#    'totalpageviews': 1,
#    'totaluniquepageviews': 1,
#    'url': 'https://www.harvardartmuseums.org/collections/object/246077',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'print', 'worktypeid': '278'}]},
#   {'accessionmethod': 'Transfer',
#    'accessionyear': 2011,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Transfer from the Carpenter Center for the Visual Arts, American Professional Photographers Collection',
#    'culture': 'American',
#    'datebegin': 1935,
#    'dated': 'c. 1940',
#    'dateend': 1945,
#    'dateoffirstpageview': '2012-09-01',
#    'dateoflastpageview': '2012-09-01',
#    'department': 'Department of Photographs',
#    'description': None,
#    'dimensions': 'image: 11.4 x 7.7 cm (4 1/2 x 3 1/16 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 141266,
#    'imagecount': 1,
#    'imagepermissionlevel': 1,
#    'images': [],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:13:09-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 141266,
#    'objectnumber': '4.2002.1068',
#    'people': [{'alphasort': 'Annas, Harry',
#      'birthplace': None,
#      'culture': 'American',
#      'deathplace': None,
#      'displaydate': '1897 - 1980',
#      'displayname': 'Harry Annas',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Harry Annas',
#      'personid': 22094,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': None,
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 20164,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/141266',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': 'Gelatin silver print',
#    'techniqueid': 123,
#    'title': 'Untitled (girl in white dress with large white hat and evening bag)',
#    'titlescount': 2,
#    'totalpageviews': 1,
#    'totaluniquepageviews': 1,
#    'url': 'https://www.harvardartmuseums.org/collections/object/141266',
#    'verificationlevel': 3,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'worktypes': [{'worktype': 'photograph', 'worktypeid': '259'}]},
#   {'accessionmethod': 'Gift',
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': '© Artists Rights Society (ARS), New York / VG Bild-Kunst, Bonn',
#    'creditline': 'Harvard Art Museums/Busch-Reisinger Museum, Gift of T. Lux Feininger',
#    'culture': 'American',
#    'datebegin': 1949,
#    'dated': 'after 1948',
#    'dateend': 1958,
#    'dateoffirstpageview': '2012-12-10',
#    'dateoflastpageview': '2012-12-10',
#    'department': 'Busch-Reisinger Museum',
#    'description': None,
#    'dimensions': '3.5 x 2.5 cm (1 3/8 x 1 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 2,
#    'id': 35047,
#    'imagecount': 3,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV212569C_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 14309540,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/14309540',
#      'imageid': 381051,
#      'publiccaption': None,
#      'renditionnumber': 'INV212569C',
#      'width': 687},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV212569_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 14309080,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/14309080',
#      'imageid': 345025,
#      'publiccaption': None,
#      'renditionnumber': 'INV212569',
#      'width': 860},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV212569P_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 14309770,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/14309770',
#      'imageid': 388413,
#      'publiccaption': None,
#      'renditionnumber': 'INV212569P',
#      'width': 687}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:11:08-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 35047,
#    'objectnumber': 'BRLF.539.28',
#    'people': [{'alphasort': 'Feininger, Lyonel',
#      'birthplace': 'New York, NY',
#      'culture': 'American',
#      'deathplace': 'New York, NY',
#      'displaydate': '1871 - 1956',
#      'displayname': 'Lyonel Feininger',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Lyonel Feininger',
#      'personid': 20002,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV212569C_dynmc',
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 175681,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/35047',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': 'Negative, gelatin silver (35mm film)',
#    'techniqueid': 777,
#    'title': '[View of street below in snow]',
#    'titlescount': 1,
#    'totalpageviews': 1,
#    'totaluniquepageviews': 1,
#    'url': 'https://www.harvardartmuseums.org/collections/object/35047',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'negative', 'worktypeid': '235'},
#     {'worktype': 'photograph', 'worktypeid': '259'}]},
#   {'accessionmethod': 'Gift',
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': '© Artists Rights Society (ARS), New York / VG Bild-Kunst, Bonn',
#    'creditline': 'Harvard Art Museums/Busch-Reisinger Museum, Gift of T. Lux Feininger',
#    'culture': 'German',
#    'datebegin': 1936,
#    'dated': '1936',
#    'dateend': 1936,
#    'dateoffirstpageview': '2014-01-24',
#    'dateoflastpageview': '2014-01-24',
#    'department': 'Busch-Reisinger Museum',
#    'description': None,
#    'dimensions': '3.5 x 3 cm (1 3/8 x 1 3/16 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 2,
#    'id': 42423,
#    'imagecount': 3,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:INV212754C_dynmc',
#      'copyright': None,
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 13216108,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/13216108',
#      'imageid': 359937,
#      'publiccaption': None,
#      'renditionnumber': 'INV212754C',
#      'width': 701},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV212754_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 13215594,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/13215594',
#      'imageid': 345210,
#      'publiccaption': None,
#      'renditionnumber': 'INV212754',
#      'width': 935},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:INV212754P_dynmc',
#      'copyright': None,
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 13216365,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/13216365',
#      'imageid': 357731,
#      'publiccaption': None,
#      'renditionnumber': 'INV212754P',
#      'width': 701}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:11:24-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 42423,
#    'objectnumber': 'BRLF.193.12',
#    'people': [{'alphasort': 'Feininger, Lyonel',
#      'birthplace': 'New York, NY',
#      'culture': 'American',
#      'deathplace': 'New York, NY',
#      'displaydate': '1871 - 1956',
#      'displayname': 'Lyonel Feininger',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Lyonel Feininger',
#      'personid': 20002,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:huam:INV212754C_dynmc',
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 168140,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/42423',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': 'Negative, gelatin silver (35mm film)',
#    'techniqueid': 777,
#    'title': '[Church steeples]',
#    'titlescount': 1,
#    'totalpageviews': 1,
#    'totaluniquepageviews': 1,
#    'url': 'https://www.harvardartmuseums.org/collections/object/42423',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'negative', 'worktypeid': '235'},
#     {'worktype': 'photograph', 'worktypeid': '259'}]},
#   {'accessionmethod': 'Gift',
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': '19th century',
#    'classification': 'Prints',
#    'classificationid': 23,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Carl Pickhardt, Class of 1931',
#    'culture': 'French',
#    'datebegin': 1843,
#    'dated': '1843',
#    'dateend': 1843,
#    'dateoffirstpageview': '2017-04-30',
#    'dateoflastpageview': '2017-04-30',
#    'department': 'Department of Prints',
#    'description': None,
#    'dimensions': None,
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 268828,
#    'imagecount': 0,
#    'imagepermissionlevel': 0,
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:17:20-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 268828,
#    'objectnumber': 'M16326',
#    'people': [{'alphasort': 'Daumier, Honoré-Victorin',
#      'birthplace': 'Marseille, France',
#      'culture': 'French',
#      'deathplace': 'Valmondois, France',
#      'displaydate': '1808-1879',
#      'displayname': 'Honoré-Victorin Daumier',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Honoré-Victorin Daumier',
#      'personid': 34691,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 214344,
#    'relatedcount': 1,
#    'signed': None,
#    'standardreferencenumber': 'D. 1055',
#    'state': None,
#    'style': None,
#    'technique': 'Lithograph',
#    'techniqueid': 136,
#    'title': 'An Overly Long Wait',
#    'titlescount': 3,
#    'totalpageviews': 1,
#    'totaluniquepageviews': 1,
#    'url': 'https://www.harvardartmuseums.org/collections/object/268828',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'print', 'worktypeid': '278'}]},
#   {'accessionmethod': 'Gift',
#    'accessionyear': 1932,
#    'accesslevel': 1,
#    'century': '16th century',
#    'classification': 'Prints',
#    'classificationid': 23,
#    'colorcount': 7,
#    'colors': [{'color': '#e1c8af',
#      'css3': '#f5deb3',
#      'hue': 'Orange',
#      'percent': 0.28175925925926,
#      'spectrum': '#e9715f'},
#     {'color': '#967d64',
#      'css3': '#808080',
#      'hue': 'Brown',
#      'percent': 0.17083333333333,
#      'spectrum': '#b65590'},
#     {'color': '#7d644b',
#      'css3': '#696969',
#      'hue': 'Yellow',
#      'percent': 0.16356481481481,
#      'spectrum': '#b25593'},
#     {'color': '#4b4b32',
#      'css3': '#556b2f',
#      'hue': 'Green',
#      'percent': 0.11837962962963,
#      'spectrum': '#4ab851'},
#     {'color': '#af967d',
#      'css3': '#bc8f8f',
#      'hue': 'Brown',
#      'percent': 0.099490740740741,
#      'spectrum': '#c25687'},
#     {'color': '#c8af96',
#      'css3': '#d2b48c',
#      'hue': 'Brown',
#      'percent': 0.093101851851852,
#      'spectrum': '#e66c64'},
#     {'color': '#e1e1e1',
#      'css3': '#dcdcdc',
#      'hue': 'Grey',
#      'percent': 0.07287037037037,
#      'spectrum': '#955ba5'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Philip Hofer',
#    'culture': 'French',
#    'datebegin': 0,
#    'dated': '16th century',
#    'dateend': 0,
#    'dateoffirstpageview': '2013-01-22',
#    'dateoflastpageview': '2013-01-22',
#    'department': 'Department of Prints',
#    'description': None,
#    'dimensions': None,
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 0,
#    'id': 252691,
#    'imagecount': 1,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV179799_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 988,
#      'idsid': 20436433,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20436433',
#      'imageid': 294472,
#      'publiccaption': None,
#      'renditionnumber': 'INV179799',
#      'width': 1024}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:16:53-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 252691,
#    'objectnumber': 'M5833',
#    'people': [{'alphasort': 'Anonymous France (Lyons) 1599',
#      'birthplace': None,
#      'culture': 'French',
#      'deathplace': None,
#      'displaydate': '16th century',
#      'displayname': 'Anonymous France (Lyons) 1599',
#      'displayorder': 1,
#      'gender': 'unknown',
#      'name': 'Anonymous France (Lyons) 1599',
#      'personid': 34062,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV179799_dynmc',
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 205112,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/252691',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': 'Relief print',
#    'techniqueid': 703,
#    'title': 'Letter M',
#    'titlescount': 2,
#    'totalpageviews': 1,
#    'totaluniquepageviews': 1,
#    'url': 'https://www.harvardartmuseums.org/collections/object/252691',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'print', 'worktypeid': '278'}]}]}

# %%
print(R.status_code)
# Out:
# 200

# %%
R.json()['info']
# Out:
# {'next': 'https://api.harvardartmuseums.org/object?q=totalpageviews%3A1&size=10&apikey=622b6240-e14a-11e8-9234-6f5a1db33697&sort=random%3A8675309&page=2',
#  'page': 1,
#  'pages': 2352,
#  'totalrecords': 23512,
#  'totalrecordsperquery': 10}

# %%
set(R.json()['records'][0].keys())
# Out:
# {'accessionmethod',
#  'accessionyear',
#  'accesslevel',
#  'century',
#  'classification',
#  'classificationid',
#  'colorcount',
#  'colors',
#  'commentary',
#  'contact',
#  'contextualtextcount',
#  'copyright',
#  'creditline',
#  'culture',
#  'datebegin',
#  'dated',
#  'dateend',
#  'dateoffirstpageview',
#  'dateoflastpageview',
#  'department',
#  'description',
#  'dimensions',
#  'division',
#  'edition',
#  'exhibitioncount',
#  'groupcount',
#  'id',
#  'imagecount',
#  'imagepermissionlevel',
#  'images',
#  'labeltext',
#  'lastupdate',
#  'markscount',
#  'mediacount',
#  'medium',
#  'objectid',
#  'objectnumber',
#  'people',
#  'peoplecount',
#  'period',
#  'periodid',
#  'primaryimageurl',
#  'provenance',
#  'publicationcount',
#  'rank',
#  'relatedcount',
#  'seeAlso',
#  'signed',
#  'standardreferencenumber',
#  'state',
#  'style',
#  'technique',
#  'techniqueid',
#  'title',
#  'titlescount',
#  'totalpageviews',
#  'totaluniquepageviews',
#  'url',
#  'verificationlevel',
#  'verificationleveldescription',
#  'worktypes'}

# %% [markdown]
# ## Changing our request
#
# Let's say we're not interested in the most obscure parts of the collection, but rather in the most popular parts of the collection. There are a few ways we might go about doing this. One way might be to sort our search results by `totalpageviews`, and see what the top 10 are.
#
# To do that, we can go back to the [Object API documentation](https://github.com/harvardartmuseums/api-docs/blob/master/sections/object.md) and look for hints about what we might be able to do.

# %%
parameters = {
    "apikey":APIKEY,
    "sort":"totalpageviews",
    "sortorder":"desc",
    "size":10
} # Add your own query parameters here
R = requests.get(url,params=parameters)
R.json()
# Out:
# {'info': {'next': 'https://api.harvardartmuseums.org/object?apikey=622b6240-e14a-11e8-9234-6f5a1db33697&sort=totalpageviews&sortorder=desc&size=10&page=2',
#   'page': 1,
#   'pages': 23361,
#   'totalrecords': 233609,
#   'totalrecordsperquery': 10},
#  'records': [{'accessionmethod': 'Bequest',
#    'accessionyear': 1951,
#    'accesslevel': 1,
#    'century': '19th century',
#    'classification': 'Paintings',
#    'classificationid': 26,
#    'colorcount': 10,
#    'colors': [{'color': '#64af7d',
#      'css3': '#5f9ea0',
#      'hue': 'Green',
#      'percent': 0.2979781420765,
#      'spectrum': '#4fb94f'},
#     {'color': '#64c896',
#      'css3': '#66cdaa',
#      'hue': 'Green',
#      'percent': 0.21289617486339,
#      'spectrum': '#47b853'},
#     {'color': '#323219',
#      'css3': '#2f4f4f',
#      'hue': 'Brown',
#      'percent': 0.19814207650273,
#      'spectrum': '#3db657'},
#     {'color': '#7d7d4b',
#      'css3': '#696969',
#      'hue': 'Green',
#      'percent': 0.056775956284153,
#      'spectrum': '#6cbd45'},
#     {'color': '#969664',
#      'css3': '#808080',
#      'hue': 'Green',
#      'percent': 0.043715846994536,
#      'spectrum': '#84c441'},
#     {'color': '#afaf7d',
#      'css3': '#bdb76b',
#      'hue': 'Green',
#      'percent': 0.042622950819672,
#      'spectrum': '#9ecb3b'},
#     {'color': '#4b9664',
#      'css3': '#2e8b57',
#      'hue': 'Green',
#      'percent': 0.036885245901639,
#      'spectrum': '#3db657'},
#     {'color': '#191919',
#      'css3': '#000000',
#      'hue': 'Grey',
#      'percent': 0.034972677595628,
#      'spectrum': '#1eb264'},
#     {'color': '#644b19',
#      'css3': '#8b4513',
#      'hue': 'Orange',
#      'percent': 0.032295081967213,
#      'spectrum': '#64bc46'},
#     {'color': '#647d64',
#      'css3': '#696969',
#      'hue': 'Green',
#      'percent': 0.018032786885246,
#      'spectrum': '#4fb94f'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest from the Collection of Maurice Wertheim, Class of 1906',
#    'culture': 'Dutch',
#    'datebegin': 1888,
#    'dated': '1888',
#    'dateend': 1888,
#    'dateoffirstpageview': '2009-05-12',
#    'dateoflastpageview': '2019-11-05',
#    'department': 'Department of Paintings, Sculpture & Decorative Arts',
#    'description': None,
#    'dimensions': '61.5 x 50.3 cm (24 3/16 x 19 13/16 in.)\r\nframed: 90.4 x 79.7 x 8.3 cm (35 9/16 x 31 3/8 x 3 1/4 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 26,
#    'groupcount': 3,
#    'id': 299843,
#    'imagecount': 6,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC251942_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 47174896,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/47174896',
#      'imageid': 429030,
#      'publiccaption': None,
#      'renditionnumber': 'DDC251942',
#      'width': 2087},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC000072_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 18737483,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18737483',
#      'imageid': 185978,
#      'publiccaption': None,
#      'renditionnumber': 'DDC000072',
#      'width': 2088},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC251934_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 47174892,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/47174892',
#      'imageid': 429028,
#      'publiccaption': None,
#      'renditionnumber': 'DDC251934',
#      'width': 2259},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:30033_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 4,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 43182083,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43182083',
#      'imageid': 25781,
#      'publiccaption': None,
#      'renditionnumber': '30033',
#      'width': 844},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:50493_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 5,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 43183405,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43183405',
#      'imageid': 19801,
#      'publiccaption': None,
#      'renditionnumber': '50493',
#      'width': 2082},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:50849_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 6,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 43183422,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43183422',
#      'imageid': 42292,
#      'publiccaption': None,
#      'renditionnumber': '50849',
#      'width': 2093}],
#    'labeltext': 'In early 1888, Van Gogh moved to Arles in the south of France, where he hoped to establish an art colony. Believing that painting could be reinvented through the genre of portraiture, he encouraged his fellow artists to paint themselves, and then to exchange the canvases. After receiving self-portraits from Emile Bernard and Gauguin, who were working together in Brittany at the time, Van Gogh inscribed this painting “To my friend Paul Gauguin,” and sent it to him. He described the process of creating his arresting likeness in several letters to his brother Theo, an art dealer in Paris, explaining how he manipulated his features in response to Japanese prints, changed the contours of his jacket for coloristic effect, and painted the background “pale veronese green” without any shadows. Shortly after he sent the work to Gauguin, however, their friendship deteriorated, and Gauguin sold it for three hundred francs.',
#    'lastupdate': '2019-11-06T06:18:22-0500',
#    'markscount': 22,
#    'mediacount': 0,
#    'medium': 'Oil on canvas',
#    'objectid': 299843,
#    'objectnumber': '1951.65',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC251942_dynmc',
#    'provenance': 'Vincent van Gogh, Arles, (1888,) gift;  to Paul Gauguin, (1888-1897) sold. [Ambroise Vollard, Paris.] [Paul Cassirer Gallery, Berlin.] Dr. Hugo von Tschudi, Berlin, (1906-1911), by descent; to his widow, Angela von Tschudi, Munich (1911-1919),  to Neue Staatsgalerie, Munich (1919-1938); removed from the collection by the National Socialist (Nazi) authorities in 1938, consigned; to [Theodor Fischer Gallery, Lucerne, Switzerland, for sale June 30, 1939, lot 45]; to Maurice Wertheim (1939-1951) bequest; to Fogg Art Museum, 1951.\r\n\r\n \r\n\r\nNotes:\r\nGauguin sold the painting for Fr 300\r\nHugo von Tschudi bought the painting for the Nationalgalerie, Berlin, with funds from sponsors, but did not submit it to the Kaiser for pre-approval. He took the painting to Munich when he assumed a post there.\r\nAccording to Stephanie Barron, the van Gogh was removed from the Neue Staatsgalerie on March 27, 1938 and stored at Schloss Niederschönhausen in August of that year. (Barron, 1991, pp. 135-146)\r\n',
#    'publicationcount': 206,
#    'rank': 466,
#    'relatedcount': 2,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/299843',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': 'red paint, l.r.: Vincent/Arles',
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Self-Portrait Dedicated to Paul Gauguin',
#    'titlescount': 1,
#    'totalpageviews': 30662,
#    'totaluniquepageviews': 24589,
#    'url': 'https://www.harvardartmuseums.org/collections/object/299843',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]},
#   {'accessionmethod': 'Bequest',
#    'accessionyear': 1951,
#    'accesslevel': 1,
#    'century': '19th century',
#    'classification': 'Paintings',
#    'classificationid': 26,
#    'colorcount': 8,
#    'colors': [{'color': '#7d96af',
#      'css3': '#778899',
#      'hue': 'Blue',
#      'percent': 0.19830601092896,
#      'spectrum': '#7069af'},
#     {'color': '#4b647d',
#      'css3': '#696969',
#      'hue': 'Blue',
#      'percent': 0.18808743169399,
#      'spectrum': '#536fb5'},
#     {'color': '#96afaf',
#      'css3': '#a9a9a9',
#      'hue': 'Blue',
#      'percent': 0.15650273224044,
#      'spectrum': '#7b65ad'},
#     {'color': '#193232',
#      'css3': '#2f4f4f',
#      'hue': 'Green',
#      'percent': 0.1316393442623,
#      'spectrum': '#1eb264'},
#     {'color': '#647d96',
#      'css3': '#708090',
#      'hue': 'Blue',
#      'percent': 0.11136612021858,
#      'spectrum': '#656cb2'},
#     {'color': '#afafc8',
#      'css3': '#c0c0c0',
#      'hue': 'Blue',
#      'percent': 0.10060109289617,
#      'spectrum': '#8761aa'},
#     {'color': '#4b4b4b',
#      'css3': '#2f4f4f',
#      'hue': 'Grey',
#      'percent': 0.058688524590164,
#      'spectrum': '#3db657'},
#     {'color': '#324b64',
#      'css3': '#2f4f4f',
#      'hue': 'Blue',
#      'percent': 0.054808743169399,
#      'spectrum': '#4072b8'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest from the Collection of Maurice Wertheim, Class of 1906',
#    'culture': 'French',
#    'datebegin': 1877,
#    'dated': '1877',
#    'dateend': 1877,
#    'dateoffirstpageview': '2009-05-12',
#    'dateoflastpageview': '2019-11-05',
#    'department': 'Department of Paintings, Sculpture & Decorative Arts',
#    'description': None,
#    'dimensions': '83 x 101.3 cm (32 11/16 x 39 7/8 in.)\r\nframed: 110.3 x 127.5 x 9.5 cm (43 7/16 x 50 3/16 x 3 3/4 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 24,
#    'groupcount': 1,
#    'id': 228649,
#    'imagecount': 3,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC231456_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 2074,
#      'idsid': 45451171,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45451171',
#      'imageid': 417413,
#      'publiccaption': None,
#      'renditionnumber': 'DDC231456',
#      'width': 2550},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC245539_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 853,
#      'idsid': 45451173,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45451173',
#      'imageid': 417415,
#      'publiccaption': 'Framed',
#      'renditionnumber': 'DDC245539',
#      'width': 1024},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS30127_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 813,
#      'idsid': 20673617,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20673617',
#      'imageid': 7477,
#      'publiccaption': None,
#      'renditionnumber': '30127',
#      'width': 1024}],
#    'labeltext': 'This is the largest in Monet’s series of twelve paintings of the Saint-Lazare train station in Paris, a subject favored by many impressionist painters. While completing the series, Monet relocated from the town of Argenteuil to an apartment near the station in Paris. He worked on all the paintings at the same time, and sometimes he leaned the stretched canvases against each other while the paint was still wet. This caused the cork spacers on the backs of the stretchers to be pressed into the adjacent paintings, creating circular indentations in the surface that are visible along the top edge of this work. Monet’s thick build-up of pigments here is a virtuosic example of his approach to painting during this period, when he juxtaposed multitudinous hues in mounds of impasto that would blend into a coherent whole only when viewed from a distance. This technique reportedly led Cézanne to declare, “Monet is only an eye, but my God what an eye!”',
#    'lastupdate': '2019-11-06T06:16:04-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Oil on canvas',
#    'objectid': 228649,
#    'objectnumber': '1951.53',
#    'people': [{'alphasort': 'Monet, Claude',
#      'birthplace': 'Paris, France',
#      'culture': 'French',
#      'deathplace': 'Giverny, France',
#      'displaydate': '1840 - 1926',
#      'displayname': 'Claude Monet',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Claude Monet',
#      'personid': 27651,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC231456_dynmc',
#    'provenance': 'Claude Monet, Painted, 1877, sold: to Ernest Hoschedé, 1877, sold; to Charles Deudon, 1877 [1]. [Paul Rosenberg, Paris (by 1919)]. Mme. Emile Staub-Terlinden, Mannedorf, Switzerland, (by 1923-at least 1938) [2], sold; [to Wildenstein and Co., New York,(c. 1942-1945) ] sold; to  Maurice Wertheim (1945-1951), bequest; to Fogg Art Museum, 1951.\r\n\r\nNotes:\r\n[1] Distel cites Monet notebook on sale to Deudon "pour le compte de M. Hoschedé," who had gone bankrupt.\r\n\r\n[2] Seligmann archives note presence of this painting in Staub-Terlinden\'s home during 1930 visit. Staub-Terlinden put paintings on deposit with Wildenstein some time after 1938 exhibition, Wildenstein purchased c. 1942-43, per documents in Foreign Funds Control Investigative Reports.',
#    'publicationcount': 130,
#    'rank': 79814,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/228649',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': 'l.l.: Claude Monet 77',
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'The Gare Saint-Lazare: Arrival of a Train',
#    'titlescount': 2,
#    'totalpageviews': 22823,
#    'totaluniquepageviews': 18370,
#    'url': 'https://www.harvardartmuseums.org/collections/object/228649',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]},
#   {'accessionmethod': 'Bequest',
#    'accessionyear': 1960,
#    'accesslevel': 1,
#    'century': '14th century',
#    'classification': 'Manuscripts',
#    'classificationid': 185,
#    'colorcount': 8,
#    'colors': [{'color': '#c8af96',
#      'css3': '#d2b48c',
#      'hue': 'Brown',
#      'percent': 0.25104938271605,
#      'spectrum': '#e66c64'},
#     {'color': '#af967d',
#      'css3': '#bc8f8f',
#      'hue': 'Brown',
#      'percent': 0.20604938271605,
#      'spectrum': '#c25687'},
#     {'color': '#7d6464',
#      'css3': '#696969',
#      'hue': 'Brown',
#      'percent': 0.15413580246914,
#      'spectrum': '#8e5ea7'},
#     {'color': '#e1c8af',
#      'css3': '#f5deb3',
#      'hue': 'Orange',
#      'percent': 0.12364197530864,
#      'spectrum': '#e9715f'},
#     {'color': '#644b4b',
#      'css3': '#696969',
#      'hue': 'Brown',
#      'percent': 0.11753086419753,
#      'spectrum': '#8362aa'},
#     {'color': '#967d64',
#      'css3': '#808080',
#      'hue': 'Brown',
#      'percent': 0.1129012345679,
#      'spectrum': '#b65590'},
#     {'color': '#4b647d',
#      'css3': '#696969',
#      'hue': 'Blue',
#      'percent': 0.023395061728395,
#      'spectrum': '#536fb5'},
#     {'color': '#964b32',
#      'css3': '#a0522d',
#      'hue': 'Orange',
#      'percent': 0.011296296296296,
#      'spectrum': '#d0577c'}],
#    'commentary': None,
#    'contact': 'am_asianmediterranean@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Bequest of Abby Aldrich Rockefeller',
#    'culture': 'Persian',
#    'datebegin': 1330,
#    'dated': 'c. 1330-1340',
#    'dateend': 1340,
#    'dateoffirstpageview': '2009-06-05',
#    'dateoflastpageview': '2019-11-05',
#    'department': 'Department of Islamic & Later Indian Art',
#    'description': 'This folio is from a celebrated copy of the text known as the Great Ilkhanid Shahnama, one of the most complex masterpieces of Persian art. Because of its lavish production, it is assumed to have been commissioned by a high-ranking member of the Ilkhanid court and produced at the court scriptorium. The fifty-seven surviving illustrations reflect the intense interest in historical chronicles and the experimental approach to painting of the Ilkhanid period (1256–1335). The eclectic paintings reveal the cosmopolitanism of the Ilkhanid court in Tabriz, which teemed with merchants, missionaries, and diplomats from as far away as Europe and China. Here the Iranian king Bahram Gur wears a robe made of European fabric to slay a fearsome horned wolf in a setting marked by the conventions of Chinese landscape painting.',
#    'dimensions': 'folio: 41.5 x 30 cm (16 5/16 x 11 13/16 in.)',
#    'division': 'Asian and Mediterranean Art',
#    'edition': None,
#    'exhibitioncount': 7,
#    'groupcount': 2,
#    'id': 169542,
#    'imagecount': 3,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:770435',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 469446516,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/469446516',
#      'imageid': 500862,
#      'publiccaption': 'verso',
#      'renditionnumber': '770435',
#      'width': 1875},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:770434',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1824,
#      'idsid': 469446512,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/469446512',
#      'imageid': 500861,
#      'publiccaption': 'detail of verso',
#      'renditionnumber': '770434',
#      'width': 2550},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:770445',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 469454932,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/469454932',
#      'imageid': 500872,
#      'publiccaption': 'recto',
#      'renditionnumber': '770445',
#      'width': 1853}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:14:02-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Ink, colors, gold, and silver on paper',
#    'objectid': 169542,
#    'objectnumber': '1960.190',
#    'peoplecount': 0,
#    'period': 'Ilkhanid period',
#    'periodid': 2583,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:770435',
#    'provenance': 'Abby Aldrich Rockefeller, New York, NY, (by 1948), bequest; to Fogg Art Museum, 1960.',
#    'publicationcount': 16,
#    'rank': 465,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/169542',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Bahram Gur Fights the Horned Wolf (painting, verso; text, recto), illustrated folio from a manuscript of the Great Ilkhanid Shahnama (Book of Kings)',
#    'titlescount': 2,
#    'totalpageviews': 16562,
#    'totaluniquepageviews': 13925,
#    'url': 'https://www.harvardartmuseums.org/collections/object/169542',
#    'verificationlevel': 3,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'worktypes': [{'worktype': 'manuscript folio', 'worktypeid': '210'}]},
#   {'accessionmethod': 'Bequest',
#    'accessionyear': 1943,
#    'accesslevel': 1,
#    'century': '19th century',
#    'classification': 'Paintings',
#    'classificationid': 26,
#    'colorcount': 10,
#    'colors': [{'color': '#321919',
#      'css3': '#000000',
#      'hue': 'Brown',
#      'percent': 0.40401234567901,
#      'spectrum': '#3db657'},
#     {'color': '#4b4b32',
#      'css3': '#556b2f',
#      'hue': 'Green',
#      'percent': 0.19111111111111,
#      'spectrum': '#4ab851'},
#     {'color': '#7d644b',
#      'css3': '#696969',
#      'hue': 'Yellow',
#      'percent': 0.13827160493827,
#      'spectrum': '#b25593'},
#     {'color': '#c8af7d',
#      'css3': '#d2b48c',
#      'hue': 'Brown',
#      'percent': 0.061296296296296,
#      'spectrum': '#e9715f'},
#     {'color': '#967d64',
#      'css3': '#808080',
#      'hue': 'Brown',
#      'percent': 0.058086419753086,
#      'spectrum': '#b65590'},
#     {'color': '#af967d',
#      'css3': '#bc8f8f',
#      'hue': 'Brown',
#      'percent': 0.055185185185185,
#      'spectrum': '#c25687'},
#     {'color': '#7d3219',
#      'css3': '#8b4513',
#      'hue': 'Orange',
#      'percent': 0.045432098765432,
#      'spectrum': '#d0577c'},
#     {'color': '#af7d4b',
#      'css3': '#cd853f',
#      'hue': 'Yellow',
#      'percent': 0.026543209876543,
#      'spectrum': '#e9715f'},
#     {'color': '#fac896',
#      'css3': '#ffdead',
#      'hue': 'Orange',
#      'percent': 0.012469135802469,
#      'spectrum': '#ef7a55'},
#     {'color': '#af4b19',
#      'css3': '#a0522d',
#      'hue': 'Red',
#      'percent': 0.0059876543209877,
#      'spectrum': '#e86e61'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest of Grenville L. Winthrop',
#    'culture': 'French',
#    'datebegin': 1839,
#    'dated': '1839-1840',
#    'dateend': 1840,
#    'dateoffirstpageview': '2009-05-13',
#    'dateoflastpageview': '2019-11-05',
#    'department': 'Department of Paintings, Sculpture & Decorative Arts',
#    'description': None,
#    'dimensions': '72.1 x 100.3 cm (28 3/8 x 39 1/2 in.)\r\nframe: 94.6 x 122.6 x 7.6 cm (37 1/4 x 48 1/4 x 3 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 18,
#    'groupcount': 2,
#    'id': 299806,
#    'imagecount': 2,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51355_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1843,
#      'idsid': 17386642,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17386642',
#      'imageid': 52851,
#      'publiccaption': None,
#      'renditionnumber': '51355',
#      'width': 2550},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:10579_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1830,
#      'idsid': 43181266,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43181266',
#      'imageid': 5651,
#      'publiccaption': None,
#      'renditionnumber': '10579',
#      'width': 2550}],
#    'labeltext': 'The central figure of the odalisque (a concubine in a harem) represents Ingres’s reinterpretation of the Western classical tradition of the female nude in the modern context of the Middle Eastern “other.” Though Ingres had never traveled outside Europe, he became fascinated by writings about Turkish society, mixing details from travel writing with his own fantasies. Period critics admired the way Ingres depicted the skin of the three different figures, praising how “the variety and nature of the races has been understood and expressed by the artist.” One commentator sorted the figures by skin type, contrasting the “white favorite” prone at the center of the painting, the “young Abyssinian slave . . . tawny like bronze” playing music at her side, and the “black eunuch” in the background. With her languid, available pose and state of undress, the white odalisque is offered as the sexual prize for the presumed male proprietor of this lavish interior—and by proxy, the viewer.',
#    'lastupdate': '2019-11-06T06:18:22-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Oil on canvas',
#    'objectid': 299806,
#    'objectnumber': '1943.251',
#    'people': [{'alphasort': 'Ingres, Jean-Auguste-Dominique',
#      'birthplace': 'Montauban',
#      'culture': 'French',
#      'deathplace': 'Paris',
#      'displaydate': '1780 - 1867',
#      'displayname': 'Jean-Auguste-Dominique Ingres',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Jean-Auguste-Dominique Ingres',
#      'personid': 26693,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51355_dynmc',
#    'provenance': "Jean-Auguste-Dominique Ingres, sold to Charles Marcotte d'Argenteuil, 1840, by descent; to Louis-Marie-Joseph Marcotte, his son, offered for sale [through Ingres sale, Hôtel Druot, Paris, April 27, 1867, lot 17]; bought in by Marcotte, sold; to Louis Aguillon, the brother-in-law of Louis-Marie-Joseph Marcotte, by descent; to Louis Marcotte de Quivières, sold [through de Quivières sale, Hôtel Drouot, Paris, 1875, lot 11]; to Guilhermony [1]. Gustave Pereire, Paris, 1911, by descent; to his wife, Mme. Henriette Pereire. Carroll S. Tyson, Philadelphia. [Wildenstein & Co., New York], sold; to Grenville Lindall Winthrop, 1935, bequest; to Fogg Art Museum, 1943\r\n\r\nNotes\r\n[1] The spelling of Guilhermony varies; also found as Guilhermy\r\n\r\n",
#    'publicationcount': 266,
#    'rank': 464,
#    'relatedcount': 3,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/299806',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': 'l.l.: J. Ingres / Rom. 1839',
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Odalisque, Slave, and Eunuch',
#    'titlescount': 2,
#    'totalpageviews': 14965,
#    'totaluniquepageviews': 11766,
#    'url': 'https://www.harvardartmuseums.org/collections/object/299806',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]},
#   {'accessionmethod': 'Bequest',
#    'accessionyear': 1966,
#    'accesslevel': 1,
#    'century': '18th century',
#    'classification': 'Paintings',
#    'classificationid': 26,
#    'colorcount': 10,
#    'colors': [{'color': '#7d7d64',
#      'css3': '#808080',
#      'hue': 'Yellow',
#      'percent': 0.34745098039216,
#      'spectrum': '#6cbd45'},
#     {'color': '#4b4b32',
#      'css3': '#556b2f',
#      'hue': 'Green',
#      'percent': 0.29344537815126,
#      'spectrum': '#4ab851'},
#     {'color': '#64644b',
#      'css3': '#696969',
#      'hue': 'Green',
#      'percent': 0.1127731092437,
#      'spectrum': '#59ba4a'},
#     {'color': '#afafaf',
#      'css3': '#a9a9a9',
#      'hue': 'Grey',
#      'percent': 0.08733893557423,
#      'spectrum': '#8c5fa8'},
#     {'color': '#4b3219',
#      'css3': '#556b2f',
#      'hue': 'Brown',
#      'percent': 0.079271708683473,
#      'spectrum': '#4ab851'},
#     {'color': '#969696',
#      'css3': '#a9a9a9',
#      'hue': 'Grey',
#      'percent': 0.056526610644258,
#      'spectrum': '#8761aa'},
#     {'color': '#c8c8c8',
#      'css3': '#c0c0c0',
#      'hue': 'Grey',
#      'percent': 0.018207282913165,
#      'spectrum': '#8c5fa8'},
#     {'color': '#4b647d',
#      'css3': '#696969',
#      'hue': 'Blue',
#      'percent': 0.0042577030812325,
#      'spectrum': '#536fb5'},
#     {'color': '#191919',
#      'css3': '#000000',
#      'hue': 'Grey',
#      'percent': 0.0003921568627451,
#      'spectrum': '#1eb264'},
#     {'color': '#967d32',
#      'css3': '#a0522d',
#      'hue': 'Yellow',
#      'percent': 0.00033613445378151,
#      'spectrum': '#86c440'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest of Charles E. Dunlap',
#    'culture': 'French',
#    'datebegin': 1750,
#    'dated': '1750, with later additions',
#    'dateend': 1750,
#    'dateoffirstpageview': '2009-05-12',
#    'dateoflastpageview': '2019-11-05',
#    'department': 'Department of Paintings, Sculpture & Decorative Arts',
#    'description': None,
#    'dimensions': '81.2 × 64.9 cm (31 15/16 × 25 9/16 in.)\r\nframe: 99.8 x 84.5 cm (39 5/16 x 33 1/4 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 9,
#    'groupcount': 2,
#    'id': 303561,
#    'imagecount': 4,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51366_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 17386653,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17386653',
#      'imageid': 19994,
#      'publiccaption': None,
#      'renditionnumber': '51366',
#      'width': 2032},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG259401',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 420781173,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/420781173',
#      'imageid': 461352,
#      'publiccaption': None,
#      'renditionnumber': 'LEG259401',
#      'width': 2181},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:10577_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 43181265,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43181265',
#      'imageid': 921,
#      'publiccaption': None,
#      'renditionnumber': '10577',
#      'width': 829},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:20028_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 4,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 43181886,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43181886',
#      'imageid': 6377,
#      'publiccaption': None,
#      'renditionnumber': '20028',
#      'width': 811}],
#    'labeltext': 'This likeness of the marquise de Pompadour (1721–1764) was originally painted as a rectangular bust-length portrait for her brother, Abel-François Poisson, marquis de Marigny. After being damaged in transit, the portrait was extended on all sides, most likely by Boucher himself, and transformed to portray the marquise at her dressing table. The depiction of the mirror was changed from silver to green lacquer around 1759, when many courtiers surrendered their precious metals to support the war against Britain. About a decade later, the canvas may have been reshaped into an oval to suit contemporary taste.\r\nPompadour was the official mistress of Louis XV beginning in 1745. The king’s portrait on her wrist decorously signifies that bond. The signature and date of 1758 found above the chair are much later additions.',
#    'lastupdate': '2019-11-06T06:18:30-0500',
#    'markscount': 8,
#    'mediacount': 0,
#    'medium': 'Oil on canvas',
#    'objectid': 303561,
#    'objectnumber': '1966.47',
#    'people': [{'alphasort': 'Boucher, François',
#      'birthplace': 'Paris',
#      'culture': 'French',
#      'deathplace': 'Paris',
#      'displaydate': '1703 - 1770',
#      'displayname': 'François Boucher',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'François Boucher',
#      'personid': 29169,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51366_dynmc',
#    'provenance': 'Jeanne-Antoinette Poisson, Marquise de Pompadour, gift; to her brother, M de Vandières, later the Marquis de Marigny (by 1781). [Anonymous sale, Maciet and Haro, March 15, 1875,  lot 11].  Baron Salomon Albert Anselm de Rothschild, Vienna, (c. 1920s), by descent; to his son Baron Louis de Rothschild, Vienna, sold; through [Wildenstein & Co., Paris]; to Baron Maurice de Rothschild, Pregny, Switzerland, (? - until 1952) sold; through [Rosenberg & Stiebel, New York (1952-1953) sold]; to Charles E. Dunlap (1953-1966), gift; to Fogg Art Museum, 1966.\r\n\r\n\r\nNotes:\r\n\r\nMuch of the Louis de Rothschild collection was confiscated during World War II and recuperated afterwards.',
#    'publicationcount': 47,
#    'rank': 463,
#    'relatedcount': 3,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/303561',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Jeanne-Antoinette Poisson, Marquise de Pompadour',
#    'titlescount': 1,
#    'totalpageviews': 13478,
#    'totaluniquepageviews': 10963,
#    'url': 'https://www.harvardartmuseums.org/collections/object/303561',
#    'verificationlevel': 3,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]},
#   {'accessionmethod': 'Bequest',
#    'accessionyear': 1965,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Drawings',
#    'classificationid': 21,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': '© Estate of Pablo Picasso / Artists Rights Society (ARS), New York',
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest of Meta and Paul J. Sachs',
#    'culture': 'Spanish',
#    'datebegin': 1903,
#    'dated': '1903-1904',
#    'dateend': 1904,
#    'dateoffirstpageview': '2009-05-12',
#    'dateoflastpageview': '2019-11-05',
#    'department': 'Department of Drawings',
#    'description': None,
#    'dimensions': '33.8 x 26.7 cm (13 5/16 x 10 1/2 in.)\r\nframed: 54.6 x 44.5 cm (21 1/2 x 17 1/2 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 7,
#    'groupcount': 0,
#    'id': 299997,
#    'imagecount': 5,
#    'imagepermissionlevel': 1,
#    'images': [],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:18:23-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Black crayon on tan wove paper; verso: black ink',
#    'objectid': 299997,
#    'objectnumber': '1965.318',
#    'people': [{'alphasort': 'Picasso, Pablo Ruiz',
#      'birthplace': 'Malaga, Spain',
#      'culture': 'Spanish',
#      'deathplace': 'Mougins, France',
#      'displaydate': '1881 - 1973',
#      'displayname': 'Pablo Ruiz Picasso',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Pablo Ruiz Picasso',
#      'personid': 28064,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': None,
#    'provenance': 'Charles Vignier, Paris, sold; to Paul J. Sachs, Cambridge, Massachusetts (L. 2091), 1929, bequest; to Fogg Art Museum, 1965.',
#    'publicationcount': 15,
#    'rank': 85823,
#    'relatedcount': 3,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/299997',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'A Mother and Child and Four Studies of Her Right Hand, 1904; verso:  Self-Portrait Standing, 1903',
#    'titlescount': 1,
#    'totalpageviews': 13061,
#    'totaluniquepageviews': 9398,
#    'url': 'https://www.harvardartmuseums.org/collections/object/299997',
#    'verificationlevel': 3,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'worktypes': [{'worktype': 'drawing', 'worktypeid': '125'}]},
#   {'accessionmethod': 'Bequest',
#    'accessionyear': 1951,
#    'accesslevel': 1,
#    'century': '19th century',
#    'classification': 'Paintings',
#    'classificationid': 26,
#    'colorcount': 10,
#    'colors': [{'color': '#96afaf',
#      'css3': '#a9a9a9',
#      'hue': 'Blue',
#      'percent': 0.33357357357357,
#      'spectrum': '#7b65ad'},
#     {'color': '#647d7d',
#      'css3': '#708090',
#      'hue': 'Blue',
#      'percent': 0.27063063063063,
#      'spectrum': '#6c6ab0'},
#     {'color': '#7d9696',
#      'css3': '#778899',
#      'hue': 'Green',
#      'percent': 0.20228228228228,
#      'spectrum': '#7069af'},
#     {'color': '#4b647d',
#      'css3': '#696969',
#      'hue': 'Blue',
#      'percent': 0.11255255255255,
#      'spectrum': '#536fb5'},
#     {'color': '#afc8c8',
#      'css3': '#c0c0c0',
#      'hue': 'Green',
#      'percent': 0.03033033033033,
#      'spectrum': '#8761aa'},
#     {'color': '#64644b',
#      'css3': '#696969',
#      'hue': 'Green',
#      'percent': 0.027027027027027,
#      'spectrum': '#59ba4a'},
#     {'color': '#324b4b',
#      'css3': '#2f4f4f',
#      'hue': 'Grey',
#      'percent': 0.016156156156156,
#      'spectrum': '#2eb45d'},
#     {'color': '#af6432',
#      'css3': '#a0522d',
#      'hue': 'Orange',
#      'percent': 0.0032432432432432,
#      'spectrum': '#e9715f'},
#     {'color': '#c8e1e1',
#      'css3': '#dcdcdc',
#      'hue': 'Green',
#      'percent': 0.0030630630630631,
#      'spectrum': '#8761aa'},
#     {'color': '#af7d4b',
#      'css3': '#cd853f',
#      'hue': 'Yellow',
#      'percent': 0.0011411411411411,
#      'spectrum': '#e9715f'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest from the Collection of Maurice Wertheim, Class of 1906',
#    'culture': 'French',
#    'datebegin': 1875,
#    'dated': '1875',
#    'dateend': 1875,
#    'dateoffirstpageview': '2009-06-09',
#    'dateoflastpageview': '2019-11-05',
#    'department': 'Department of Paintings, Sculpture & Decorative Arts',
#    'description': None,
#    'dimensions': '61.8 x 82.5 cm (24 5/16 x 32 1/2 in.)\r\nframed: 91 x 111.2 x 10.2 cm (35 13/16 x 43 3/4 x 4 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 20,
#    'groupcount': 1,
#    'id': 228650,
#    'imagecount': 4,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC231457_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1887,
#      'idsid': 46080098,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/46080098',
#      'imageid': 417408,
#      'publiccaption': None,
#      'renditionnumber': 'DDC231457',
#      'width': 2550},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC245420_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 834,
#      'idsid': 46080100,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/46080100',
#      'imageid': 417410,
#      'publiccaption': None,
#      'renditionnumber': 'DDC245420',
#      'width': 1024},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS30367_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 827,
#      'idsid': 20673713,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20673713',
#      'imageid': 7533,
#      'publiccaption': None,
#      'renditionnumber': '30367',
#      'width': 1024},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:30464_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 4,
#      'format': 'image/jpeg',
#      'height': 771,
#      'idsid': 17357776,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17357776',
#      'imageid': 26321,
#      'publiccaption': None,
#      'renditionnumber': '30464',
#      'width': 1024}],
#    'labeltext': 'For most of the 1870s, Monet lived in Argenteuil, a town on the Seine only seventeen miles from Paris and accessible to the city by train. He often worked outdoors in his own boat and painted this basin several times, though the lower vantage point of this scene suggests a perspective from the shoreline. Eliminating the factory smokestacks that were in fact visible at this location, Monet instead highlights the area’s picturesque and recreational aspects, including the boat rental area on the left.\r\nImpressionist painters like Monet deliberately eschewed the finished structure and line of academic painting, but the irresolution of this painting has led to its occasional categorization as a “study.” As revealed in x-radiographs, the artist reworked the composition in several areas, removing a sixth paddling duck on the left, for example, by painting over it. The band of lavender brushstrokes along the horizon line is the site of a similar revision.',
#    'lastupdate': '2019-11-06T06:16:04-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Oil on canvas',
#    'objectid': 228650,
#    'objectnumber': '1951.54',
#    'people': [{'alphasort': 'Monet, Claude',
#      'birthplace': 'Paris, France',
#      'culture': 'French',
#      'deathplace': 'Giverny, France',
#      'displaydate': '1840 - 1926',
#      'displayname': 'Claude Monet',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Claude Monet',
#      'personid': 27651,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC231457_dynmc',
#    'provenance': '?J. B. Faure, Paris, 1876. [Durand-Ruel, New York], sold; James F. Sutton, (1893 - 1917) sold; ([his sale, through Durand-Ruel, 1917, no. 137]. Émile Laffon, Paris, sold; [through his sale]; to Paul Rosenberg, New York, sold; to Maurice Wertheim, (1943-1951), bequest; to Fogg Art Museum, 1951.\r\n',
#    'publicationcount': 35,
#    'rank': 79815,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/228650',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': 'l.l. Claude Monet 75',
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Red Boats, Argenteuil',
#    'titlescount': 3,
#    'totalpageviews': 11909,
#    'totaluniquepageviews': 9597,
#    'url': 'https://www.harvardartmuseums.org/collections/object/228650',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]},
#   {'accessionmethod': 'Gift',
#    'accessionyear': 2002,
#    'accesslevel': 1,
#    'century': '16th century',
#    'classification': 'Manuscripts',
#    'classificationid': 185,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_asianmediterranean@harvard.edu',
#    'contextualtextcount': 1,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, The Norma Jean Calderwood Collection of Islamic Art',
#    'culture': 'Persian',
#    'datebegin': 1562,
#    'dated': '1562',
#    'dateend': 1562,
#    'dateoffirstpageview': '2009-11-08',
#    'dateoflastpageview': '2019-11-05',
#    'department': 'Department of Islamic & Later Indian Art',
#    'description': 'Gayumars was the legendary first king of Iran, associated with the beginning of civilization and an organized social order. He and his people lived in the mountains and wore clothes made of leopard skins. The court was prosperous and his subjects content: animals and humans alike obeyed the king, who was blessed with divine power (farr). Gayumars had a son, Siyamak, whom he adored and who was loved by all save a jealous creature called Ahriman.\r\nThe large and densely detailed illustration shows the king, seated on a tiger skin, attended by his court; like him, they are dressed in leopard pelts. Siyamak sits to the left of Gayumars, and the two are encircled by courtiers and animals. The rocks of their mountain home have human faces, as does a sun that shines from behind a crag in the upper left corner. Near the sun, a demonic figure peers at a bear hurling a rock. Such playful vignettes are characteristic of Persianate painting of the time and can also be found in the illustrations of the Shahnama made for the Safavid ruler Shah Tahmasp. The red demon may represent Ahriman, the enemy of humankind.\r\n\r\n',
#    'dimensions': '37.2 x 23.4 cm (14 5/8 x 9 3/16 in.)',
#    'division': 'Asian and Mediterranean Art',
#    'edition': None,
#    'exhibitioncount': 2,
#    'groupcount': 0,
#    'id': 146520,
#    'imagecount': 2,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:62173_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 17804776,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17804776',
#      'imageid': 54487,
#      'publiccaption': 'recto',
#      'renditionnumber': '62173',
#      'width': 654},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:62174_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 17804777,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17804777',
#      'imageid': 18834,
#      'publiccaption': 'verso',
#      'renditionnumber': '62174',
#      'width': 660}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:13:20-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Ink, opaque watercolor and gold on paper',
#    'objectid': 146520,
#    'objectnumber': '2002.50.150',
#    'peoplecount': 0,
#    'period': 'Safavid period',
#    'periodid': 2363,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:62173_dynmc',
#    'provenance': '[Christies, London, 17 October 1995, lot no. 79]. [Mansour Gallery, London, before 1998], sold; to Stanford and Norma Jean Calderwood, Belmont, MA (by 1998-2002), gift; to Harvard Art Museums, 2002.',
#    'publicationcount': 1,
#    'rank': 121684,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/146520',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Court of Gayumars (painting, recto; text, verso), folio from a manuscript of the Shahnama by Firdawsi',
#    'titlescount': 2,
#    'totalpageviews': 10624,
#    'totaluniquepageviews': 9319,
#    'url': 'https://www.harvardartmuseums.org/collections/object/146520',
#    'verificationlevel': 3,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'worktypes': [{'worktype': 'manuscript folio', 'worktypeid': '210'}]},
#   {'accessionmethod': 'Gift',
#    'accessionyear': 1956,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Sculpture',
#    'classificationid': 30,
#    'colorcount': 9,
#    'colors': [{'color': '#c8c8c8',
#      'css3': '#c0c0c0',
#      'hue': 'Grey',
#      'percent': 0.45595238095238,
#      'spectrum': '#8c5fa8'},
#     {'color': '#afafaf',
#      'css3': '#a9a9a9',
#      'hue': 'Grey',
#      'percent': 0.19452380952381,
#      'spectrum': '#8c5fa8'},
#     {'color': '#e1e1e1',
#      'css3': '#dcdcdc',
#      'hue': 'Grey',
#      'percent': 0.14875,
#      'spectrum': '#955ba5'},
#     {'color': '#323232',
#      'css3': '#2f4f4f',
#      'hue': 'Grey',
#      'percent': 0.071071428571429,
#      'spectrum': '#2eb45d'},
#     {'color': '#4b4b4b',
#      'css3': '#2f4f4f',
#      'hue': 'Grey',
#      'percent': 0.041547619047619,
#      'spectrum': '#3db657'},
#     {'color': '#969696',
#      'css3': '#a9a9a9',
#      'hue': 'Grey',
#      'percent': 0.036190476190476,
#      'spectrum': '#8761aa'},
#     {'color': '#7d7d7d',
#      'css3': '#808080',
#      'hue': 'Grey',
#      'percent': 0.022321428571429,
#      'spectrum': '#8362aa'},
#     {'color': '#646464',
#      'css3': '#696969',
#      'hue': 'Grey',
#      'percent': 0.01672619047619,
#      'spectrum': '#7866ad'},
#     {'color': '#191919',
#      'css3': '#000000',
#      'hue': 'Grey',
#      'percent': 0.012916666666667,
#      'spectrum': '#1eb264'}],
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': '© Artists Rights Society (ARS), New York / VG Bild-Kunst, Bonn',
#    'creditline': 'Harvard Art Museums/Busch-Reisinger Museum, Gift of Sibyl Moholy-Nagy',
#    'culture': 'German',
#    'datebegin': 1930,
#    'dated': '1930',
#    'dateend': 1930,
#    'dateoffirstpageview': '2009-06-10',
#    'dateoflastpageview': '2019-11-05',
#    'department': 'Busch-Reisinger Museum',
#    'description': None,
#    'dimensions': '151.1 × 69.9 × 69.9 cm (59 1/2 × 27 1/2 × 27 1/2 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 5,
#    'groupcount': 1,
#    'id': 299819,
#    'imagecount': 14,
#    'imagepermissionlevel': 1,
#    'images': [],
#    'labeltext': 'One of the earliest electrically powered kinetic sculptures, Light Prop for an Electric Stage holds a central place in the history of modern sculpture. Representing the culmination of Moholy-Nagy’s experimentation at the Bauhaus, it incorporates his interest in technology, new materials, and, above all, light. Moholy sought to revolutionize human perception and thereby enable society to better apprehend the modern technological world. He presented Light Prop at a 1930 exhibition of German design as a mechanism for generating “special lighting and motion effects” on a stage. The rotating construction produces a startling array of visual effects when its moving and reflective surfaces interact with the beam of light. The sculpture became the subject of numerous photographs as well as Moholy’s abstract film Lightplay: Black, White, Gray (1930). Over the years the artist and later the museums made alterations to the sculpture to keep it in working order. It is still operational today.',
#    'lastupdate': '2019-11-06T06:18:22-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Aluminum, steel, nickel-plated brass, other metals, plastic, wood and electric motor',
#    'objectid': 299819,
#    'objectnumber': 'BR56.5',
#    'people': [{'alphasort': 'Moholy-Nagy, László',
#      'birthplace': 'Bacsborsod, Hungary',
#      'culture': 'American',
#      'deathplace': 'Chicago, Ill., USA',
#      'displaydate': '1895 - 1946',
#      'displayname': 'László Moholy-Nagy',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'László Moholy-Nagy',
#      'personid': 27634,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': None,
#    'provenance': 'Sibyl Moholy-Nagy, gift; to Busch-Reisinger Museum, 1956.',
#    'publicationcount': 18,
#    'rank': 151195,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/299819',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': 'Bauhaus',
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Light Prop for an Electric Stage (Light-Space Modulator)',
#    'titlescount': 2,
#    'totalpageviews': 8781,
#    'totaluniquepageviews': 7311,
#    'url': 'https://www.harvardartmuseums.org/collections/object/299819',
#    'verificationlevel': 3,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'videos': [{'description': 'László Moholy-Nagy’s Light Prop for an Electric Stage (Light-Space Modulator), 1930',
#      'primaryurl': 'https://vimeo.com/111474831',
#      'videoid': 445926},
#     {'description': '“Lightplay: Black-White-Gray” by László Moholy-Nagy',
#      'primaryurl': 'https://vimeo.com/111650264',
#      'videoid': 445927}],
#    'worktypes': [{'worktype': 'sculpture', 'worktypeid': '317'}]},
#   {'accessionmethod': 'Purchase',
#    'accessionyear': 1941,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Paintings',
#    'classificationid': 26,
#    'colorcount': 10,
#    'colors': [{'color': '#191919',
#      'css3': '#000000',
#      'hue': 'Grey',
#      'percent': 0.51584158415842,
#      'spectrum': '#1eb264'},
#     {'color': '#afafaf',
#      'css3': '#a9a9a9',
#      'hue': 'Grey',
#      'percent': 0.12686468646865,
#      'spectrum': '#8c5fa8'},
#     {'color': '#323232',
#      'css3': '#2f4f4f',
#      'hue': 'Grey',
#      'percent': 0.096567656765677,
#      'spectrum': '#2eb45d'},
#     {'color': '#969696',
#      'css3': '#a9a9a9',
#      'hue': 'Grey',
#      'percent': 0.065808580858086,
#      'spectrum': '#8761aa'},
#     {'color': '#c8c8c8',
#      'css3': '#c0c0c0',
#      'hue': 'Grey',
#      'percent': 0.054455445544554,
#      'spectrum': '#8c5fa8'},
#     {'color': '#7d4b32',
#      'css3': '#8b4513',
#      'hue': 'Brown',
#      'percent': 0.030891089108911,
#      'spectrum': '#c25687'},
#     {'color': '#7d7d7d',
#      'css3': '#808080',
#      'hue': 'Grey',
#      'percent': 0.026204620462046,
#      'spectrum': '#8362aa'},
#     {'color': '#966432',
#      'css3': '#a0522d',
#      'hue': 'Orange',
#      'percent': 0.022112211221122,
#      'spectrum': '#e46867'},
#     {'color': '#4b4b4b',
#      'css3': '#2f4f4f',
#      'hue': 'Grey',
#      'percent': 0.016303630363036,
#      'spectrum': '#3db657'},
#     {'color': '#646464',
#      'css3': '#696969',
#      'hue': 'Grey',
#      'percent': 0.015907590759076,
#      'spectrum': '#7866ad'}],
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': '© Artists Rights Society (ARS), New York / VG Bild-Kunst, Bonn',
#    'creditline': 'Harvard Art Museums/Busch-Reisinger Museum, Association Fund',
#    'culture': 'German',
#    'datebegin': 1927,
#    'dated': '1927',
#    'dateend': 1927,
#    'dateoffirstpageview': '2009-05-12',
#    'dateoflastpageview': '2019-11-05',
#    'department': 'Busch-Reisinger Museum',
#    'description': None,
#    'dimensions': '139.5 x 95.5 cm (54 15/16 x 37 5/8 in.)\r\nframed: 151.4 x 105.7 x 4.4 cm (59 5/8 x 41 5/8 x 1 3/4 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 12,
#    'groupcount': 2,
#    'id': 304344,
#    'imagecount': 4,
#    'imagepermissionlevel': 1,
#    'images': [],
#    'labeltext': 'Beckmann debuted this now iconic self-portrait at the fifty-third exhibition of the Berlin Secession in 1928. For critics of the day, it upstaged the work of his contemporaries, like Otto Dix and Max Pechstein. “The effect is brutal,” wrote one reviewer, “but the work is surely in the spirit of the most recent art.” The perceived brutality referred less to the rawness of the subject’s direct gaze than to formal aspects of the painting’s execution: the thick application of pigment and the large planes of color, notably black. Half cast into deep shadow by an unseen light source, Beckmann’s face at close range resembles a mask. Known to frequent elite conservative circles, the artist easily dons the elegant attire and “mask” of the bourgeoisie, then launches his critique from within its own ranks. Despite his avowed distance from politics, over the next decade Beckmann increasingly used figurative allegories to comment on present-day circumstances.',
#    'lastupdate': '2019-11-06T06:18:33-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Oil on canvas',
#    'objectid': 304344,
#    'objectnumber': 'BR41.37',
#    'people': [{'alphasort': 'Beckmann, Max',
#      'birthplace': 'Leipzig, Germany',
#      'culture': 'German',
#      'deathplace': 'New York, N.Y., USA',
#      'displaydate': '1884 - 1950',
#      'displayname': 'Max Beckmann',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Max Beckmann',
#      'personid': 27201,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': None,
#    'provenance': 'Julius Meier-Graefe, sold; to National Gallery, Berlin, 1928, removed from the collection by the National Socialist (Nazi) authorities, July, 1937; [Buchholz Gallery, Berlin]; [Buchholz Gallery, New York], sold; to Busch-Reisinger Museum, 1941.\r\n\r\n\r\n\r\n',
#    'publicationcount': 35,
#    'rank': 462,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/304344',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': 'l.r., Beckmann F. 27',
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Self-Portrait in Tuxedo',
#    'titlescount': 2,
#    'totalpageviews': 8770,
#    'totaluniquepageviews': 6708,
#    'url': 'https://www.harvardartmuseums.org/collections/object/304344',
#    'verificationlevel': 3,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]}]}

# %% [markdown]
# ### Looking at the results
#
# Often, you'll want to look at some specific aspect of the data you're getting. Since the API returns everything, you'll have to format the output in some friendly, readable format.
#
# We're being pretty low-level with the text formatting here, and one important key to understanding this bit is that "\t" means "tab", so that you can insert that character, which normally does something else.
#
# Feel free to play around with this cell to format it more to your liking. The string `format()` method allows you to interpolate variables or expressions into a string. You use curly braces (`{}`) in the string where you'd like to substitute variables; you can also use named arguments (`"Test {foo}".format(foo="bar")` prints "Test bar"). In this next cell, we'll iterate through the results and print them out in a nicer format.

# %%
records = R.json()['records']
print("views\tartwork")
print()
for record in records:
    print(record['totalpageviews'] + "\t" + record['title'])
    print(f"{record['totalpageviews']}\t{record['title']}")
    # `.format` puts its arguments sequentially in the string calling it wherever there are {} pairs
    # It does a lot more than that, with more advanced documentation here: 
    # https://docs.python.org/3.4/library/string.html#id1
# Out:
# views	artwork
#
# 30662	Self-Portrait Dedicated to Paul Gauguin
# 22823	The Gare Saint-Lazare: Arrival of a Train
# 16562	Bahram Gur Fights the Horned Wolf (painting, verso; text, recto), illustrated folio from a manuscript of the Great Ilkhanid Shahnama (Book of Kings)
# 14965	Odalisque, Slave, and Eunuch
# 13478	Jeanne-Antoinette Poisson, Marquise de Pompadour
# 13061	A Mother and Child and Four Studies of Her Right Hand, 1904; verso:  Self-Portrait Standing, 1903
# 11909	Red Boats, Argenteuil
# 10624	Court of Gayumars (painting, recto; text, verso), folio from a manuscript of the Shahnama by Firdawsi
# 8781	Light Prop for an Electric Stage (Light-Space Modulator)
# 8770	Self-Portrait in Tuxedo

# %% [markdown]
# The top result from this query is a Van Gogh painted titled "Self-Portrait Dedicated to Paul Gauguin." You can grab just the first object by accessing the records list (which is indexed from 0):

# %%
topResult = R.json()['records'][0]
topResult
# Out:
# {'accessionmethod': 'Bequest',
#  'accessionyear': 1951,
#  'accesslevel': 1,
#  'century': '19th century',
#  'classification': 'Paintings',
#  'classificationid': 26,
#  'colorcount': 10,
#  'colors': [{'color': '#64af7d',
#    'css3': '#5f9ea0',
#    'hue': 'Green',
#    'percent': 0.2979781420765,
#    'spectrum': '#4fb94f'},
#   {'color': '#64c896',
#    'css3': '#66cdaa',
#    'hue': 'Green',
#    'percent': 0.21289617486339,
#    'spectrum': '#47b853'},
#   {'color': '#323219',
#    'css3': '#2f4f4f',
#    'hue': 'Brown',
#    'percent': 0.19814207650273,
#    'spectrum': '#3db657'},
#   {'color': '#7d7d4b',
#    'css3': '#696969',
#    'hue': 'Green',
#    'percent': 0.056775956284153,
#    'spectrum': '#6cbd45'},
#   {'color': '#969664',
#    'css3': '#808080',
#    'hue': 'Green',
#    'percent': 0.043715846994536,
#    'spectrum': '#84c441'},
#   {'color': '#afaf7d',
#    'css3': '#bdb76b',
#    'hue': 'Green',
#    'percent': 0.042622950819672,
#    'spectrum': '#9ecb3b'},
#   {'color': '#4b9664',
#    'css3': '#2e8b57',
#    'hue': 'Green',
#    'percent': 0.036885245901639,
#    'spectrum': '#3db657'},
#   {'color': '#191919',
#    'css3': '#000000',
#    'hue': 'Grey',
#    'percent': 0.034972677595628,
#    'spectrum': '#1eb264'},
#   {'color': '#644b19',
#    'css3': '#8b4513',
#    'hue': 'Orange',
#    'percent': 0.032295081967213,
#    'spectrum': '#64bc46'},
#   {'color': '#647d64',
#    'css3': '#696969',
#    'hue': 'Green',
#    'percent': 0.018032786885246,
#    'spectrum': '#4fb94f'}],
#  'commentary': None,
#  'contact': 'am_europeanamerican@harvard.edu',
#  'contextualtextcount': 0,
#  'copyright': None,
#  'creditline': 'Harvard Art Museums/Fogg Museum, Bequest from the Collection of Maurice Wertheim, Class of 1906',
#  'culture': 'Dutch',
#  'datebegin': 1888,
#  'dated': '1888',
#  'dateend': 1888,
#  'dateoffirstpageview': '2009-05-12',
#  'dateoflastpageview': '2019-11-05',
#  'department': 'Department of Paintings, Sculpture & Decorative Arts',
#  'description': None,
#  'dimensions': '61.5 x 50.3 cm (24 3/16 x 19 13/16 in.)\r\nframed: 90.4 x 79.7 x 8.3 cm (35 9/16 x 31 3/8 x 3 1/4 in.)',
#  'division': 'European and American Art',
#  'edition': None,
#  'exhibitioncount': 26,
#  'groupcount': 3,
#  'id': 299843,
#  'imagecount': 6,
#  'imagepermissionlevel': 0,
#  'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC251942_dynmc',
#    'copyright': 'President and Fellows of Harvard College',
#    'displayorder': 1,
#    'format': 'image/jpeg',
#    'height': 2550,
#    'idsid': 47174896,
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/47174896',
#    'imageid': 429030,
#    'publiccaption': None,
#    'renditionnumber': 'DDC251942',
#    'width': 2087},
#   {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC000072_dynmc',
#    'copyright': 'President and Fellows of Harvard College',
#    'displayorder': 2,
#    'format': 'image/jpeg',
#    'height': 2550,
#    'idsid': 18737483,
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18737483',
#    'imageid': 185978,
#    'publiccaption': None,
#    'renditionnumber': 'DDC000072',
#    'width': 2088},
#   {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC251934_dynmc',
#    'copyright': 'President and Fellows of Harvard College',
#    'displayorder': 3,
#    'format': 'image/jpeg',
#    'height': 2550,
#    'idsid': 47174892,
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/47174892',
#    'imageid': 429028,
#    'publiccaption': None,
#    'renditionnumber': 'DDC251934',
#    'width': 2259},
#   {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:30033_dynmc',
#    'copyright': 'President and Fellows of Harvard College',
#    'displayorder': 4,
#    'format': 'image/jpeg',
#    'height': 1024,
#    'idsid': 43182083,
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43182083',
#    'imageid': 25781,
#    'publiccaption': None,
#    'renditionnumber': '30033',
#    'width': 844},
#   {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:50493_dynmc',
#    'copyright': 'President and Fellows of Harvard College',
#    'displayorder': 5,
#    'format': 'image/jpeg',
#    'height': 2550,
#    'idsid': 43183405,
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43183405',
#    'imageid': 19801,
#    'publiccaption': None,
#    'renditionnumber': '50493',
#    'width': 2082},
#   {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:50849_dynmc',
#    'copyright': 'President and Fellows of Harvard College',
#    'displayorder': 6,
#    'format': 'image/jpeg',
#    'height': 2550,
#    'idsid': 43183422,
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43183422',
#    'imageid': 42292,
#    'publiccaption': None,
#    'renditionnumber': '50849',
#    'width': 2093}],
#  'labeltext': 'In early 1888, Van Gogh moved to Arles in the south of France, where he hoped to establish an art colony. Believing that painting could be reinvented through the genre of portraiture, he encouraged his fellow artists to paint themselves, and then to exchange the canvases. After receiving self-portraits from Emile Bernard and Gauguin, who were working together in Brittany at the time, Van Gogh inscribed this painting “To my friend Paul Gauguin,” and sent it to him. He described the process of creating his arresting likeness in several letters to his brother Theo, an art dealer in Paris, explaining how he manipulated his features in response to Japanese prints, changed the contours of his jacket for coloristic effect, and painted the background “pale veronese green” without any shadows. Shortly after he sent the work to Gauguin, however, their friendship deteriorated, and Gauguin sold it for three hundred francs.',
#  'lastupdate': '2019-11-06T06:18:22-0500',
#  'markscount': 22,
#  'mediacount': 0,
#  'medium': 'Oil on canvas',
#  'objectid': 299843,
#  'objectnumber': '1951.65',
#  'people': [{'alphasort': 'Gogh, Vincent van',
#    'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#    'culture': 'Dutch',
#    'deathplace': 'Auvers-sur-Oise, France',
#    'displaydate': '1853 - 1890',
#    'displayname': 'Vincent van Gogh',
#    'displayorder': 1,
#    'gender': 'male',
#    'name': 'Vincent van Gogh',
#    'personid': 22730,
#    'prefix': None,
#    'role': 'Artist'}],
#  'peoplecount': 1,
#  'period': None,
#  'periodid': None,
#  'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC251942_dynmc',
#  'provenance': 'Vincent van Gogh, Arles, (1888,) gift;  to Paul Gauguin, (1888-1897) sold. [Ambroise Vollard, Paris.] [Paul Cassirer Gallery, Berlin.] Dr. Hugo von Tschudi, Berlin, (1906-1911), by descent; to his widow, Angela von Tschudi, Munich (1911-1919),  to Neue Staatsgalerie, Munich (1919-1938); removed from the collection by the National Socialist (Nazi) authorities in 1938, consigned; to [Theodor Fischer Gallery, Lucerne, Switzerland, for sale June 30, 1939, lot 45]; to Maurice Wertheim (1939-1951) bequest; to Fogg Art Museum, 1951.\r\n\r\n \r\n\r\nNotes:\r\nGauguin sold the painting for Fr 300\r\nHugo von Tschudi bought the painting for the Nationalgalerie, Berlin, with funds from sponsors, but did not submit it to the Kaiser for pre-approval. He took the painting to Munich when he assumed a post there.\r\nAccording to Stephanie Barron, the van Gogh was removed from the Neue Staatsgalerie on March 27, 1938 and stored at Schloss Niederschönhausen in August of that year. (Barron, 1991, pp. 135-146)\r\n',
#  'publicationcount': 206,
#  'rank': 466,
#  'relatedcount': 2,
#  'seeAlso': [{'format': 'application/json',
#    'id': 'https://iiif.harvardartmuseums.org/manifests/object/299843',
#    'profile': 'http://iiif.io/api/presentation/2/context.json',
#    'type': 'IIIF Manifest'}],
#  'signed': 'red paint, l.r.: Vincent/Arles',
#  'standardreferencenumber': None,
#  'state': None,
#  'style': None,
#  'technique': None,
#  'techniqueid': None,
#  'title': 'Self-Portrait Dedicated to Paul Gauguin',
#  'titlescount': 1,
#  'totalpageviews': 30662,
#  'totaluniquepageviews': 24589,
#  'url': 'https://www.harvardartmuseums.org/collections/object/299843',
#  'verificationlevel': 4,
#  'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#  'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]}

# %% [markdown]
# You can easily access properties from the image record:

# %%
topResult['verificationlevel']
# Out:
# 4

# %% [markdown]
# ### Exercise
# - Try using the `person` endpoint to search for information about Van Gogh. Get his `id` number.
# - Try displaying all HAM works by Van Gogh using that `id`. Filter your results to only include records with an image associated.

# %%
url
# Out:
# 'https://api.harvardartmuseums.org/object'

# %%
url = "https://api.harvardartmuseums.org/person"
parameters = {
    "apikey":APIKEY,
    "q":"displayname:'van AND Gogh' AND gender:male"
} # Add your own query parameters here
R = requests.get(url,params=parameters)
R.json()['records'][0]['id']
# Out:
# 22730

# %%
url = "https://api.harvardartmuseums.org/object"
parameters = {
    "apikey":APIKEY,
    "person":"22730",
    'size':100
} # Add your own query parameters here
R = requests.get(url,params=parameters)
R.json()
# Out:
# {'info': {'page': 1,
#   'pages': 1,
#   'totalrecords': 24,
#   'totalrecordsperquery': 100},
#  'records': [{'accessionmethod': 'Bequest',
#    'accessionyear': 1934,
#    'accesslevel': 1,
#    'century': '19th century',
#    'classification': 'Paintings',
#    'classificationid': 26,
#    'colorcount': 8,
#    'colors': [{'color': '#967d64',
#      'css3': '#808080',
#      'hue': 'Brown',
#      'percent': 0.33080459770115,
#      'spectrum': '#b65590'},
#     {'color': '#7d644b',
#      'css3': '#696969',
#      'hue': 'Yellow',
#      'percent': 0.1932183908046,
#      'spectrum': '#b25593'},
#     {'color': '#4b4b32',
#      'css3': '#556b2f',
#      'hue': 'Green',
#      'percent': 0.15729885057471,
#      'spectrum': '#4ab851'},
#     {'color': '#644b4b',
#      'css3': '#696969',
#      'hue': 'Brown',
#      'percent': 0.14574712643678,
#      'spectrum': '#8362aa'},
#     {'color': '#af9664',
#      'css3': '#bdb76b',
#      'hue': 'Yellow',
#      'percent': 0.085574712643678,
#      'spectrum': '#e9715f'},
#     {'color': '#c8af7d',
#      'css3': '#d2b48c',
#      'hue': 'Brown',
#      'percent': 0.049770114942529,
#      'spectrum': '#e9715f'},
#     {'color': '#c8c896',
#      'css3': '#d2b48c',
#      'hue': 'Green',
#      'percent': 0.020747126436782,
#      'spectrum': '#a9cf38'},
#     {'color': '#321919',
#      'css3': '#000000',
#      'hue': 'Brown',
#      'percent': 0.01683908045977,
#      'spectrum': '#3db657'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest of Annie Swan Coburn',
#    'culture': 'Dutch',
#    'datebegin': 1889,
#    'dated': '1889',
#    'dateend': 1889,
#    'dateoffirstpageview': '2009-05-25',
#    'dateoflastpageview': '2019-11-05',
#    'department': 'Department of Paintings, Sculpture & Decorative Arts',
#    'description': '\r\n',
#    'dimensions': '43.18 x 33.34 cm (17 x 13 1/8 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 6,
#    'groupcount': 0,
#    'id': 230942,
#    'imagecount': 3,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:53534_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 17388673,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17388673',
#      'imageid': 53131,
#      'publiccaption': None,
#      'renditionnumber': '53534',
#      'width': 793},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS245063',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 425332529,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/425332529',
#      'imageid': 467852,
#      'publiccaption': None,
#      'renditionnumber': '245063',
#      'width': 1958},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV184941_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 20490390,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20490390',
#      'imageid': 300401,
#      'publiccaption': None,
#      'renditionnumber': 'INV184941',
#      'width': 889}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:16:10-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Oil on canvas',
#    'objectid': 230942,
#    'objectnumber': '1934.35',
#    'people': [{'alphasort': 'Unidentified Artist',
#      'birthplace': None,
#      'culture': None,
#      'deathplace': None,
#      'displaydate': None,
#      'displayname': 'Unidentified Artist',
#      'displayorder': 1,
#      'gender': 'unknown',
#      'name': 'Unidentified Artist',
#      'personid': 34147,
#      'prefix': None,
#      'role': 'Artist'},
#     {'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Imitator of Vincent van Gogh',
#      'displayorder': 2,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': 'Imitator of',
#      'role': 'Alternative attribution'},
#     {'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Previously attributed to Vincent van Gogh',
#      'displayorder': 3,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': 'Previously attributed to',
#      'role': 'Previous attribution'}],
#    'peoplecount': 3,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:53534_dynmc',
#    'provenance': 'Otto Wacker Art Gallery, Berlin, Sold to private collector in Switzerland.\r\nPrivate Collector, Switzerland, Purchase from Otto Wacker gallery, Sold to Wildenstein, NY.\r\nAnnie Swan Coburn, Chicago, Purchase from Wildenstein Galleries, NY, Bequest to Fogg Art Museum, 1934.\r\n',
#    'publicationcount': 13,
#    'rank': 59195,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/230942',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': '\r\n',
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Self-portrait with a Bandaged Ear and Pipe',
#    'titlescount': 2,
#    'totalpageviews': 1587,
#    'totaluniquepageviews': 1244,
#    'url': 'https://www.harvardartmuseums.org/collections/object/230942',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]},
#   {'accessionmethod': 'Bequest',
#    'accessionyear': 1943,
#    'accesslevel': 1,
#    'century': '19th century',
#    'classification': 'Drawings',
#    'classificationid': 21,
#    'colorcount': 9,
#    'colors': [{'color': '#c8c8af',
#      'css3': '#c0c0c0',
#      'hue': 'Green',
#      'percent': 0.26997101449275,
#      'spectrum': '#b55592'},
#     {'color': '#e1e1c8',
#      'css3': '#dcdcdc',
#      'hue': 'Green',
#      'percent': 0.21953623188406,
#      'spectrum': '#e9715f'},
#     {'color': '#afaf96',
#      'css3': '#a9a9a9',
#      'hue': 'Green',
#      'percent': 0.19426086956522,
#      'spectrum': '#8e5ea7'},
#     {'color': '#fae1e1',
#      'css3': '#ffe4e1',
#      'hue': 'Red',
#      'percent': 0.13669565217391,
#      'spectrum': '#e76d63'},
#     {'color': '#af967d',
#      'css3': '#bc8f8f',
#      'hue': 'Brown',
#      'percent': 0.085623188405797,
#      'spectrum': '#c25687'},
#     {'color': '#7d7d64',
#      'css3': '#808080',
#      'hue': 'Yellow',
#      'percent': 0.045159420289855,
#      'spectrum': '#6cbd45'},
#     {'color': '#64644b',
#      'css3': '#696969',
#      'hue': 'Green',
#      'percent': 0.034144927536232,
#      'spectrum': '#59ba4a'},
#     {'color': '#323232',
#      'css3': '#2f4f4f',
#      'hue': 'Grey',
#      'percent': 0.010260869565217,
#      'spectrum': '#2eb45d'},
#     {'color': '#4b4b32',
#      'css3': '#556b2f',
#      'hue': 'Green',
#      'percent': 0.0043478260869565,
#      'spectrum': '#4ab851'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest of Grenville L. Winthrop',
#    'culture': 'Dutch',
#    'datebegin': 1888,
#    'dated': '1888',
#    'dateend': 1888,
#    'dateoffirstpageview': '2009-05-16',
#    'dateoflastpageview': '2019-11-03',
#    'department': 'Department of Drawings',
#    'description': None,
#    'dimensions': '49.4 x 38 cm (19 7/16 x 14 15/16 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 6,
#    'groupcount': 2,
#    'id': 299938,
#    'imagecount': 1,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51273_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 17386572,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17386572',
#      'imageid': 16797,
#      'publiccaption': None,
#      'renditionnumber': '51273',
#      'width': 1969}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:18:23-0500',
#    'markscount': 2,
#    'mediacount': 0,
#    'medium': 'Brown ink over graphite on white wove paper',
#    'objectid': 299938,
#    'objectnumber': '1943.515',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51273_dynmc',
#    'provenance': 'Mrs. J. van Gogh-Bonger, Amsterdam. Klas Fähraeus, Lindingö-Brevik, 1911. Thorsten Laurin, Stockholm. Grenville L. Winthrop, New York, New York (acquired in Paris through Martin Birnbaum), March 1931,bequest; to the Fogg Art Museum, 1943.',
#    'publicationcount': 54,
#    'rank': 182,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/299938',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': 'brown ink, l.l.: Vincent',
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Peasant of the Camargue',
#    'titlescount': 3,
#    'totalpageviews': 2171,
#    'totaluniquepageviews': 1679,
#    'url': 'https://www.harvardartmuseums.org/collections/object/299938',
#    'verificationlevel': 3,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'worktypes': [{'worktype': 'drawing', 'worktypeid': '125'}]},
#   {'accessionmethod': None,
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': None,
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_straus@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Straus Center for Conservation and Technical Studies, Alan Burroughs Collection of X-Radiographs',
#    'culture': None,
#    'datebegin': 0,
#    'dated': None,
#    'dateend': 0,
#    'dateoffirstpageview': '2017-08-03',
#    'dateoflastpageview': '2019-07-13',
#    'department': 'Straus Center for Conservation and Technical Studies',
#    'description': 'X-Radiograph Description: Negative\r\n\r\nBurroughs Number: 0126\r\n\r\nX-Radiograph(s) of: \r\nArtist: Gogh, Vincent van, Dutch, 1853-1890\r\nTitle: Old Shoes\r\nOwner: Through David Rosen\r\n',
#    'dimensions': None,
#    'division': None,
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 1,
#    'id': 343825,
#    'imagecount': 0,
#    'imagepermissionlevel': 0,
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:19:47-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 343825,
#    'objectnumber': 'Straus.4332',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Artist of original: Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': 'Artist of original:',
#      'role': 'Related name'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 263287,
#    'relatedcount': 0,
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'X-radiograph(s) of "Old Shoes"',
#    'titlescount': 1,
#    'totalpageviews': 7,
#    'totaluniquepageviews': 5,
#    'url': 'https://www.harvardartmuseums.org/collections/object/343825',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'photograph', 'worktypeid': '259'},
#     {'worktype': 'x-radiograph', 'worktypeid': '405'}]},
#   {'accessionmethod': None,
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': None,
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_straus@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Straus Center for Conservation and Technical Studies, Alan Burroughs Collection of X-Radiographs',
#    'culture': None,
#    'datebegin': 0,
#    'dated': None,
#    'dateend': 0,
#    'dateoffirstpageview': '2018-11-29',
#    'dateoflastpageview': '2019-10-15',
#    'department': 'Straus Center for Conservation and Technical Studies',
#    'description': 'X-Radiograph Description: X-Radiograph; Details : Head; Hands (little shows)\r\n\r\nBurroughs Number: 2519\r\n\r\nX-Radiograph(s) of: \r\nArtist: Gogh, Vincent van, Dutch, 1853-1890\r\nTitle: Madame Augustine Roulin Rocking a Cradle (La Berceuse)\r\nDate: 1889\r\nDescription: Oil on canvas; 92.7 x 72.7 cm (36 1/2 x 28 5/8 in.)\r\nOwner: Boston Museum of Fine Arts, MA (Spaulding Collection)\r\n',
#    'dimensions': 'film size: 14 x 17',
#    'division': None,
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 1,
#    'id': 346218,
#    'imagecount': 2,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR005429_dynmc',
#      'copyright': None,
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45761684,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45761684',
#      'imageid': 419540,
#      'publiccaption': None,
#      'renditionnumber': 'STR005429',
#      'width': 817},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR005430_dynmc',
#      'copyright': None,
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45761685,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45761685',
#      'imageid': 419541,
#      'publiccaption': None,
#      'renditionnumber': 'STR005430',
#      'width': 816}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:19:53-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 346218,
#    'objectnumber': 'Straus.6725',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Artist of original: Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': 'Artist of original:',
#      'role': 'Related name'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR005429_dynmc',
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 265678,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/346218',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'X-radiograph(s) of "Madame Augustine Roulin Rocking a Cradle (La Berceuse)"',
#    'titlescount': 1,
#    'totalpageviews': 5,
#    'totaluniquepageviews': 5,
#    'url': 'https://www.harvardartmuseums.org/collections/object/346218',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'photograph', 'worktypeid': '259'},
#     {'worktype': 'x-radiograph', 'worktypeid': '405'}]},
#   {'accessionmethod': None,
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': None,
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_straus@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Straus Center for Conservation and Technical Studies, Alan Burroughs Collection of X-Radiographs',
#    'culture': None,
#    'datebegin': 1956,
#    'dated': 'July 10, 1956',
#    'dateend': 1956,
#    'dateoffirstpageview': '2017-08-08',
#    'dateoflastpageview': '2019-10-26',
#    'department': 'Straus Center for Conservation and Technical Studies',
#    'description': 'X-Radiograph Description: X-Radiograph  (head and shoulders)\r\n\r\nX-Radiograph Settings: 15 kv, 7 ma, 75 sec.; 15 kv, 7 ma, 8 min.; ; \r\n\r\nBurroughs Number: 3666\r\n\r\nX-Radiograph(s) of: \r\nArtist: Gogh, Vincent van, Dutch, 1853-1890\r\nTitle: Self-Portrait for Gauguin\r\nDate: 1888\r\nOwner: Harvard University Art Museums (Wertheim Collection)\r\nObject Number: 1951.65',
#    'dimensions': 'film size: 35.6 x 43.2 cm (14 x 17 in.)',
#    'division': None,
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 1,
#    'id': 347268,
#    'imagecount': 9,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006958_dynmc',
#      'copyright': None,
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582871,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582871',
#      'imageid': 421069,
#      'publiccaption': None,
#      'renditionnumber': 'STR006958',
#      'width': 822},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006959_dynmc',
#      'copyright': None,
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582872,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582872',
#      'imageid': 421070,
#      'publiccaption': None,
#      'renditionnumber': 'STR006959',
#      'width': 844},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006964_dynmc',
#      'copyright': None,
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582877,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582877',
#      'imageid': 421075,
#      'publiccaption': None,
#      'renditionnumber': 'STR006964',
#      'width': 844},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006965_dynmc',
#      'copyright': None,
#      'displayorder': 4,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582878,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582878',
#      'imageid': 421076,
#      'publiccaption': None,
#      'renditionnumber': 'STR006965',
#      'width': 844},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006966_dynmc',
#      'copyright': None,
#      'displayorder': 5,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582879,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582879',
#      'imageid': 421077,
#      'publiccaption': None,
#      'renditionnumber': 'STR006966',
#      'width': 308},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006967_dynmc',
#      'copyright': None,
#      'displayorder': 6,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582880,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582880',
#      'imageid': 421078,
#      'publiccaption': None,
#      'renditionnumber': 'STR006967',
#      'width': 363},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006968_dynmc',
#      'copyright': None,
#      'displayorder': 7,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582881,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582881',
#      'imageid': 421079,
#      'publiccaption': None,
#      'renditionnumber': 'STR006968',
#      'width': 393},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006969_dynmc',
#      'copyright': None,
#      'displayorder': 8,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582882,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582882',
#      'imageid': 421080,
#      'publiccaption': None,
#      'renditionnumber': 'STR006969',
#      'width': 659},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006970_dynmc',
#      'copyright': None,
#      'displayorder': 9,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582883,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582883',
#      'imageid': 421081,
#      'publiccaption': None,
#      'renditionnumber': 'STR006970',
#      'width': 796}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:19:55-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 347268,
#    'objectnumber': 'Straus.7775',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Artist of original: Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': 'Artist of original:',
#      'role': 'Related name'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006958_dynmc',
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 266728,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/347268',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'X-radiograph(s) of "Self-Portrait for Gauguin"',
#    'titlescount': 1,
#    'totalpageviews': 91,
#    'totaluniquepageviews': 76,
#    'url': 'https://www.harvardartmuseums.org/collections/object/347268',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'x-radiograph', 'worktypeid': '405'},
#     {'worktype': 'photograph', 'worktypeid': '259'}]},
#   {'accessionmethod': None,
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': None,
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_straus@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Straus Center for Conservation and Technical Studies, Alan Burroughs Collection of X-Radiographs',
#    'culture': None,
#    'datebegin': 1980,
#    'dated': 'January 31, 1980',
#    'dateend': 1980,
#    'dateoffirstpageview': '2013-04-09',
#    'dateoflastpageview': '2019-11-05',
#    'department': 'Straus Center for Conservation and Technical Studies',
#    'description': 'X-Radiograph Description: X-Radiograph (4) 4 sheets cut and assembled manually. Scanned and on TMS/DRS  2/2009\r\n\r\nX-Radiograph Settings: 5 ma, 60 kv, 45 sec ; Baltospot\r\n\r\nBurroughs Number: 3666a\r\n\r\nX-Radiograph(s) of: \r\nArtist: Gogh, Vincent van, Dutch, 1853-1890\r\nTitle: Self-Portrait for Gauguin\r\nDate: 1888\r\nDescription: oil on canvas. \r\nOwner: Harvard University Art Museums (Wertheim Collection)\r\nObject Number: 1951.65',
#    'dimensions': None,
#    'division': None,
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 1,
#    'id': 347269,
#    'imagecount': 4,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006963_dynmc',
#      'copyright': None,
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582876,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582876',
#      'imageid': 421074,
#      'publiccaption': None,
#      'renditionnumber': 'STR006963',
#      'width': 844},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006960_dynmc',
#      'copyright': None,
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582873,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582873',
#      'imageid': 421071,
#      'publiccaption': None,
#      'renditionnumber': 'STR006960',
#      'width': 621},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006961_dynmc',
#      'copyright': None,
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582874,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582874',
#      'imageid': 421072,
#      'publiccaption': None,
#      'renditionnumber': 'STR006961',
#      'width': 966},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006962_dynmc',
#      'copyright': None,
#      'displayorder': 4,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582875,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582875',
#      'imageid': 421073,
#      'publiccaption': None,
#      'renditionnumber': 'STR006962',
#      'width': 512}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:19:55-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 347269,
#    'objectnumber': 'Straus.7776',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Artist of original: Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': 'Artist of original:',
#      'role': 'Related name'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006963_dynmc',
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 266729,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/347269',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'X-radiograph(s) of "Self-Portrait for Gauguin"',
#    'titlescount': 1,
#    'totalpageviews': 382,
#    'totaluniquepageviews': 328,
#    'url': 'https://www.harvardartmuseums.org/collections/object/347269',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'photograph', 'worktypeid': '259'},
#     {'worktype': 'x-radiograph', 'worktypeid': '405'}]},
#   {'accessionmethod': None,
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': None,
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_straus@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Straus Center for Conservation and Technical Studies, Alan Burroughs Collection of X-Radiographs',
#    'culture': None,
#    'datebegin': 0,
#    'dated': None,
#    'dateend': 0,
#    'dateoffirstpageview': '2019-03-16',
#    'dateoflastpageview': '2019-10-15',
#    'department': 'Straus Center for Conservation and Technical Studies',
#    'description': 'X-Radiograph Description: Negative, Print\r\n\r\nBurroughs Number: 0127\r\n\r\nX-Radiograph(s) of: \r\nArtist: Gogh, Vincent van, Dutch, 1853-1890\r\nTitle: Landscape\r\nOwner: Through David Rosen\r\n',
#    'dimensions': None,
#    'division': None,
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 1,
#    'id': 343827,
#    'imagecount': 0,
#    'imagepermissionlevel': 0,
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:19:47-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 343827,
#    'objectnumber': 'Straus.4334',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Artist of original: Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': 'Artist of original:',
#      'role': 'Related name'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 263289,
#    'relatedcount': 0,
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'X-radiograph(s) of "Landscape"',
#    'titlescount': 1,
#    'totalpageviews': 4,
#    'totaluniquepageviews': 4,
#    'url': 'https://www.harvardartmuseums.org/collections/object/343827',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'photograph', 'worktypeid': '259'},
#     {'worktype': 'x-radiograph', 'worktypeid': '405'}]},
#   {'accessionmethod': None,
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': None,
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_straus@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Straus Center for Conservation and Technical Studies, Alan Burroughs Collection of X-Radiographs',
#    'culture': None,
#    'datebegin': 0,
#    'dated': None,
#    'dateend': 0,
#    'dateoffirstpageview': '2019-04-06',
#    'dateoflastpageview': '2019-10-15',
#    'department': 'Straus Center for Conservation and Technical Studies',
#    'description': 'X-Radiograph Description: X-Radiograph; Detail : flowers\r\n\r\nBurroughs Number: 2520\r\n\r\nX-Radiograph(s) of: \r\nArtist: Gogh, Vincent van, Dutch, 1853-1890\r\nTitle: Still-Life\r\nDescription: Canvas\r\nOwner: Coburn Collection, Boston\r\n',
#    'dimensions': 'film size: 14 x 17',
#    'division': None,
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 1,
#    'id': 346219,
#    'imagecount': 1,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR005431_dynmc',
#      'copyright': None,
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45576218,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45576218',
#      'imageid': 419542,
#      'publiccaption': None,
#      'renditionnumber': 'STR005431',
#      'width': 844}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:19:53-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 346219,
#    'objectnumber': 'Straus.6726',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Artist of original: Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': 'Artist of original:',
#      'role': 'Related name'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR005431_dynmc',
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 265679,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/346219',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'X-radiograph(s) of "Still-Life"',
#    'titlescount': 1,
#    'totalpageviews': 4,
#    'totaluniquepageviews': 3,
#    'url': 'https://www.harvardartmuseums.org/collections/object/346219',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'photograph', 'worktypeid': '259'},
#     {'worktype': 'x-radiograph', 'worktypeid': '405'}]},
#   {'accessionmethod': None,
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': None,
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_straus@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Straus Center for Conservation and Technical Studies, Alan Burroughs Collection of X-Radiographs',
#    'culture': None,
#    'datebegin': 0,
#    'dated': None,
#    'dateend': 0,
#    'dateoffirstpageview': None,
#    'dateoflastpageview': None,
#    'department': 'Straus Center for Conservation and Technical Studies',
#    'description': 'X-Radiograph Description: X-Radiograph; Detail : hea\r\n\r\nBurroughs Number: 2521\r\n\r\nX-Radiograph(s) of: \r\nArtist: Gogh, Vincent van, Dutch, 1853-1890\r\nTitle: Self-Portrait (Copy? Compare La Faille, Pl XIII)\r\nDescription: Canvas\r\nOwner: Coburn Collection, Boston\r\n',
#    'dimensions': 'film size: 14 x 17',
#    'division': None,
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 1,
#    'id': 346220,
#    'imagecount': 0,
#    'imagepermissionlevel': 0,
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:19:53-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 346220,
#    'objectnumber': 'Straus.6727',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Artist of original: Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': 'Artist of original:',
#      'role': 'Related name'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 265680,
#    'relatedcount': 0,
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'X-radiograph(s) of "Self-Portrait (Copy? Compare La Faille, Pl XIII)"',
#    'titlescount': 1,
#    'totalpageviews': 0,
#    'totaluniquepageviews': 0,
#    'url': 'https://www.harvardartmuseums.org/collections/object/346220',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'photograph', 'worktypeid': '259'},
#     {'worktype': 'x-radiograph', 'worktypeid': '405'}]},
#   {'accessionmethod': None,
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': None,
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_straus@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Straus Center for Conservation and Technical Studies, Alan Burroughs Collection of X-Radiographs',
#    'culture': None,
#    'datebegin': 0,
#    'dated': None,
#    'dateend': 0,
#    'dateoffirstpageview': '2017-10-13',
#    'dateoflastpageview': '2019-10-15',
#    'department': 'Straus Center for Conservation and Technical Studies',
#    'description': 'X-Radiograph Description: X-Radiograph (2) Portion of picture covered: 100%; \r\n\r\nBurroughs Number: 3557\r\n\r\nX-Radiograph(s) of: \r\nArtist: Forgery\r\nArtist: After Gogh, Vincent van, Dutch, 1853-1890\r\nTitle: Self-Portrait with a Bandaged Ear and Pipe\r\nDescription: oil on canvas, high impasto\r\nOwner: Harvard University Art Museums\r\nObject Number: 1934.35',
#    'dimensions': 'film size: 35.6 x 43.2 cm (14 x 17 in.)',
#    'division': None,
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 1,
#    'id': 347170,
#    'imagecount': 3,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006768_dynmc',
#      'copyright': None,
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582689,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582689',
#      'imageid': 420879,
#      'publiccaption': None,
#      'renditionnumber': 'STR006768',
#      'width': 822},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006769_dynmc',
#      'copyright': None,
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582690,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582690',
#      'imageid': 420880,
#      'publiccaption': None,
#      'renditionnumber': 'STR006769',
#      'width': 844},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006770_dynmc',
#      'copyright': None,
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45582691,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45582691',
#      'imageid': 420881,
#      'publiccaption': None,
#      'renditionnumber': 'STR006770',
#      'width': 844}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:19:55-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 347170,
#    'objectnumber': 'Straus.7677',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Artist of original: After Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': 'Artist of original: After',
#      'role': 'Related name'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR006768_dynmc',
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 266630,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/347170',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'X-radiograph(s) of "Self-Portrait with a Bandaged Ear and Pipe"',
#    'titlescount': 1,
#    'totalpageviews': 15,
#    'totaluniquepageviews': 13,
#    'url': 'https://www.harvardartmuseums.org/collections/object/347170',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'photograph', 'worktypeid': '259'},
#     {'worktype': 'x-radiograph', 'worktypeid': '405'}]},
#   {'accessionmethod': None,
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': None,
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_straus@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Straus Center for Conservation and Technical Studies, Alan Burroughs Collection of X-Radiographs',
#    'culture': None,
#    'datebegin': 1981,
#    'dated': 'December 18, 1981',
#    'dateend': 1981,
#    'dateoffirstpageview': '2018-02-13',
#    'dateoflastpageview': '2019-10-24',
#    'department': 'Straus Center for Conservation and Technical Studies',
#    'description': 'X-Radiograph Description: X-Radiograph\r\n\r\nX-Radiograph Settings: 50 kv, 5 ma, 2 min.; 50 kv, 5 ma, 1 min.; 50 kv, 5 ma, 2 min.; 80 kv, 5 ma, 2 min. ; \r\n\r\nBurroughs Number: 4054\r\n\r\nX-Radiograph(s) of: \r\nArtist: Gogh, Vincent van (?), Dutch, 1853-1890\r\nTitle: "Woodcutter" with lead white layer\r\nOwner: Brandeis University, Waltham, MA\r\n',
#    'dimensions': None,
#    'division': None,
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 1,
#    'id': 347583,
#    'imagecount': 2,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR007967_dynmc',
#      'copyright': None,
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45599602,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45599602',
#      'imageid': 422078,
#      'publiccaption': None,
#      'renditionnumber': 'STR007967',
#      'width': 844},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR007968_dynmc',
#      'copyright': None,
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45599603,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45599603',
#      'imageid': 422079,
#      'publiccaption': None,
#      'renditionnumber': 'STR007968',
#      'width': 853}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:19:56-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 347583,
#    'objectnumber': 'Straus.8090',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Artist of original: (?) Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': 'Artist of original: (?)',
#      'role': 'Related name'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR007967_dynmc',
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 267043,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/347583',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'X-radiograph(s) of ""Woodcutter" with lead white layer"',
#    'titlescount': 1,
#    'totalpageviews': 4,
#    'totaluniquepageviews': 3,
#    'url': 'https://www.harvardartmuseums.org/collections/object/347583',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'x-radiograph', 'worktypeid': '405'},
#     {'worktype': 'photograph', 'worktypeid': '259'}]},
#   {'accessionmethod': None,
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': None,
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_straus@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Straus Center for Conservation and Technical Studies, Alan Burroughs Collection of X-Radiographs',
#    'culture': None,
#    'datebegin': 1997,
#    'dated': 'November 18, 1997',
#    'dateend': 1997,
#    'dateoffirstpageview': '2013-04-09',
#    'dateoflastpageview': '2019-10-26',
#    'department': 'Straus Center for Conservation and Technical Studies',
#    'description': 'X-Radiograph Description: X-Radiograph\r\n\r\nX-Radiograph Settings: 5 ma, 55 kv, 1 min., 58" from tube\r\n\r\nBurroughs Number: 4452\r\n\r\nX-Radiograph(s) of: \r\nArtist: Gogh, Vincent van, Dutch, 1853-1890\r\nTitle: Three Pairs of Shoes\r\nOwner: Harvard University Art Museums\r\nObject Number: 1951.66',
#    'dimensions': None,
#    'division': None,
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 1,
#    'id': 347773,
#    'imagecount': 4,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR009028_dynmc',
#      'copyright': None,
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45605045,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45605045',
#      'imageid': 423139,
#      'publiccaption': None,
#      'renditionnumber': 'STR009028',
#      'width': 844},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR009029_dynmc',
#      'copyright': None,
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45605046,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45605046',
#      'imageid': 423140,
#      'publiccaption': None,
#      'renditionnumber': 'STR009029',
#      'width': 844},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR009030_dynmc',
#      'copyright': None,
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45605047,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45605047',
#      'imageid': 423141,
#      'publiccaption': None,
#      'renditionnumber': 'STR009030',
#      'width': 844},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR009031_dynmc',
#      'copyright': None,
#      'displayorder': 4,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45605048,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45605048',
#      'imageid': 423142,
#      'publiccaption': None,
#      'renditionnumber': 'STR009031',
#      'width': 844}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:19:57-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 347773,
#    'objectnumber': 'Straus.8280',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Artist of original: Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': 'Artist of original:',
#      'role': 'Related name'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR009028_dynmc',
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 267233,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/347773',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'X-radiograph(s) of "Three Pairs of Shoes"',
#    'titlescount': 1,
#    'totalpageviews': 274,
#    'totaluniquepageviews': 215,
#    'url': 'https://www.harvardartmuseums.org/collections/object/347773',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'photograph', 'worktypeid': '259'},
#     {'worktype': 'x-radiograph', 'worktypeid': '405'}]},
#   {'accessionmethod': None,
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': None,
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_straus@harvard.edu',
# ...
#    'classificationid': 21,
#    'colorcount': 10,
#    'colors': [{'color': '#191919',
#      'css3': '#000000',
#      'hue': 'Grey',
#      'percent': 0.22722222222222,
#      'spectrum': '#1eb264'},
#     {'color': '#e1e1e1',
#      'css3': '#dcdcdc',
#      'hue': 'Grey',
#      'percent': 0.16622222222222,
#      'spectrum': '#955ba5'},
#     {'color': '#323232',
#      'css3': '#2f4f4f',
#      'hue': 'Grey',
#      'percent': 0.16372222222222,
#      'spectrum': '#2eb45d'},
#     {'color': '#64644b',
#      'css3': '#696969',
#      'hue': 'Green',
#      'percent': 0.0965,
#      'spectrum': '#59ba4a'},
#     {'color': '#000000',
#      'css3': '#000000',
#      'hue': 'Black',
#      'percent': 0.090777777777778,
#      'spectrum': '#1eb264'},
#     {'color': '#4b4b32',
#      'css3': '#556b2f',
#      'hue': 'Green',
#      'percent': 0.076,
#      'spectrum': '#4ab851'},
#     {'color': '#7d6464',
#      'css3': '#696969',
#      'hue': 'Brown',
#      'percent': 0.066833333333333,
#      'spectrum': '#8e5ea7'},
#     {'color': '#fafae1',
#      'css3': '#ffffe0',
#      'hue': 'Green',
#      'percent': 0.047888888888889,
#      'spectrum': '#ed765a'},
#     {'color': '#96967d',
#      'css3': '#808080',
#      'hue': 'Green',
#      'percent': 0.025888888888889,
#      'spectrum': '#8e5ea7'},
#     {'color': '#afaf96',
#      'css3': '#a9a9a9',
#      'hue': 'Green',
#      'percent': 0.021555555555556,
#      'spectrum': '#8e5ea7'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest of Meta and Paul J. Sachs',
#    'culture': 'Dutch',
#    'datebegin': 1882,
#    'dated': 'c. 1882-1883',
#    'dateend': 1883,
#    'dateoffirstpageview': '2009-05-12',
#    'dateoflastpageview': '2019-11-03',
#    'department': 'Department of Drawings',
#    'description': None,
#    'dimensions': '46 × 27.5 cm (18 1/8 × 10 13/16 in.)\r\nframed: 62.5 × 46.4 × 1.9 cm (24 5/8 × 18 1/4 × 3/4 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 2,
#    'groupcount': 0,
#    'id': 296533,
#    'imagecount': 4,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS45707_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 20681094,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20681094',
#      'imageid': 33066,
#      'publiccaption': None,
#      'renditionnumber': '45707',
#      'width': 1541},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS41918',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 424454638,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/424454638',
#      'imageid': 31099,
#      'publiccaption': None,
#      'renditionnumber': '41918',
#      'width': 1513},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR011332_dynmc',
#      'copyright': None,
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 1285,
#      'idsid': 45614944,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45614944',
#      'imageid': 425443,
#      'publiccaption': None,
#      'renditionnumber': 'STR011332',
#      'width': 2550},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS81350_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 4,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 20684768,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20684768',
#      'imageid': 37798,
#      'publiccaption': None,
#      'renditionnumber': '81350',
#      'width': 825}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:18:15-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Graphite, brown ink, black ink and wash, white gouache on heavily textured white wove paper',
#    'objectid': 296533,
#    'objectnumber': '1965.289',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS45707_dynmc',
#    'provenance': 'Richard Bühler. [Paul Rosenberg, Paris]. [Graphisches Kabinett, Munich], sold; to Meta and Paul J. Sachs, Cambridge, Massachusetts, 1928, bequest; to Fogg Art Museum, 1965',
#    'publicationcount': 5,
#    'rank': 85792,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/296533',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'The Wounded Veteran',
#    'titlescount': 1,
#    'totalpageviews': 705,
#    'totaluniquepageviews': 506,
#    'url': 'https://www.harvardartmuseums.org/collections/object/296533',
#    'verificationlevel': 3,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'worktypes': [{'worktype': 'drawing', 'worktypeid': '125'}]},
#   {'accessionmethod': None,
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': None,
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_straus@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Straus Center for Conservation and Technical Studies, Alan Burroughs Collection of X-Radiographs',
#    'culture': None,
#    'datebegin': 0,
#    'dated': None,
#    'dateend': 0,
#    'dateoffirstpageview': '2019-04-06',
#    'dateoflastpageview': '2019-10-15',
#    'department': 'Straus Center for Conservation and Technical Studies',
#    'description': 'X-Radiograph Description: X-radiograph; 2 details, X-rays in very poor condition\r\n\r\nBurroughs Number: 2516\r\n\r\nX-Radiograph(s) of: \r\nArtist: Gogh, Vincent van, Dutch, 1853-1890\r\nTitle: Ravine (another subject underneath)\r\nDate: 1889\r\nDescription: Oil on canvas ; 73 x 91.7 cm (28 3/4 x 36 1/8 in.)\r\nOwner: Boston Museum of Fine Arts, MA (McLeod collection)\r\nObject Number: 52.1524',
#    'dimensions': 'film size: 14 x 17',
#    'division': None,
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 1,
#    'id': 346215,
#    'imagecount': 2,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR005424_dynmc',
#      'copyright': None,
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45761679,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45761679',
#      'imageid': 419535,
#      'publiccaption': None,
#      'renditionnumber': 'STR005424',
#      'width': 817},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR005425_dynmc',
#      'copyright': None,
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45761680,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45761680',
#      'imageid': 419536,
#      'publiccaption': None,
#      'renditionnumber': 'STR005425',
#      'width': 815}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:19:53-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 346215,
#    'objectnumber': 'Straus.6722',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Artist of original: Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': 'Artist of original:',
#      'role': 'Related name'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR005424_dynmc',
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 265675,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/346215',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'X-radiograph(s) of "Ravine (another subject underneath)"',
#    'titlescount': 1,
#    'totalpageviews': 5,
#    'totaluniquepageviews': 4,
#    'url': 'https://www.harvardartmuseums.org/collections/object/346215',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'photograph', 'worktypeid': '259'},
#     {'worktype': 'x-radiograph', 'worktypeid': '405'}]},
#   {'accessionmethod': None,
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': None,
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_straus@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Straus Center for Conservation and Technical Studies, Alan Burroughs Collection of X-Radiographs',
#    'culture': None,
#    'datebegin': 0,
#    'dated': None,
#    'dateend': 0,
#    'dateoffirstpageview': '2019-04-06',
#    'dateoflastpageview': '2019-10-15',
#    'department': 'Straus Center for Conservation and Technical Studies',
#    'description': 'X-Radiograph Description: X-Radiograph; Details : head ans hands (little shows), X-rays in very poor condition\r\n\r\nBurroughs Number: 2517\r\n\r\nX-Radiograph(s) of: \r\nArtist: Gogh, Vincent van, Dutch, 1853-1890\r\nTitle: The Postman Roulin\r\nDate: 1888\r\nDescription: Canvas (stretcher)\r\nOwner: Private Collection\r\n',
#    'dimensions': 'film size: 14 x 17',
#    'division': None,
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 1,
#    'id': 346216,
#    'imagecount': 2,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR005426_dynmc',
#      'copyright': None,
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45761681,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45761681',
#      'imageid': 419537,
#      'publiccaption': None,
#      'renditionnumber': 'STR005426',
#      'width': 817},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR005427_dynmc',
#      'copyright': None,
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45761682,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45761682',
#      'imageid': 419538,
#      'publiccaption': None,
#      'renditionnumber': 'STR005427',
#      'width': 815}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:19:53-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 346216,
#    'objectnumber': 'Straus.6723',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Artist of original: Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': 'Artist of original:',
#      'role': 'Related name'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR005426_dynmc',
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 265676,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/346216',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'X-radiograph(s) of "The Postman Roulin"',
#    'titlescount': 1,
#    'totalpageviews': 2,
#    'totaluniquepageviews': 2,
#    'url': 'https://www.harvardartmuseums.org/collections/object/346216',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'photograph', 'worktypeid': '259'},
#     {'worktype': 'x-radiograph', 'worktypeid': '405'}]},
#   {'accessionmethod': None,
#    'accessionyear': None,
#    'accesslevel': 1,
#    'century': None,
#    'classification': 'Photographs',
#    'classificationid': 17,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_straus@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Straus Center for Conservation and Technical Studies, Alan Burroughs Collection of X-Radiographs',
#    'culture': None,
#    'datebegin': 0,
#    'dated': None,
#    'dateend': 0,
#    'dateoffirstpageview': '2017-10-02',
#    'dateoflastpageview': '2019-10-15',
#    'department': 'Straus Center for Conservation and Technical Studies',
#    'description': 'X-Radiograph Description: Negative, Print\r\n\r\nBurroughs Number: 0128\r\n\r\nX-Radiograph(s) of: \r\nArtist: Gogh, Vincent van, Dutch, 1853-1890\r\nTitle: Still-Life\r\nOwner: Through David Rosen\r\n',
#    'dimensions': None,
#    'division': None,
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 1,
#    'id': 343829,
#    'imagecount': 1,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR004370_dynmc',
#      'copyright': None,
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 45563534,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45563534',
#      'imageid': 418481,
#      'publiccaption': None,
#      'renditionnumber': 'STR004370',
#      'width': 822}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:19:47-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': None,
#    'objectid': 343829,
#    'objectnumber': 'Straus.4336',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Artist of original: Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': 'Artist of original:',
#      'role': 'Related name'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:huam:STR004370_dynmc',
#    'provenance': None,
#    'publicationcount': 0,
#    'rank': 263291,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/343829',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'X-radiograph(s) of "Still-Life"',
#    'titlescount': 1,
#    'totalpageviews': 15,
#    'totaluniquepageviews': 12,
#    'url': 'https://www.harvardartmuseums.org/collections/object/343829',
#    'verificationlevel': 2,
#    'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#    'worktypes': [{'worktype': 'photograph', 'worktypeid': '259'},
#     {'worktype': 'x-radiograph', 'worktypeid': '405'}]}]}

# %% [markdown]
# ## More endpoints to love
#
# That exercise just brought in the `person` endpoint, but you'll notice that there are in fact many endpoints that we may want to query.
#
# A note on terminology: an API endpoint is a one place that you can go to ask specific questions about a certain part of a dataset or service. Many APIs, especially commercial APIs, contain many, many endpoints, to facilitate all sorts of different activity on a platform.
#
# For example, you can take a look at the [reddit API documentation](https://www.reddit.com/dev/api/) (which we won't be using, this is just an example), to see all of the different endpoints that an application might need to serve as an alternative front end for reddit.
#
# Endpoints on the same API are likely to behave similarly, but they will all serve different purposes. Looking at our HAM endpoints, it looks like they all follow the same basic formulation: `https://api.harvardartmuseums.org/RESOURCE_TYPE`. We can use this to our advantage, and create a function to query any endpoint easily.

# %%
def ham_query(apikey, endpoint, **kwargs):
    """Sends kwargs to the specified endpoint, using apikey for authentication"""
    params = kwargs
    params['apikey'] = apikey
    url = f"https://api.harvardartmuseums.org/{endpoint}"
    R = requests.get(url,params=params)
    return R

# %%
response = ham_query(APIKEY, "gallery", floor=2)

# %%
response.json()
# Out:
# {'info': {'next': 'https://api.harvardartmuseums.org/gallery?floor=2&apikey=622b6240-e14a-11e8-9234-6f5a1db33697&page=2',
#   'page': 1,
#   'pages': 3,
#   'totalrecords': 24,
#   'totalrecordsperquery': 10},
#  'records': [{'floor': 2,
#    'galleryid': 2340,
#    'gallerynumber': '2340',
#    'id': 2340,
#    'labeltext': 'For centuries, silver was among the most revered and highly valued materials in Britain. Shipped across the Atlantic from the vast mines of Central America, silver was used to craft a variety of sacred and secular objects, from cups and salvers to medals and coins. Between 1600 and 1850, silver objects also figured prominently in a wide range of religious and social rituals, from the communion service to the taking of tea.\r\n\r\n\r\nThis gallery displays pieces of silver crafted for four of these rituals, each of which required specific forms and styles of ornamentation. Ritual objects from the religious altar occupy the left side of the cabinet. The center section presents elaborately ornamented dining wares decorated to elicit attention. Assembled on the right are exotic objects used in tea drinking, and in the rightmost section, one finds cups and tankards from Harvard’s High Table, the exclusive area where privileged students and senior faculty dined in the seventeenth and eighteenth centuries.\r\n\r\n\r\nThe silver on view in each section is linked by shared stylistic attributes and decorative motifs, pointing to the relationship between design and ritual. Between the seventeenth and nineteenth centuries in Britain, the art of crafting silver was a culturally embedded practice informed by the ideological questions, patterns of human behavior, and larger debates about the power of objects that animated all of the rituals in which silver objects played a part.',
#    'lastupdate': '2019-11-06T04:43:42-0500',
#    'name': 'European and American Art, 17th–19th century',
#    'objectcount': 0,
#    'theme': 'The Silver Cabinet: Art and Ritual, 1600–1850',
#    'url': 'https://www.harvardartmuseums.org/visit/floor-plan/2/2340'},
#   {'floor': 2,
#    'galleryid': 2200,
#    'gallerynumber': '2200',
#    'id': 2200,
#    'labeltext': 'A sustained commitment to the tenets of neoclassicism persisted after the French Revolution, and artists such as Jacques-Louis David and his school continued to adhere to the sculptural and archaeological approach to form that they had helped popularize in the previous century. However, their style was soon challenged by romanticism, which proposed a radically different kind of representation. Its development over the first half of the nineteenth century produced myriad reformulations and contradictions in its definition. But at its height, romantic painting was characterized by a bold and vibrant palette and by loose and expressive brushstrokes that often obscured any careful preparatory drawing beneath the composition. Nature, as a powerful force and stimulant for extreme human emotions, was a favored focus, as were literary subjects and the poetry of William Shakespeare and Lord Byron. The artist was viewed as a unique conduit for those elements through his work.\r\nThe years 1823–24 marked a watershed moment for romanticism in France, with the publication of the first part of Stendhal’s Racine and Shakespeare, which enumerated the limitations of the classicist tradition, and with the Salon of 1824, where critics compared history paintings by Jean-Auguste-Dominique Ingres and Eugène Delacroix, and there, too, found classicism wanting. Adopting the terminology of the German critic Friedrich von Schlegel, who had earlier pitted romanticism against classicism, critics heralded Ingres as a classicist and Delacroix as a romantic—figureheads of antithetical styles, even though many of the same concerns underpinned both artists’ approaches. Delacroix, in fact, claimed he was not a “romantic” at all.',
#    'lastupdate': '2019-11-06T04:43:42-0500',
#    'name': 'European and American Art, 17th–19th century',
#    'objectcount': 22,
#    'theme': 'The Emergence of Romanticism in Early Nineteenth-Century France',
#    'url': 'https://www.harvardartmuseums.org/visit/floor-plan/2/2200'},
#   {'floor': 2,
#    'galleryid': 2210,
#    'gallerynumber': '2210',
#    'id': 2210,
#    'labeltext': None,
#    'lastupdate': '2019-11-06T04:43:42-0500',
#    'name': 'West Arcade',
#    'objectcount': 6,
#    'theme': None,
#    'url': 'https://www.harvardartmuseums.org/visit/floor-plan/2/2210'},
#   {'floor': 2,
#    'galleryid': 2460,
#    'gallerynumber': '2460',
#    'id': 2460,
#    'labeltext': None,
#    'lastupdate': '2019-11-06T04:43:42-0500',
#    'name': 'East Arcade',
#    'objectcount': 2,
#    'theme': None,
#    'url': 'https://www.harvardartmuseums.org/visit/floor-plan/2/2460'},
#   {'floor': 2,
#    'galleryid': 2620,
#    'gallerynumber': '2620',
#    'id': 2620,
#    'labeltext': None,
#    'lastupdate': '2019-11-06T04:43:42-0500',
#    'name': 'East Asian Art',
#    'objectcount': 5,
#    'theme': None,
#    'url': 'https://www.harvardartmuseums.org/visit/floor-plan/2/2620'},
#   {'floor': 2,
#    'galleryid': 2700,
#    'gallerynumber': '2700',
#    'id': 2700,
#    'labeltext': 'Capitals of the Art World in Europe, 1874–1914: Berlin, London, Paris\r\n\r\nThe influence of impressionist artists from France--who valued the practice of painting the modern world, whether that be landscapes or scenes of prosperous urban life as opposed to historical or biblical subjects--spread across Europe and the West in the later part of the 19th century. Artists in such countries as the United Kingdom, Germany, and the United States also took up impressionism’s optical challenges of painting with a sense of immediacy, using free brushwork and light, bright colors. Painters like John Singer Sargent followed these aspects of the impressionist style, while others, such as James Abbott McNeill Whistler, remained committed to quotidian subjects but also began to explore the darker side of urban life. Whistler would wander the streets of London at night, trying to impress the fog-laden cityscapes upon his visual memory, which he then translated into his famous “nocturnes,” or night scenes, once back in his studio. The influence of these imaginative, atmospheric paintings was enormous, both in Europe and in the United States.\r\n\r\n\r\nWhistler was the archetypal transnational artist of the period: born in America, he trained in Paris before practicing in London. Increased opportunities for travel and geopolitical peace and stability before the start of World War I allowed for this way of life, and many artists followed suit. New technologies for reproducing works of art in illustrated magazines and newspapers meant also that artists could enjoy international renown. And as government commissions for grand paintings diminished, countries organized international expositions to showcase their cultural riches. Artists outside of this system were left to develop their own networks; male artists formed “brotherhoods,” loose associations of artists working together with similar goals.',
#    'lastupdate': '2019-11-06T04:43:42-0500',
#    'name': 'European and American Art, 19th century',
#    'objectcount': 24,
#    'theme': 'Impressionism and the Late Nineteenth Century',
#    'url': 'https://www.harvardartmuseums.org/visit/floor-plan/2/2700'},
#   {'floor': 2,
#    'galleryid': 2100,
#    'gallerynumber': '2100',
#    'id': 2100,
#    'labeltext': 'This gallery brings together examples of the new materials, technologies, and ways of seeing that animated the art world in the mid-19th century. Painters, sculptors, and photographers developed innovative techniques to respond to a world rendered unfamiliar by urbanization and industrialization. Oil painting remained a leading expressive medium, but painters adapted centuries of tradition to the turbulent, changing times in which they lived. Some turned to the landscape to offset the trauma of the modern city, while others took an interest in the emerging psychology and science of perception. For American painters who faced the trauma of civil war, realism offered the best path to take stock of a nation devastated by bloodshed, factionalism, and social unrest.\r\nThe mid-19th century also witnessed the advent of photography. Invented in France and England and widely adapted by 1839, this radical image-making technology astonished early audiences and made formerly elite forms like portraiture available to wide swaths of the population. Photography put pressure on every genre of art making, even as it drew from longstanding art historical conventions. The works in the gallery reflect the influence of this new medium, as well as the new ways of seeing and interpreting the world it brought about.',
#    'lastupdate': '2019-11-06T04:43:42-0500',
#    'name': 'European and American Art, 17th–19th century',
#    'objectcount': 44,
#    'theme': 'Centuries of Tradition, Changing Times: Art for an Uncertain Age',
#    'url': 'https://www.harvardartmuseums.org/visit/floor-plan/2/2100'},
#   {'floor': 2,
#    'galleryid': 2220,
#    'gallerynumber': '2220',
#    'id': 2220,
#    'labeltext': 'Two styles prevailed in European art of the eighteenth century: rococo, associated with the reign of French king Louis XV (1715–1774), and neoclassicism, which emerged mid-century. The term rococo is a combination of the French word rocaille—a style of ornament with an elaborate, often asymmetrical conflation of natural elements, especially plants, stones, and shells—and the Italian word barocco, which refers to the baroque style, characterized by exuberant ornamentation and dramatic action. Artists of this era favored a palette of light hues; they frequently alluded to contemporary dance and theater; and particularly in the realm of decorative arts, they borrowed elements from Chinese art that was being exported to Europe. These traits led to the characterization of rococo art as lighthearted and fantastical, despite its continued consideration of sober, moral subjects—such as the Virgin’s Purification in Corrado Giaquinto’s painting at the center of this gallery—and its studied attentiveness to tradition.\r\nNeoclassicism, a style based on the art of ancient Greece and Rome, developed in tandem with archaeological excavations at Herculaneum and Pompeii toward the middle of the century. The availability of extensive new evidence of the arts of antiquity—coupled later in the century with the scholarly writings of Johann Joachim Winckelmann (1717–1768), who distinguished styles in the art of different ancient civilizations—triggered a demand for greater accuracy in the visual representation of ancient subjects. Artists responded to this necessity by importing into their compositions classical forms and objects that they had seen in ancient collections or knew through prints. Young collectors from northern European countries sought to expand their knowledge of antiquity by traveling through Italy on an extensive trip known as the Grand Tour. While visiting ancient sites and museums, they purchased antiquities and contemporary art for their burgeoning private collections.',
#    'lastupdate': '2019-11-06T04:43:42-0500',
#    'name': 'European and American Art, 17th–19th century',
#    'objectcount': 37,
#    'theme': 'Rococo and Neoclassicism in the Eighteenth Century',
#    'url': 'https://www.harvardartmuseums.org/visit/floor-plan/2/2220'},
#   {'floor': 2,
#    'galleryid': 2240,
#    'gallerynumber': '2240',
#    'id': 2240,
#    'labeltext': 'The Arts in the 18th-Century Atlantic World\r\n\r\nBetween 1700 and 1800, thousands of trading ships crisscrossed the Atlantic Ocean. Carrying raw materials and finished products, free and enslaved people, and word of new discoveries and scientific advances, these ships circulated a range of ideas and images and linked cities and communities across Britain, Europe, and North and South America into a vast, interconnected culture. This gallery brings together paintings, works on paper, and pieces of decorative art to explore the intersection between the arts and this larger web of circulation and exchange.\r\n\r\nEighteenth-century artists mined the past for inspiration, and many of the works on display here make use of forms, subjects, and symbols derived from the ancient world. Disseminated through illustrations of archaeological discoveries in elaborate folios like Giovanni Battista Piranesi’s Antiquities of Rome, this neoclassical vocabulary constituted the lingua franca of the interconnected Atlantic. Classical references were as common in portraits from colonial Boston as they were in paintings acquired by collectors on the Grand Tour, like Vanvitelli’s view of the Colosseum.\r\n\r\nIn an age of expansive trade, works of art and domestic objects were regularly sent across the ocean. Charles Willson Peale painted his standing portrait of George Washington in Philadelphia, then promptly crated and shipped it off to Paris, where it remained for much of its history. Filled with Asian silks and Cuban mahogany, John Singleton Copley’s portraits of the Boylston family celebrate the new world of exotic commodities that overseas trade had opened up.\r\n\r\nArtist’s materials, tools, and knowledge of art-making techniques also moved around the Atlantic. Many of the works in this gallery are products of these new methods and materials. The case in the center of the room highlights two extraordinary examples: a wampum wrist ornament fabricated in New England with the help of steel drills imported from Europe and a ceramic punch bowl crafted in Britain and based on Asian prototypes.',
#    'lastupdate': '2019-11-06T04:43:42-0500',
#    'name': 'European and American Art, 17th–19th century',
#    'objectcount': 25,
#    'theme': 'The Arts in the Eighteenth–Century Atlantic World',
#    'url': 'https://www.harvardartmuseums.org/visit/floor-plan/2/2240'},
#   {'floor': 2,
#    'galleryid': 2410,
#    'gallerynumber': '2410',
#    'id': 2410,
#    'labeltext': None,
#    'lastupdate': '2019-11-06T04:43:42-0500',
#    'name': 'South Arcade',
#    'objectcount': 5,
#    'theme': None,
#    'url': 'https://www.harvardartmuseums.org/visit/floor-plan/2/2410'}]}

# %% [markdown]
# ### Boy, that's convenient!
#
# That function works because Python has this neat ability to take arbitrary arguments in functions, if you tell it to. Essentially, there are two special arguments in function definitions: `*args` and `**kwargs`. These make available `args` and `kwargs` objects, respectively, in your function. `args` is a list, and `kwargs` is a dictionary. This makes it so that you don't have to specify all of the arguments your function can take, you can just give it general rules for lists or key pairs of data as input.
#
# You might be wondering why you wouldn't just use a dictionary or list instead of those arguments. In our case, it's mostly a stylistic choice, and one that saves us a couple of key strokes.

# %% [markdown]
# #### Try out some other endpoints!

# %%
# Here's an example: all of the current exhibits with their begin and end dates
response = ham_query(APIKEY, "exhibition", status="current", size=100, sort="chronological")
current_exhibits = response.json()['records']
current_exhibits
print()
for exhibit in current_exhibits:
    print(f"({exhibit['begindate']} to {exhibit['enddate']}) {exhibit['title']}")
# Out:
# (2016-09-07 to 2020-09-07) Davis Museum Permanent Gallery reinstallation
# (2018-11-17 to 2021-11-14) Clay—Modeling African Design
# (2019-03-09 to 2021-01-01) Charlotte Posenenske: A Retrospective
# (2019-05-24 to 2020-01-26) Gauguin: Portraits
# (2019-05-26 to 2020-01-12) Manet and Modern Beauty
# (2019-07-13 to 2020-02-23) Hyman Bloom: A Matter of Life and Death
# (2019-08-31 to 2019-12-01) Through a Glass, Darkly: Allegory and Faith in Netherlandish Prints from Lucas van Leyden to Rembrandt
# (2019-08-31 to 2020-01-05) Woven Interiors: Early Medieval Textiles of the Eastern Mediterranean
# (2019-08-31 to 2020-01-05) Winslow Homer: Eyewitness
# (2019-08-31 to 2020-01-05) Early Christian Africa: Arts of Transformation
# (2019-08-31 to 2020-01-05) Critical Printing
# (2019-09-04 to 2019-12-14) Dharma and Pūnya: Buddhist Ritual Art of Nepal
# (2019-09-05 to 2019-12-08) Unto This Last: Two Hundred Years of John Ruskin
# (2019-09-05 to 2020-01-12) In a Cloud, in a Wall, in a Chair: Modernists in Mexico at Midcentury
# (2019-09-06 to 2020-01-05) Crossing Lines, Constructing Home: Displacement and Belonging in Contemporary Art
# (2019-09-11 to 2020-02-02) William Blake
# (2019-09-15 to 2019-12-15) City of Dreams. Lyonel Feininger and His Villages
# (2019-09-16 to 2020-02-02) Zarina: Atlas of Her World
# (2019-10-04 to 2020-05-31) John Singer Sargent: Portraits in Charcoal
# (2019-10-17 to 2022-01-16) Nam June Paik: The Future is Now
# (2019-10-19 to 2020-01-19) Thomas Jefferson Architect: Palladian Models, Democratic Principles, and the Conflict of Ideals
# (2019-10-19 to 2020-02-16) The Eternal Feast: Banqueting in 10th-14th Century Chinese Art
# (2019-10-20 to 2020-06-01) Monet: The Truth of Nature
# (2019-10-22 to 2020-02-29) Galerie St. Etienne 80th anniversary
# (2019-10-25 to 2020-01-12) Rachel Harrison
# (2019-10-26 to 2020-01-26) Counter-Landscapes: Performative Actions from the 1970's - now
# (2019-10-26 to 2020-09-13) Edward Hopper and the American Hotel
# (2019-11-01 to 2020-02-09) Young Rembrandt

# %% [markdown]
# ### Endpoint Exercises
#
# [HAM API Documentation](https://github.com/harvardartmuseums/api-docs)
#
# - Get a list of all the medium types in the museum
# - How many levels of mediums are there?
# - Choose a medium from the most specific (highest numerical value) level. Note the medium id. Create a new query to the object endpoint, using the medium id as a filter. How many objects are there created from this medium?
# - Choose a level 2 medium instead. Create a new query to the object endpoint, again filtering by this medium id. Print out the medium types of the returned records. What do you notice about the types?
# - BONUS: reorganize your list of medium objects into a nested structure so that child media are accessed through a list under their parents. Print out the list like so:
# - Metal
#     - Pb
#     - potin
#     - ...
#     - copper alloy
#         - copper-antimony-arsenic alloy
#         - copper-iron alloy
#         - copper-tin-antimony-arsenic alloy
#         - leaded copper-tin-antimony alloy
#         - etc ...

# %%
# How many levels of mediums are there?
mediums = ham_query(APIKEY, 'medium', size=100)
levels = [r['level'] for r in mediums.json()['records']]
set(levels)
# Out:
# {1, 2, 3}

# %%
l3s = ham_query(APIKEY,'medium',size=100,q="level:3").json()

# %%
l3s
# Out:
# {'info': {'page': 1,
#   'pages': 1,
#   'totalrecords': 18,
#   'totalrecordsperquery': 100},
#  'records': [{'haschildren': 0,
#    'id': 2040159,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040159,
#    'name': 'leaded arsenical copper',
#    'objectcount': 1,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040162,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040162,
#    'name': 'leaded copper-antimony-arsenic alloy',
#    'objectcount': 1,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040153,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040153,
#    'name': 'copper-antimony-arsenic alloy',
#    'objectcount': 1,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040154,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040154,
#    'name': 'copper-iron alloy',
#    'objectcount': 1,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040157,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040157,
#    'name': 'copper-tin-antimony-arsenic alloy',
#    'objectcount': 1,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040163,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040163,
#    'name': 'leaded copper-tin-antimony alloy',
#    'objectcount': 3,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040165,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040165,
#    'name': 'copper-lead-arsenic alloy',
#    'objectcount': 1,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040166,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040166,
#    'name': 'leaded bronze',
#    'objectcount': 333,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040149,
#    'lastupdate': '2019-11-06T05:18:24-0500',
#    'level': 3,
#    'mediumid': 2040149,
#    'name': 'arsenical bronze',
#    'objectcount': 4,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040150,
#    'lastupdate': '2019-11-06T05:18:24-0500',
#    'level': 3,
#    'mediumid': 2040150,
#    'name': 'arsenical copper',
#    'objectcount': 11,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040152,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040152,
#    'name': 'low-tin bronze',
#    'objectcount': 1,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040156,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040156,
#    'name': 'copper-tin-antimony alloy',
#    'objectcount': 8,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040164,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040164,
#    'name': 'mixed copper alloy',
#    'objectcount': 95,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040151,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040151,
#    'name': 'high-tin bronze',
#    'objectcount': 1,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040158,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040158,
#    'name': 'leaded arsenical bronze',
#    'objectcount': 2,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040155,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040155,
#    'name': 'copper-silver alloy',
#    'objectcount': 1,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040160,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040160,
#    'name': 'leaded brass',
#    'objectcount': 25,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'},
#   {'haschildren': 0,
#    'id': 2040161,
#    'lastupdate': '2019-11-06T05:25:12-0500',
#    'level': 3,
#    'mediumid': 2040161,
#    'name': 'leaded copper',
#    'objectcount': 15,
#    'parentmediumid': 2040148,
#    'pathforward': 'Metal\\copper alloy\\'}]}

# %%
l3_id = l3s['records'][0]['id']
l3_id
# Out:
# 2040159

# %%
ham_query(APIKEY,'object',medium=l3_id).json()
# Out:
# {'info': {'page': 1,
#   'pages': 1,
#   'totalrecords': 1,
#   'totalrecordsperquery': 10},
#  'records': [{'accessionmethod': 'Gift',
#    'accessionyear': 1968,
#    'accesslevel': 1,
#    'century': '2nd millennium BCE',
#    'classification': 'Weapons and Ammunition',
#    'classificationid': 155,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_asianmediterranean@harvard.edu',
#    'contextualtextcount': 1,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Gift of Richard R. Wagner',
#    'culture': 'Levantine',
#    'datebegin': -1900,
#    'dated': '19th-18th century BCE',
#    'dateend': -1700,
#    'dateoffirstpageview': '2010-03-03',
#    'dateoflastpageview': '2019-10-29',
#    'department': 'Department of Ancient and Byzantine Art & Numismatics',
#    'description': None,
#    'details': {'technical': [{'formattedtext': '<P><SPAN style="FONT-SIZE: 12pt; FONT-FAMILY: \'Times New Roman\',\'serif\'; mso-fareast-font-family: Calibri; mso-fareast-theme-font: minor-latin; mso-ansi-language: EN-US; mso-fareast-language: EN-US; mso-bidi-language: AR-SA"><SPAN style="FONT-SIZE: 12pt; FONT-FAMILY: \'Times New Roman\',\'serif\'; mso-fareast-font-family: Calibri; mso-fareast-theme-font: minor-latin; mso-ansi-language: EN-US; mso-fareast-language: EN-US; mso-bidi-language: AR-SA">ICP-MS/AAA data from sample, </SPAN>Leaded Arsenical Copper:</SPAN></P>\r\n<P><SPAN style="FONT-SIZE: 12pt; FONT-FAMILY: \'Times New Roman\',\'serif\'; mso-fareast-font-family: Calibri; mso-fareast-theme-font: minor-latin; mso-ansi-language: EN-US; mso-fareast-language: EN-US; mso-bidi-language: AR-SA">Cu, <SPAN style="mso-no-proof: yes">66.79</SPAN>; Sn, <SPAN style="mso-no-proof: yes">less than 0.25</SPAN>; Pb, <SPAN style="mso-no-proof: yes">30.28</SPAN>; Zn, <SPAN style="mso-no-proof: yes">0.003</SPAN>; Fe, <SPAN style="mso-no-proof: yes">0.14</SPAN>; Ni, <SPAN style="mso-no-proof: yes">0.02</SPAN>; Ag, <SPAN style="mso-no-proof: yes">0.03</SPAN>; Sb, <SPAN style="mso-no-proof: yes">0.05</SPAN>; As, <SPAN style="mso-no-proof: yes">2.69</SPAN>; Bi, <SPAN style="mso-no-proof: yes">less than 0.025</SPAN>; Co, <SPAN style="mso-no-proof: yes">less than 0.01</SPAN>; Au, <SPAN style="mso-no-proof: yes">less than 0.01</SPAN>; Cd, less than 0.001</SPAN></P>\r\n<P><SPAN style="FONT-SIZE: 12pt; FONT-FAMILY: \'Times New Roman\',\'serif\'; mso-fareast-font-family: Calibri; mso-fareast-theme-font: minor-latin; mso-ansi-language: EN-US; mso-fareast-language: EN-US; mso-bidi-language: AR-SA">J. Riederer</SPAN></P>',
#       'text': 'ICP-MS/AAA data from sample, Leaded Arsenical Copper:\r\nCu, 66.79; Sn, less than 0.25; Pb, 30.28; Zn, 0.003; Fe, 0.14; Ni, 0.02; Ag, 0.03; Sb, 0.05; As, 2.69; Bi, less than 0.025; Co, less than 0.01; Au, less than 0.01; Cd, less than 0.001\r\nJ. Riederer',
#       'type': 'Chemical Composition'},
#      {'formattedtext': '<P class=MsoNormal style="MARGIN: 0in 0in 3pt"><SPAN style="mso-ascii-font-family: \'Times New Roman\'; mso-ascii-theme-font: major-bidi; mso-hansi-font-family: \'Times New Roman\'; mso-hansi-theme-font: major-bidi; mso-bidi-font-family: \'Times New Roman\'; mso-bidi-theme-font: major-bidi"><FONT size=3><FONT face="Times New Roman">The solid blade was cast in one piece. The very crisp edges and simplification of the forms suggests that, rather than having been made by the lost-wax process, it could have been cast in a piece-mold made up of three to five pieces that defined the main front and back of the blade and an oval-sectioned cylindrical piece that defined the&nbsp;socket for the shaft. The socket section could have been made in two halves, each of which could have extended perpendicularly to create the flat edges of the blade. It is not clear whether the six facets that run across the back of the axe head were defined in the mold or created in the metal. The topography of the blade on each side of the axe is not identical; accretions obscure the surface and any finer evidence of tool marks. The wall thickness where the handle would have been inserted is c. 2.2 to 2.5 mm.<?xml:namespace prefix = "o" ns = "urn:schemas-microsoft-com:office:office" /><o:p></o:p></FONT></FONT></SPAN></P>\r\n<P class=MsoNormal style="MARGIN: 0in 0in 3pt"><SPAN style="mso-ascii-font-family: \'Times New Roman\'; mso-ascii-theme-font: major-bidi; mso-hansi-font-family: \'Times New Roman\'; mso-hansi-theme-font: major-bidi; mso-bidi-font-family: \'Times New Roman\'; mso-bidi-theme-font: major-bidi"><o:p><FONT size=3 face="Times New Roman">&nbsp;</FONT></o:p></SPAN></P>\r\n<P class=MsoNormal style="MARGIN: 0in 0in 3pt"><SPAN style="mso-ascii-font-family: \'Times New Roman\'; mso-ascii-theme-font: major-bidi; mso-hansi-font-family: \'Times New Roman\'; mso-hansi-theme-font: major-bidi; mso-bidi-font-family: \'Times New Roman\'; mso-bidi-theme-font: major-bidi"><FONT size=3><FONT face="Times New Roman">Overall, the object is in good condition. Some loss at the edges of the axe blade due to mineralization have occurred, some of which have been covered up with a waxy or resinous coating. A few long, intentional scrape marks on one side of the axe blade expose a green corrosion layer above a cupritic layer and probably result from an attempt to clean the piece. Mottled tan and pink burial accretions have been darkened to a light brown by a waxy or resinous coating in some areas and cover light green corrosion products.<o:p></o:p></FONT></FONT></SPAN></P>\r\n<P class=MsoNormal style="MARGIN: 0in 0in 3pt"><SPAN style="mso-ascii-font-family: \'Times New Roman\'; mso-ascii-theme-font: major-bidi; mso-hansi-font-family: \'Times New Roman\'; mso-hansi-theme-font: major-bidi; mso-bidi-font-family: \'Times New Roman\'; mso-bidi-theme-font: major-bidi"><o:p><FONT size=3 face="Times New Roman">&nbsp;</FONT></o:p></SPAN></P>\r\n<P class=MsoNormal style="MARGIN: 0in 0in 3pt"><SPAN style="mso-ascii-font-family: \'Times New Roman\'; mso-ascii-theme-font: major-bidi; mso-hansi-font-family: \'Times New Roman\'; mso-hansi-theme-font: major-bidi; mso-bidi-font-family: \'Times New Roman\'; mso-bidi-theme-font: major-bidi"><o:p><FONT size=3 face="Times New Roman">&nbsp;</FONT></o:p></SPAN></P><SPAN style="FONT-SIZE: 12pt; FONT-FAMILY: \'Times New Roman\',\'serif\'; mso-ascii-theme-font: major-bidi; mso-hansi-theme-font: major-bidi; mso-bidi-theme-font: major-bidi; mso-fareast-font-family: Calibri; mso-fareast-theme-font: minor-latin; mso-bidi-language: AR-SA; mso-ansi-language: EN-US; mso-fareast-language: EN-US">Tracy Richardson and Francesca G. Bewer (submitted 1999, updated 2012)</SPAN>',
#       'text': 'The solid blade was cast in one piece. The very crisp edges and simplification of the forms suggests that, rather than having been made by the lost-wax process, it could have been cast in a piece-mold made up of three to five pieces that defined the main front and back of the blade and an oval-sectioned cylindrical piece that defined the socket for the shaft. The socket section could have been made in two halves, each of which could have extended perpendicularly to create the flat edges of the blade. It is not clear whether the six facets that run across the back of the axe head were defined in the mold or created in the metal. The topography of the blade on each side of the axe is not identical; accretions obscure the surface and any finer evidence of tool marks. The wall thickness where the handle would have been inserted is c. 2.2 to 2.5 mm.\r\n \r\nOverall, the object is in good condition. Some loss at the edges of the axe blade due to mineralization have occurred, some of which have been covered up with a waxy or resinous coating. A few long, intentional scrape marks on one side of the axe blade expose a green corrosion layer above a cupritic layer and probably result from an attempt to clean the piece. Mottled tan and pink burial accretions have been darkened to a light brown by a waxy or resinous coating in some areas and cover light green corrosion products.\r\n \r\n \r\nTracy Richardson and Francesca G. Bewer (submitted 1999, updated 2012)',
#       'type': 'Technical Observations'}]},
#    'dimensions': '10.7 x 9.6 cm (4 3/16 x 3 3/4 in.)',
#    'division': 'Asian and Mediterranean Art',
#    'edition': None,
#    'exhibitioncount': 0,
#    'groupcount': 1,
#    'id': 312111,
#    'imagecount': 2,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC249887_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 683,
#      'idsid': 47334030,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/47334030',
#      'imageid': 426159,
#      'publiccaption': None,
#      'renditionnumber': 'DDC249887',
#      'width': 1024},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG5343_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 532,
#      'idsid': 43163264,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43163264',
#      'imageid': 98323,
#      'publiccaption': None,
#      'renditionnumber': 'LEG5343',
#      'width': 1024}],
#    'labeltext': None,
#    'lastupdate': '2019-11-06T06:18:51-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Leaded arsenical copper',
#    'objectid': 312111,
#    'objectnumber': '1968.110',
#    'peoplecount': 0,
#    'period': 'Bronze Age, Middle',
#    'periodid': 919,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC249887_dynmc',
#    'provenance': 'Richard R. Wagner, gift; to the Fogg Museum, 1968.',
#    'publicationcount': 2,
#    'rank': 87907,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/312111',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': 'Cast, lost-wax process',
#    'techniqueid': 1311,
#    'title': 'Battle Axe Head',
#    'titlescount': 1,
#    'totalpageviews': 47,
#    'totaluniquepageviews': 42,
#    'url': 'https://www.harvardartmuseums.org/collections/object/312111',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'axe', 'worktypeid': '33'}]}]}

# %% [markdown]
# ## Individual Objects and IIIF

# %% [markdown]
# The HAM object API can provide more information (such as `exhibition`, `citation`, `publication`, and `marks`) if you ask for a specific object by its objectid. For some records that have been extensively annotated (often those with `verificationlevel` == 4) the lists for these properties can contain hundreds of entries.

# %%
def ham_query_with_id(apikey, endpoint, ID, **kwargs):
    """Sends kwargs to the specified endpoint, using apikey for authentication. ID is a required arg (appears in the route)"""
    params = kwargs
    params['apikey'] = apikey
    url = "https://api.harvardartmuseums.org/{}/{}".format(endpoint,ID)
    R = requests.get(url,params=params)
    return R

# %%
objectid = topResult['objectid']
topResultFull = ham_query_with_id(APIKEY, "object", objectid)

print(topResultFull.url)
print("Verification Level 4: {}".format(topResultFull.json()['verificationlevel'] == 4))
print()
print(topResultFull.json())
# Out:
# https://api.harvardartmuseums.org/object/299843?apikey=622b6240-e14a-11e8-9234-6f5a1db33697
# Verification Level 4: True
#
# {'objectid': 299843, 'objectnumber': '1951.65', 'accessionyear': 1951, 'dated': '1888', 'datebegin': 1888, 'dateend': 1888, 'classification': 'Paintings', 'classificationid': 26, 'medium': 'Oil on canvas', 'technique': None, 'techniqueid': None, 'period': None, 'periodid': None, 'century': '19th century', 'culture': 'Dutch', 'style': None, 'signed': 'red paint, l.r.: Vincent/Arles', 'state': None, 'edition': None, 'standardreferencenumber': None, 'dimensions': '61.5 x 50.3 cm (24 3/16 x 19 13/16 in.)\r\nframed: 90.4 x 79.7 x 8.3 cm (35 9/16 x 31 3/8 x 3 1/4 in.)', 'copyright': None, 'creditline': 'Harvard Art Museums/Fogg Museum, Bequest from the Collection of Maurice Wertheim, Class of 1906', 'department': 'Department of Paintings, Sculpture & Decorative Arts', 'division': 'European and American Art', 'contact': 'am_europeanamerican@harvard.edu', 'description': None, 'provenance': 'Vincent van Gogh, Arles, (1888,) gift;  to Paul Gauguin, (1888-1897) sold. [Ambroise Vollard, Paris.] [Paul Cassirer Gallery, Berlin.] Dr. Hugo von Tschudi, Berlin, (1906-1911), by descent; to his widow, Angela von Tschudi, Munich (1911-1919),  to Neue Staatsgalerie, Munich (1919-1938); removed from the collection by the National Socialist (Nazi) authorities in 1938, consigned; to [Theodor Fischer Gallery, Lucerne, Switzerland, for sale June 30, 1939, lot 45]; to Maurice Wertheim (1939-1951) bequest; to Fogg Art Museum, 1951.\r\n\r\n \r\n\r\nNotes:\r\nGauguin sold the painting for Fr 300\r\nHugo von Tschudi bought the painting for the Nationalgalerie, Berlin, with funds from sponsors, but did not submit it to the Kaiser for pre-approval. He took the painting to Munich when he assumed a post there.\r\nAccording to Stephanie Barron, the van Gogh was removed from the Neue Staatsgalerie on March 27, 1938 and stored at Schloss Niederschönhausen in August of that year. (Barron, 1991, pp. 135-146)\r\n', 'commentary': None, 'labeltext': 'In early 1888, Van Gogh moved to Arles in the south of France, where he hoped to establish an art colony. Believing that painting could be reinvented through the genre of portraiture, he encouraged his fellow artists to paint themselves, and then to exchange the canvases. After receiving self-portraits from Emile Bernard and Gauguin, who were working together in Brittany at the time, Van Gogh inscribed this painting “To my friend Paul Gauguin,” and sent it to him. He described the process of creating his arresting likeness in several letters to his brother Theo, an art dealer in Paris, explaining how he manipulated his features in response to Japanese prints, changed the contours of his jacket for coloristic effect, and painted the background “pale veronese green” without any shadows. Shortly after he sent the work to Gauguin, however, their friendship deteriorated, and Gauguin sold it for three hundred francs.', 'imagecount': 6, 'mediacount': 0, 'colorcount': 10, 'markscount': 22, 'peoplecount': 1, 'titlescount': 1, 'publicationcount': 206, 'exhibitioncount': 26, 'contextualtextcount': 0, 'groupcount': 3, 'relatedcount': 2, 'totalpageviews': 30662, 'totaluniquepageviews': 24589, 'dateoffirstpageview': '2009-05-12', 'dateoflastpageview': '2019-11-05', 'verificationlevel': 4, 'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted', 'imagepermissionlevel': 0, 'accesslevel': 1, 'accessionmethod': 'Bequest', 'rank': 466, 'url': 'https://www.harvardartmuseums.org/collections/object/299843', 'id': 299843, 'lastupdate': '2019-11-06T06:18:22-0500', 'colors': [{'percent': 0.2979781420765, 'spectrum': '#4fb94f', 'color': '#64af7d', 'css3': '#5f9ea0', 'hue': 'Green'}, {'percent': 0.21289617486339, 'spectrum': '#47b853', 'color': '#64c896', 'css3': '#66cdaa', 'hue': 'Green'}, {'percent': 0.19814207650273, 'spectrum': '#3db657', 'color': '#323219', 'css3': '#2f4f4f', 'hue': 'Brown'}, {'percent': 0.056775956284153, 'spectrum': '#6cbd45', 'color': '#7d7d4b', 'css3': '#696969', 'h ...

# %% [markdown]
# When we printed the 10 most popular records above (under **Looking at the Results**), you may have noticed a sharp dropoff after the first few records. Our Van Gogh painting is particularly popular, with ~8000 more views than the second most popular record and more than 4x as many as the tenth most popular. This particular Art Museum record is used as the default image asset for the demo installation of [Project Mirador](http://projectmirador.org/demo/), an image viewer for [IIIF (International Image Interoperability Framework)](https://iiif.io/) media assets.
#
# We're not going to go deep into IIIF in this workshop, but want to mention that IIIF is both a community of developers and a collection of APIs and API-compliant tools that you can use to share, manipulate, and display visual materials. The [Image API](https://iiif.io/api/image/2.1/) and [Presentation API](https://iiif.io/api/presentation/2.1/) are the most used outputs as of now, though there are also APIs for Authentication, Search, and beta versions for other media (video and VR).

# %% [markdown]
# ### IIIF Image API
#
# Within our `topResultFull` object, there is an images list, which contains IIIF baseurls as well as Image Delivery Service URLs:

# %%
ham_images = topResultFull.json()['images']
ham_images
# Out:
# [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC251942_dynmc',
#   'copyright': 'President and Fellows of Harvard College',
#   'displayorder': 1,
#   'format': 'image/jpeg',
#   'height': 2550,
#   'idsid': 47174896,
#   'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/47174896',
#   'imageid': 429030,
#   'publiccaption': None,
#   'renditionnumber': 'DDC251942',
#   'width': 2087},
#  {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC000072_dynmc',
#   'copyright': 'President and Fellows of Harvard College',
#   'displayorder': 2,
#   'format': 'image/jpeg',
#   'height': 2550,
#   'idsid': 18737483,
#   'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18737483',
#   'imageid': 185978,
#   'publiccaption': None,
#   'renditionnumber': 'DDC000072',
#   'width': 2088},
#  {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC251934_dynmc',
#   'copyright': 'President and Fellows of Harvard College',
#   'displayorder': 3,
#   'format': 'image/jpeg',
#   'height': 2550,
#   'idsid': 47174892,
#   'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/47174892',
#   'imageid': 429028,
#   'publiccaption': None,
#   'renditionnumber': 'DDC251934',
#   'width': 2259},
#  {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:30033_dynmc',
#   'copyright': 'President and Fellows of Harvard College',
#   'displayorder': 4,
#   'format': 'image/jpeg',
#   'height': 1024,
#   'idsid': 43182083,
#   'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43182083',
#   'imageid': 25781,
#   'publiccaption': None,
#   'renditionnumber': '30033',
#   'width': 844},
#  {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:50493_dynmc',
#   'copyright': 'President and Fellows of Harvard College',
#   'displayorder': 5,
#   'format': 'image/jpeg',
#   'height': 2550,
#   'idsid': 43183405,
#   'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43183405',
#   'imageid': 19801,
#   'publiccaption': None,
#   'renditionnumber': '50493',
#   'width': 2082},
#  {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:50849_dynmc',
#   'copyright': 'President and Fellows of Harvard College',
#   'displayorder': 6,
#   'format': 'image/jpeg',
#   'height': 2550,
#   'idsid': 43183422,
#   'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43183422',
#   'imageid': 42292,
#   'publiccaption': None,
#   'renditionnumber': '50849',
#   'width': 2093}]

# %% [markdown]
# This particular record has 6 images associated with it. Try copying and pasting some of the `baseimageurl`s in your browser:

# %%
for index, image in enumerate(ham_images, start=1):
    print(f"image {index} baseimageurl: {image['baseimageurl']}\nimage {index} iiifbaseuri: {image['iiifbaseuri']}\n")
# Out:
# image 1 baseimageurl: https://nrs.harvard.edu/urn-3:HUAM:DDC251942_dynmc
# image 1 iiifbaseuri: https://ids.lib.harvard.edu/ids/iiif/47174896
#
# image 2 baseimageurl: https://nrs.harvard.edu/urn-3:HUAM:DDC000072_dynmc
# image 2 iiifbaseuri: https://ids.lib.harvard.edu/ids/iiif/18737483
#
# image 3 baseimageurl: https://nrs.harvard.edu/urn-3:HUAM:DDC251934_dynmc
# image 3 iiifbaseuri: https://ids.lib.harvard.edu/ids/iiif/47174892
#
# image 4 baseimageurl: https://nrs.harvard.edu/urn-3:HUAM:30033_dynmc
# image 4 iiifbaseuri: https://ids.lib.harvard.edu/ids/iiif/43182083
#
# image 5 baseimageurl: https://nrs.harvard.edu/urn-3:HUAM:50493_dynmc
# image 5 iiifbaseuri: https://ids.lib.harvard.edu/ids/iiif/43183405
#
# image 6 baseimageurl: https://nrs.harvard.edu/urn-3:HUAM:50849_dynmc
# image 6 iiifbaseuri: https://ids.lib.harvard.edu/ids/iiif/43183422

# %% [markdown]
# You'll notice that the `baseimageurls` use Harvard's Name Resolution service, which redirects to an Image Delivery Service URL that displays the image. This is nice, but we're more interested in the `iiifbaseuris` because we can manipulate IIIF resources using the Image API. Try opening one of those. What happens?
#
# The IIIF Image API spec requires that we pass not just a baseurl, but a well-formed IIIF-compliant URI to get an image. Let's check out that [documentation](https://iiif.io/api/image/2.1/) and see what else we need to construct one of those.
#
# From the docs:
#
# >The IIIF Image API URI for requesting an image must conform to the following URI Template:
# >
# >`{scheme}://{server}{/prefix}/{identifier}/{region}/{size}/{rotation}/{quality}.{format}`
# >
# >For example:
# >
# >`http://www.example.org/image-service/abcd1234/full/full/0/default.jpg`
# >
# The parameters of the Image Request URI include region, size, rotation, quality and format, which define the characteristics of the returned image. These are described in detail in Image Request Parameters.
#
# The `iiifbaseuri`s include up through the `{identifier}`, but we need to include additional parameters to get the server to actually render the image for us. These parameters are passed within the URI itself, rather than in a query string appended after a delimiter (usually `?`), which is what we've been using `requests` to do. Let's write a function that can generate IIIF URIs for us. Because all of the parameters we want to insert are required, we won't use `**kwargs` - instead we'll set default params which you can override by passing in new ones.

# %%
def iiif_query(baseuri, region="full", size="full", rotation=0, quality="default", format="jpg", info=False):
    """Creates a valid IIIF URL, with the option to request image information"""
    if baseuri[-1:] != "/":
        baseuri += "/"
    if info == True:
        return baseuri+"info.json"
    else:
        url = baseuri+"{}/{}/{}/{}.{}".format(region, size, rotation, quality, format)
        return url

# %% [markdown]
# Now let's try using this function to display the images and links within our notebook. We'll need to add a few more modules to do this: `display`, `Image`, and `HTML`, all from `IPython.display`.

# %%
from IPython.display import display, Image, HTML
for img in ham_images:
    image_url = iiif_query(img['iiifbaseuri'])
    display(HTML("<a href='{}'>{}</a>".format(image_url,image_url)))
    display(Image(url=image_url, height=200, width=200))
# Out:
# <a href='https://ids.lib.harvard.edu/ids/iiif/47174896/full/full/0/default.jpg'>https://ids.lib.harvard.edu/ids/iiif/47174896/full/full/0/default.jpg</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/47174896/full/full/0/default.jpg" width="200" height="200"/>
# <a href='https://ids.lib.harvard.edu/ids/iiif/18737483/full/full/0/default.jpg'>https://ids.lib.harvard.edu/ids/iiif/18737483/full/full/0/default.jpg</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/18737483/full/full/0/default.jpg" width="200" height="200"/>
# <a href='https://ids.lib.harvard.edu/ids/iiif/47174892/full/full/0/default.jpg'>https://ids.lib.harvard.edu/ids/iiif/47174892/full/full/0/default.jpg</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/47174892/full/full/0/default.jpg" width="200" height="200"/>
# <a href='https://ids.lib.harvard.edu/ids/iiif/43182083/full/full/0/default.jpg'>https://ids.lib.harvard.edu/ids/iiif/43182083/full/full/0/default.jpg</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/43182083/full/full/0/default.jpg" width="200" height="200"/>
# <a href='https://ids.lib.harvard.edu/ids/iiif/43183405/full/full/0/default.jpg'>https://ids.lib.harvard.edu/ids/iiif/43183405/full/full/0/default.jpg</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/43183405/full/full/0/default.jpg" width="200" height="200"/>
# <a href='https://ids.lib.harvard.edu/ids/iiif/43183422/full/full/0/default.jpg'>https://ids.lib.harvard.edu/ids/iiif/43183422/full/full/0/default.jpg</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/43183422/full/full/0/default.jpg" width="200" height="200"/>

# %% [markdown]
# Now we have some valid image URLs! We've displayed the content of those URLs here directly using Jupyter's display and image libraries, but you can also open them in your browser directly!
#
# This is nice, but the Image API lets us do a lot more by just by passing in some parameters. Maybe we want to generate some square, grayscale images for a gallery:

# %%
for img in ham_images:
    image_url = iiif_query(img['iiifbaseuri'], quality="gray", region="square")
    display(HTML("<a href='{}'>{}</a>".format(image_url,image_url)))
    display(Image(url=image_url, height=200, width=200))
# Out:
# <a href='https://ids.lib.harvard.edu/ids/iiif/47174896/square/full/0/gray.jpg'>https://ids.lib.harvard.edu/ids/iiif/47174896/square/full/0/gray.jpg</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/47174896/square/full/0/gray.jpg" width="200" height="200"/>
# <a href='https://ids.lib.harvard.edu/ids/iiif/18737483/square/full/0/gray.jpg'>https://ids.lib.harvard.edu/ids/iiif/18737483/square/full/0/gray.jpg</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/18737483/square/full/0/gray.jpg" width="200" height="200"/>
# <a href='https://ids.lib.harvard.edu/ids/iiif/47174892/square/full/0/gray.jpg'>https://ids.lib.harvard.edu/ids/iiif/47174892/square/full/0/gray.jpg</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/47174892/square/full/0/gray.jpg" width="200" height="200"/>
# <a href='https://ids.lib.harvard.edu/ids/iiif/43182083/square/full/0/gray.jpg'>https://ids.lib.harvard.edu/ids/iiif/43182083/square/full/0/gray.jpg</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/43182083/square/full/0/gray.jpg" width="200" height="200"/>
# <a href='https://ids.lib.harvard.edu/ids/iiif/43183405/square/full/0/gray.jpg'>https://ids.lib.harvard.edu/ids/iiif/43183405/square/full/0/gray.jpg</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/43183405/square/full/0/gray.jpg" width="200" height="200"/>
# <a href='https://ids.lib.harvard.edu/ids/iiif/43183422/square/full/0/gray.jpg'>https://ids.lib.harvard.edu/ids/iiif/43183422/square/full/0/gray.jpg</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/43183422/square/full/0/gray.jpg" width="200" height="200"/>

# %% [markdown]
# ### IIIF Image API Exercise
# Let's try requesting only the right half of an image (using `region`), in black and white, and getting back a PNG:

# %%
# Write your code here
for img in ham_images:
    image_url = iiif_query(img['iiifbaseuri'], quality="bitonal", region="pct:50,0,100,100", format="png")
    display(HTML("<a href='{}'>{}</a>".format(image_url,image_url)))
    display(Image(url=image_url, height=200, width=200))
# Out:
# <a href='https://ids.lib.harvard.edu/ids/iiif/47174896/pct:50,0,100,100/full/0/bitonal.png'>https://ids.lib.harvard.edu/ids/iiif/47174896/pct:50,0,100,100/full/0/bitonal.png</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/47174896/pct:50,0,100,100/full/0/bitonal.png" width="200" height="200"/>
# <a href='https://ids.lib.harvard.edu/ids/iiif/18737483/pct:50,0,100,100/full/0/bitonal.png'>https://ids.lib.harvard.edu/ids/iiif/18737483/pct:50,0,100,100/full/0/bitonal.png</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/18737483/pct:50,0,100,100/full/0/bitonal.png" width="200" height="200"/>
# <a href='https://ids.lib.harvard.edu/ids/iiif/47174892/pct:50,0,100,100/full/0/bitonal.png'>https://ids.lib.harvard.edu/ids/iiif/47174892/pct:50,0,100,100/full/0/bitonal.png</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/47174892/pct:50,0,100,100/full/0/bitonal.png" width="200" height="200"/>
# <a href='https://ids.lib.harvard.edu/ids/iiif/43182083/pct:50,0,100,100/full/0/bitonal.png'>https://ids.lib.harvard.edu/ids/iiif/43182083/pct:50,0,100,100/full/0/bitonal.png</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/43182083/pct:50,0,100,100/full/0/bitonal.png" width="200" height="200"/>
# <a href='https://ids.lib.harvard.edu/ids/iiif/43183405/pct:50,0,100,100/full/0/bitonal.png'>https://ids.lib.harvard.edu/ids/iiif/43183405/pct:50,0,100,100/full/0/bitonal.png</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/43183405/pct:50,0,100,100/full/0/bitonal.png" width="200" height="200"/>
# <a href='https://ids.lib.harvard.edu/ids/iiif/43183422/pct:50,0,100,100/full/0/bitonal.png'>https://ids.lib.harvard.edu/ids/iiif/43183422/pct:50,0,100,100/full/0/bitonal.png</a>
# <img src="https://ids.lib.harvard.edu/ids/iiif/43183422/pct:50,0,100,100/full/0/bitonal.png" width="200" height="200"/>

# %% [markdown]
# Feel free to try to manipulate the images in other ways as well! That's it for our quick introduction to the Image API.

# %% [markdown]
# ### IIIF Presentation API
#
# If you're interested in the Presi API (for presenting structured IIIF resources as part of a more fully-functional web app), check out [this documentation](https://iiif.io/api/presentation/2.1/) to learn how IIIF manifests structure sequences of canvases which image viewers then present to end users. You can find an HAM Object's manifest in the `seeAlso` field, or by by appending the object ID to a baseurl:

# %%
print(topResult['seeAlso'])
print('https://iiif.harvardartmuseums.org/manifests/object/{}'.format(topResult['id']))

# %% [markdown]
# #### Mirador
#
# You can consume these resources using [Mirador](http://projectmirador.org/), an image viewer which uses the IIIF Image and Presentation APIs. We used to use Mirador in a different version of this workshop which integrated Omeka, a content management system.
#
# If you head to the [Project Mirador Demo](http://projectmirador.org/) page, you can add a new manifest in the top left ("four boxes icon" -> "Replace Object" -> "Add new object from URL"). Paste in your manifest URL there.
#
# Example manifest URL for the second most viewed painting, "The Gare Saint-Lazare: Arrival of a Train": https://iiif.harvardartmuseums.org/manifests/object/228649

# %% [markdown]
# ## More stuff!
#
# So far, we've only been getting limited sets of object data. But what if there were a big query we wanted to make? Let's try it out on "Unidentified culture" materials in the museum.

# %%
unknown = ham_query(APIKEY, "object", culture="Unidentified culture", size=100).json()

# %% [markdown]
# Looking at our previous queries, it looks like we've got some information about our query in the "info" section. Let's take a look at that...

# %%
unknown['info']
# Out:
# {'next': 'https://api.harvardartmuseums.org/object?culture=Unidentified%20culture&size=100&apikey=622b6240-e14a-11e8-9234-6f5a1db33697&page=2',
#  'page': 1,
#  'pages': 7,
#  'totalrecords': 607,
#  'totalrecordsperquery': 100}

# %% [markdown]
# ### Iterating through pages
#
# It looks like we have 7 pages of data to get, and our response gives us a "next" url for easy iteration. Nice!
#
# However, let's look at how we would iterate even without this convenience factor.

# %%
unknown.keys()
# Out:
# dict_keys(['info', 'records'])

# %% [markdown]
# It looks like we have two components to our response, info and records. Since `info` is request specific, we're just after `records`, and we'll want to combine them all.
#
# We could set this up in a regular loop, which would query the API as fast as our processors can go, which can produce many queries per second, and is usually limited more by network speed than by processor speed. However, this can put a strain on the API endpoint, so it can be good practice to build in timers when making many requests. Sometimes an API will specify a number of requests/second that you're allowed to make, sometimes not. Putting even a fraction of a second delay in your code will help make sure that you don't accidentally get yourself banned from the API.

# %%
import time

# %%
unknown_records = []
keepGoing = True
page = 1

while keepGoing:
    R = ham_query(APIKEY, "object", culture="Unidentified culture", size=100, page=page)
    time.sleep(0.5)
    response = R.json()
    unknown_records.extend(response['records'])
    if response['info']['pages'] == page:
        keepGoing = False
    else:
        page += 1

# %%
len(unknown_records)
# Out:
# 607

# %%
unknown_records[0]
# Out:
# {'accessionmethod': 'Gift',
#  'accessionyear': 1952,
#  'accesslevel': 1,
#  'century': '19th century',
#  'classification': 'Drawings',
#  'classificationid': 21,
#  'colorcount': 0,
#  'commentary': None,
#  'contact': 'am_europeanamerican@harvard.edu',
#  'contextualtextcount': 0,
#  'copyright': None,
#  'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Agnes Mongan',
#  'culture': 'Unidentified culture',
#  'datebegin': 0,
#  'dated': '19th century',
#  'dateend': 0,
#  'dateoffirstpageview': '2009-08-30',
#  'dateoflastpageview': '2015-12-13',
#  'department': 'Department of Drawings',
#  'description': None,
#  'dimensions': 'actual: 10.7 x 10 cm (4 3/16 x 3 15/16 in.)',
#  'division': 'European and American Art',
#  'edition': None,
#  'exhibitioncount': 0,
#  'groupcount': 0,
#  'id': 296822,
#  'imagecount': 1,
#  'imagepermissionlevel': 0,
#  'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV002983_dynmc',
#    'copyright': 'President and Fellows of Harvard College',
#    'displayorder': 1,
#    'format': 'image/jpeg',
#    'height': 1024,
#    'idsid': 18741987,
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18741987',
#    'imageid': 109476,
#    'publiccaption': None,
#    'renditionnumber': 'INV002983',
#    'width': 965}],
#  'labeltext': None,
#  'lastupdate': '2019-11-06T06:18:16-0500',
#  'markscount': 0,
#  'mediacount': 0,
#  'medium': 'Brown ink, brown wash, and white gouache on cream paper',
#  'objectid': 296822,
#  'objectnumber': '1952.106',
#  'people': [{'alphasort': 'Unidentified Artist',
#    'birthplace': None,
#    'culture': None,
#    'deathplace': None,
#    'displaydate': None,
#    'displayname': 'Unidentified Artist',
#    'displayorder': 1,
#    'gender': 'unknown',
#    'name': 'Unidentified Artist',
#    'personid': 34147,
#    'prefix': None,
#    'role': 'Artist'}],
#  'peoplecount': 1,
#  'period': None,
#  'periodid': None,
#  'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV002983_dynmc',
#  'provenance': None,
#  'publicationcount': 0,
#  'rank': 80229,
#  'relatedcount': 0,
#  'seeAlso': [{'format': 'application/json',
#    'id': 'https://iiif.harvardartmuseums.org/manifests/object/296822',
#    'profile': 'http://iiif.io/api/presentation/2/context.json',
#    'type': 'IIIF Manifest'}],
#  'signed': None,
#  'standardreferencenumber': None,
#  'state': None,
#  'style': None,
#  'technique': None,
#  'techniqueid': None,
#  'title': 'Madonna and Child and Saints',
#  'titlescount': 1,
#  'totalpageviews': 4,
#  'totaluniquepageviews': 3,
#  'url': 'https://www.harvardartmuseums.org/collections/object/296822',
#  'verificationlevel': 3,
#  'verificationleveldescription': 'Good. Object is well described and information is vetted',
#  'worktypes': [{'worktype': 'drawing', 'worktypeid': '125'}]}

# %% [markdown]
# # Enhancing Data
#
# We've now used Python and the Art Museum API to create a custom dataset. We've also played with the IIIF Image API to programmatically alter images. In this next section, we're going to provide you space to experiment and enhance your dataset by using a third API to join an additional datasource. We're going to provide some directions for an exercise using GeoNames and Folium, a wrapper for the Javascript mapping library Leaflet. But you're also free to find another API such as Wikidata, the Getty Union List of Artist Names, or the Google Vision API.
#
# ## Overview
# - Pick a current exhibit to examine; find fields that can be geocoded
# - Use the GeoNames API to geocode those fields
# - Display the points as markers on a Leaflet map
#
# ## Working with HAM Exhibits
# Let's start by picking one current exhibit to examine. We've already stored this data in `current_exhibits`.
# - We'll want to pick an exhibit that has a number of people associated with it, so that we have multiple locations to georeference.
# - People are stored in `exhibit['records']['people']`. Take a look at these and see what we could geocode.
# - Within each record, this is stored in a `peoplecount` field (eg `exhibit['records']['peoplecount']`).
# - You'll need to do a new query to the `object` API for each exhibit.
# - Let's sum these up to get a quick count of people associated with each exhibit. Sort the exhibits by this count, and print those along with the exhibit names and IDs.

# %%
# Write code here!

# %%
for e in current_exhibits:
    R = ham_query(APIKEY, 'object', exhibition=e['id'], size=100)
    time.sleep(0.5)
    print(e['title'], e['id'])
    print(sum([r['peoplecount'] for r in R.json()['records']]))
    print()
# Out:
# Davis Museum Permanent Gallery reinstallation 5172
# 0
#
# Clay—Modeling African Design 5820
# 9
#
# Charlotte Posenenske: A Retrospective 5593
# 2
#
# Gauguin: Portraits 5471
# 1
#
# Manet and Modern Beauty 5477
# 1
#
# Hyman Bloom: A Matter of Life and Death 5777
# 4
#
# Through a Glass, Darkly: Allegory and Faith in Netherlandish Prints from Lucas van Leyden to Rembrandt 5697
# 15
#
# Woven Interiors: Early Medieval Textiles of the Eastern Mediterranean 5506
# 1
#
# Winslow Homer: Eyewitness 5660
# 122
#
# Early Christian Africa: Arts of Transformation 5924
# 5
#
# Critical Printing 5925
# 26
#
# Dharma and Pūnya: Buddhist Ritual Art of Nepal 5281
# 1
#
# Unto This Last: Two Hundred Years of John Ruskin 5713
# 2
#
# In a Cloud, in a Wall, in a Chair: Modernists in Mexico at Midcentury 5805
# 1
#
# Crossing Lines, Constructing Home: Displacement and Belonging in Contemporary Art 5834
# 40
#
# William Blake 5759
# 3
#
# City of Dreams. Lyonel Feininger and His Villages 5559
# 5
#
# Zarina: Atlas of Her World  5866
# 1
#
# John Singer Sargent: Portraits in Charcoal 5652
# 1
#
# Nam June Paik: The Future is Now 5846
# 6
#
# Thomas Jefferson Architect: Palladian Models, Democratic Principles, and the Conflict of Ideals 5674
# 1
#
# The Eternal Feast: Banqueting in 10th-14th Century Chinese Art 5828
# 0
#
# Monet: The Truth of Nature 5619
# 1
#
# Galerie St. Etienne 80th anniversary 5859
# 1
#
# Rachel Harrison 5766
# 1
#
# Counter-Landscapes: Performative Actions from the 1970's - now 5860
# 1
#
# Edward Hopper and the American Hotel 5698
# 1
#
# Young Rembrandt 5658
# 1

# %% [markdown]
# Pick two of the top three exhibits to further examine.
# - Store all the objects in those exhibits
# - Store the exhibition information (endpoint `exhibition`) as well

# %%
ham_query(APIKEY, 'object', exhibition=5660, size=100).json()['info']['pages']
# Out:
# 1

# %%
eyewitness_objects = ham_query(APIKEY, 'object', exhibition=5660, size=100).json()['records']

# %%
len(eyewitness_objects)
# Out:
# 56

# %%
eyewitness_exhibit = ham_query_with_id(APIKEY, 'exhibition', 5660).json()
eyewitness_exhibit
# Out:
# {'begindate': '2019-08-31',
#  'color': None,
#  'description': None,
#  'enddate': '2020-01-05',
#  'exhibitionid': 5660,
#  'id': 5660,
#  'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG270275',
#    'caption': 'Winslow Homer, Prisoners from the Front, 1866. Oil on canvas. The Metropolitan Museum of Art, New York, Gift of Mrs. Frank B. Porter, 1922, 22.207, TL42108. Photo: © The Metropolitan Museum of Art. Image source: Art Resource, NY.',
#    'copyright': 'Image copyright © The Metropolitn Museum of Art. Image source: Art Resource, NY',
#    'displayorder': 1,
#    'format': 'image/jpeg',
#    'height': 1606,
#    'idsid': 462607066,
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/462607066',
#    'imageid': 495715,
#    'renditionnumber': 'LEG270275',
#    'width': 2550}],
#  'lastupdate': '2019-11-06T05:06:53-0500',
#  'people': [{'displayname': 'Curated by Ethan Lasser',
#    'displayorder': 1,
#    'name': 'Ethan Lasser',
#    'personid': 58267,
#    'prefix': 'Curated by',
#    'role': 'Curator'},
#   {'displayname': 'Curated by Makeda Best',
#    'displayorder': 2,
#    'name': 'Makeda Best',
#    'personid': 63840,
#    'prefix': 'Curated by',
#    'role': 'Curator'}],
#  'poster': {'caption': 'Winslow Homer, Prisoners from the Front, 1866. Oil on canvas. The Metropolitan Museum of Art, New York, Gift of Mrs. Frank B. Porter, 1922, 22.207, TL42108. Photo: © The Metropolitan Museum of Art. Image source: Art Resource, NY.',
#   'imageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG270275'},
#  'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG270275',
#  'shortdescription': None,
#  'temporalorder': 4612,
#  'textiledescription': 'Discover how celebrated American artist Winslow Homer’s work for the illustrated periodical _Harper’s Weekly_ helped shape his later career as a painter and watercolorist.\r\n\r\nDuring the Civil War (1861–1865), American artist Winslow Homer (1836–1910) served as a correspondent for _Harper’s_. His sketches of soldiers, both in battle on the front lines and in quieter moments back at camp, were reproduced to accompany the journal’s accounts of the conflict. Homer worked for _Harper’s_ just as new technologies were making it possible to rapidly reproduce newsworthy images on a large scale. Working together with _Harper’s_ editors and engravers, he employed a range of pictorial strategies to reassure skeptical readers that his illustrations were not fabrications, but eyewitness observations “drawn on the spot.”\r\n\r\nWhile in the field as an artist-correspondent, Homer developed habits of seeing and pictorial strategies that informed his work in other media. In addition to tracing these connections, this show explores broader questions that Homer’s art raises about the responsibility of artists who work in periods riven by war and conflict.\r\n\r\nCo-curated by Ethan W. Lasser, Theodore E. Stebbins Jr. Curator of American Art and Head of the Division of European and American Art; and Makeda Best, Richard L. Menschel Curator of Photography; with the assistance of Oliver Wunsch, former Maher Curatorial Fellow of American Art (2018–19), Harvard Art Museums.\r\n\r\nSupport for this exhibition was provided by the Bolton Fund for American Art, Gift of the Payne Fund; and the Henry Luce Foundation Fund for the American Art Department. Exhibition-related programming is made possible by the Richard L. Menschel Endowment Fund and the M. Victor Leventritt Lecture Series Endowment Fund.\r\n\r\n*Related Exhibition*\r\n"_Homer at the Beach: A Marine Painter\'s Journey, 1869-1880_":https://www.capeannmuseum.org/exhibitions/homer-beach/ is on view at the Cape Ann Museum August 3–December 1, 2019.',
#  'title': 'Winslow Homer: Eyewitness',
#  'url': 'https://www.harvardartmuseums.org/visit/exhibitions/5660',
#  'venues': [{'address1': '32 Quincy St.',
#    'address2': None,
#    'begindate': '2019-08-31',
#    'city': 'Cambridge',
#    'country': None,
#    'enddate': '2020-01-05',
#    'fullname': 'Harvard Art Museums',
#    'galleries': [{'floor': 3,
#      'galleryid': 3600,
#      'gallerynumber': '3600',
#      'name': 'University Research Gallery'}],
#    'ishamvenue': 1,
#    'name': 'Harvard Art Museums',
#    'state': 'MA',
#    'venueid': 55780,
#    'zipcode': '02138'}]}

# %% [markdown]
# ## Geonames API
#
# Let's start by checking out the JSON version of the [GeoNames API](http://www.geonames.org/export/JSON-webservices.html).
#
# - Write a function that hits `searchJSON` and geocodes a placename. It should return the latitude and longitude (`lat` and `lng`) of the top result. You'll need to include your GeoNames username in the API calls.

# %%
USERNAME = 'cdc43339'
def search_place(placename):
    """Searches the GeoNames searchJSON endpoint for a placename, returning a latitude and longitude"""
    # Your code here
    endpoint = "http://api.geonames.org/searchJSON"
    parameters = {
        "username": USERNAME,
        "q": placename
    }
    R = requests.get(endpoint, params=parameters)
    top = R.json()['geonames'][0]
    # print(f"{top['name']}")
    return top['lat'], top['lng']

# %%
print(search_place("London, UK"))
# Out:
# ('51.50853', '-0.12574')

# %% [markdown]
# - Write another function which takes an exhibit, gets all the people in the exhibit, and geocodes their birthplace and deathplace. The function should return a dictionary of people objects that also have `birthplace_coordinates` and `deathplace_coordinates` attributes. Be warned that not every person will have a birthplace and/or deathplace.

# %%
def geocode_exhibit_people_locations(exhibit):
    exhibit_people = {}
    for record in exhibit:
        if record['peoplecount'] > 0:
            record_people = record['people']
        for person in record_people:
            if person['birthplace'] is not None:
                person['birthplace_coordinates'] = search_place(person['birthplace'])
            if person['deathplace'] is not None:
                person['deathplace_coordinates'] = search_place(person['deathplace'])
        exhibit_people[record['id']] = record_people
    return exhibit_people

# %%
eyewitness_people = geocode_exhibit_people_locations(eyewitness_objects)

# %%
print(eyewitness_people)
# Out:
# {256334: [{'alphasort': 'Homer, Winslow', 'birthplace': 'Boston, MA', 'name': 'Winslow Homer', 'prefix': 'After', 'personid': 26501, 'gender': 'male', 'role': 'Artist', 'displayorder': 1, 'culture': 'American', 'displaydate': '1836 - 1910', 'deathplace': 'Prouts Neck, ME', 'displayname': 'After Winslow Homer', 'birthplace_coordinates': ('42.35843', '-71.05977'), 'deathplace_coordinates': ('43.53342', '-70.31449')}, {'alphasort': 'Unidentified Artist', 'birthplace': None, 'name': 'Unidentified Artist', 'prefix': 'Engraved by', 'personid': 34147, 'gender': 'unknown', 'role': 'Artist', 'displayorder': 2, 'culture': None, 'displaydate': None, 'deathplace': None, 'displayname': 'Engraved by Unidentified Artist'}], 256471: [{'alphasort': 'Homer, Winslow', 'birthplace': 'Boston, MA', 'name': 'Winslow Homer', 'prefix': 'After', 'personid': 26501, 'gender': 'male', 'role': 'Artist', 'displayorder': 1, 'culture': 'American', 'displaydate': '1836 - 1910', 'deathplace': 'Prouts Neck, ME', 'displayname': 'After Winslow Homer', 'birthplace_coordinates': ('42.35843', '-71.05977'), 'deathplace_coordinates': ('43.53342', '-70.31449')}, {'alphasort': 'Unidentified Artist', 'birthplace': None, 'name': 'Unidentified Artist', 'prefix': 'Engraved by', 'personid': 34147, 'gender': 'unknown', 'role': 'Artist', 'displayorder': 2, 'culture': None, 'displaydate': None, 'deathplace': None, 'displayname': 'Engraved by Unidentified Artist'}], 256788: [{'alphasort': 'Homer, Winslow', 'birthplace': 'Boston, MA', 'name': 'Winslow Homer', 'prefix': 'After', 'personid': 26501, 'gender': 'male', 'role': 'Artist', 'displayorder': 1, 'culture': 'American', 'displaydate': '1836 - 1910', 'deathplace': 'Prouts Neck, ME', 'displayname': 'After Winslow Homer', 'birthplace_coordinates': ('42.35843', '-71.05977'), 'deathplace_coordinates': ('43.53342', '-70.31449')}, {'alphasort': 'Unidentified Artist', 'birthplace': None, 'name': 'Unidentified Artist', 'prefix': 'Engraved by', 'personid': 34147, 'gender': 'unknown', 'role': 'Artist', 'displayorder': 2, 'culture': None, 'displaydate': None, 'deathplace': None, 'displayname': 'Engraved by Unidentified Artist'}], 230621: [{'alphasort': 'Homer, Winslow', 'birthplace': 'Boston, MA', 'name': 'Winslow Homer', 'prefix': None, 'personid': 26501, 'gender': 'male', 'role': 'Artist', 'displayorder': 1, 'culture': 'American', 'displaydate': '1836 - 1910', 'deathplace': 'Prouts Neck, ME', 'displayname': 'Winslow Homer', 'birthplace_coordinates': ('42.35843', '-71.05977'), 'deathplace_coordinates': ('43.53342', '-70.31449')}], 231372: [{'alphasort': 'Mathew B. Brady & Studio', 'birthplace': 'Warren County, New York', 'name': 'Mathew B. Brady & Studio', 'prefix': None, 'personid': 29389, 'gender': 'unknown', 'role': 'Artist', 'displayorder': 1, 'culture': 'American', 'displaydate': 'active 1844 - 1895', 'deathplace': 'New York, New York', 'displayname': 'Mathew B. Brady & Studio', 'birthplace_coordinates': ('43.30952', '-73.64401'), 'deathplace_coordinates': ('40.71427', '-74.00597')}, {'alphasort': "Brady's National Portrait Gallery", 'birthplace': None, 'name': "Brady's National Portrait Gallery", 'prefix': None, 'personid': 18035, 'gender': 'unknown', 'role': 'Artist', 'displayorder': 2, 'culture': 'American', 'displaydate': '1860-1894', 'deathplace': None, 'displayname': "Brady's National Portrait Gallery"}, {'alphasort': 'Anthony & Co.', 'birthplace': None, 'name': 'Anthony & Co.', 'prefix': None, 'personid': 35161, 'gender': 'unknown', 'role': 'Publisher', 'displayorder': 3, 'culture': 'American', 'displaydate': 'active 1862-1901', 'deathplace': None, 'displayname': 'Anthony & Co.'}, {'alphasort': 'Ellsworth, Elmer Ephraim Colonel', 'birthplace': None, 'name': 'Colonel Elmer Ephraim Ellsworth', 'prefix': None, 'personid': 17831, 'gender': 'unknown', 'role': 'Sitter', 'displayorder': 4, 'culture': None, 'displaydate': None, 'deathplace': None, 'displayname': 'Colonel Elmer Ephraim Ellsworth'}], 299839: [{'alphasort': 'Homer, Winsl ...

# %% [markdown]
# ## Folium and Leaflet

# %% [markdown]
# We can use [Folium](https://python-visualization.github.io/folium/index.html) to incorporate [Leaflet](https://leafletjs.com/reference-1.5.0.html), an open-source JavaScript library for interactive web maps. Here are some more Folium examples: https://nbviewer.jupyter.org/github/python-visualization/folium/tree/master/examples/.
# - Check out both the Folium library documentation and the Leaflet API documentation to understand how Leaflet maps are implemented.
# - Install Folium if you haven't already: `conda install folium -c conda-forge` or `pip install folium`
# - Import Folium and create a map object. Folium has a number of different basemap options and other possible configurations - check out the documentation to customize the look of your map.

# %%
import folium
people_map = folium.Map(
    zoom_start=8,
    tiles='Stamen Toner'
)

mk = folium.features.Marker([0, 0])
pp = folium.Popup('hello')
ic = folium.features.Icon(color='red')

mk.add_child(ic)
mk.add_child(pp)
people_map.add_child(mk)

people_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - Create a function which can add people to the map as markers. The function should accept an object or list of people; a map, to which the markers will be added; and any other parameters you'd like
# - Label each marker with the person's name and the location.
# - Bonus points for creating different colored markers for birth and death locations and for styling the label / making it more readable.

# %%
def add_people_to_map(people, leaflet_map):
        """Adds people as markers to a Leaflet map"""
    for painting_id in people:
        p = people[painting_id]
        for person in p:
        # your code here

# %% [markdown]
# ## Exporting
#
# Now we have some cool data, but maybe we want to do something with it outside of Python. It's common to see CSV data traded around, since it's just a plain text spreadsheet file, so most things can parse it. Let's make one of those! We could use the relatively low level `csv` library, but instead, let's use a higher level library, `pandas`

# %%
import pandas as pd # Common invocation of pandas. Gotta save those 4 keystrokes.

# %% [markdown]
# ### "Be a dataframe!" - us
#
# Pandas thinks of things in terms of dataframes, which will be familiar if you work in R. Basically, they're really efficient arrays of data. They also translate really well to a tabular format.
#
# To make an iterable object into a dataframe, sometimes you can just get away with shouting "Hey you! Be a dataframe!" at it (in code). Since we have a list of dictionaries with consistent keys, there's a good chance this process will do something smart for us:

# %%
pd.DataFrame(unknown_records).head()
# Out:
#   accessionmethod  accessionyear  accesslevel               century  \
# 0            Gift         1952.0            1          19th century
# 1        Purchase         2004.0            1          19th century
# 2            Gift         1995.0            1  Unidentified century
# 3            Gift         1969.0            1  Unidentified century
# 4            Gift         1995.0            1  Unidentified century
#
#   classification  classificationid  colorcount colors commentary  \
# 0       Drawings                21           0    NaN       None
# 1    Photographs                17           0    NaN       None
# 2        Amulets               180           0    NaN       None
# 3      Sculpture                30           0    NaN       None
# 4        Amulets               180           0    NaN       None
#
#                              contact  \
# 0    am_europeanamerican@harvard.edu
# 1    am_europeanamerican@harvard.edu
# 2  am_asianmediterranean@harvard.edu
# 3  am_asianmediterranean@harvard.edu
# 4  am_asianmediterranean@harvard.edu
#
#                          ...                                       technique  \
# 0                        ...                                            None
# 1                        ...                            Albumen silver print
# 2                        ...                          Cast, lost-wax process
# 3                        ...                          Cast, lost-wax process
# 4                        ...                          Cast, lost-wax process
#
#   techniqueid                                              title titlescount  \
# 0         NaN                       Madonna and Child and Saints           1
# 1       110.0  Untitled (album page with architectural studie...           1
# 2      1311.0          Phallic Amulet with Snail-Shell Testicles           1
# 3      1311.0                                        Double Hand           1
# 4      1311.0                          Phallic Amulet with Wings           1
#
#    totalpageviews totaluniquepageviews  \
# 0               4                    3
# 1               0                    0
# 2             247                  224
# 3               4                    3
# 4             189                  160
#
#                                                  url verificationlevel  \
# 0  https://www.harvardartmuseums.org/collections/...                 3
# 1  https://www.harvardartmuseums.org/collections/...                 2
# 2  https://www.harvardartmuseums.org/collections/...                 4
# 3  https://www.harvardartmuseums.org/collections/...                 4
# 4  https://www.harvardartmuseums.org/collections/...                 4
#
#                         verificationleveldescription  \
# 0  Good. Object is well described and information...
# 1  Adequate. Object is adequately described but i...
# 2  Best. Object is extensively researched, well d...
# 3  Best. Object is extensively researched, well d...
# 4  Best. Object is extensively researched, well d...
#
#                                            worktypes
# 0     [{'worktypeid': '125', 'worktype': 'drawing'}]
# 1  [{'worktypeid': '259', 'worktype': 'photograph'}]
# 2       [{'worktypeid': '12', 'worktype': 'amulet'}]
# 3   [{'worktypeid': '317', 'worktype': 'sculpture'}]
# 4       [{'worktypeid': '12', 'worktype': 'amulet'}]
#
# [5 rows x 62 columns]

# %% [markdown]
# What do you know! It worked. But let's take a look at a more hands on approach to the same thing.

# %%
pd.DataFrame.from_dict(unknown_records).head()
# Out:
#   accessionmethod  accessionyear  accesslevel               century  \
# 0            Gift         1952.0            1          19th century
# 1        Purchase         2004.0            1          19th century
# 2            Gift         1995.0            1  Unidentified century
# 3            Gift         1969.0            1  Unidentified century
# 4            Gift         1995.0            1  Unidentified century
#
#   classification  classificationid  colorcount colors commentary  \
# 0       Drawings                21           0    NaN       None
# 1    Photographs                17           0    NaN       None
# 2        Amulets               180           0    NaN       None
# 3      Sculpture                30           0    NaN       None
# 4        Amulets               180           0    NaN       None
#
#                              contact  \
# 0    am_europeanamerican@harvard.edu
# 1    am_europeanamerican@harvard.edu
# 2  am_asianmediterranean@harvard.edu
# 3  am_asianmediterranean@harvard.edu
# 4  am_asianmediterranean@harvard.edu
#
#                          ...                                       technique  \
# 0                        ...                                            None
# 1                        ...                            Albumen silver print
# 2                        ...                          Cast, lost-wax process
# 3                        ...                          Cast, lost-wax process
# 4                        ...                          Cast, lost-wax process
#
#   techniqueid                                              title titlescount  \
# 0         NaN                       Madonna and Child and Saints           1
# 1       110.0  Untitled (album page with architectural studie...           1
# 2      1311.0          Phallic Amulet with Snail-Shell Testicles           1
# 3      1311.0                                        Double Hand           1
# 4      1311.0                          Phallic Amulet with Wings           1
#
#    totalpageviews totaluniquepageviews  \
# 0               4                    3
# 1               0                    0
# 2             247                  224
# 3               4                    3
# 4             189                  160
#
#                                                  url verificationlevel  \
# 0  https://www.harvardartmuseums.org/collections/...                 3
# 1  https://www.harvardartmuseums.org/collections/...                 2
# 2  https://www.harvardartmuseums.org/collections/...                 4
# 3  https://www.harvardartmuseums.org/collections/...                 4
# 4  https://www.harvardartmuseums.org/collections/...                 4
#
#                         verificationleveldescription  \
# 0  Good. Object is well described and information...
# 1  Adequate. Object is adequately described but i...
# 2  Best. Object is extensively researched, well d...
# 3  Best. Object is extensively researched, well d...
# 4  Best. Object is extensively researched, well d...
#
#                                            worktypes
# 0     [{'worktypeid': '125', 'worktype': 'drawing'}]
# 1  [{'worktypeid': '259', 'worktype': 'photograph'}]
# 2       [{'worktypeid': '12', 'worktype': 'amulet'}]
# 3   [{'worktypeid': '317', 'worktype': 'sculpture'}]
# 4       [{'worktypeid': '12', 'worktype': 'amulet'}]
#
# [5 rows x 62 columns]

# %% [markdown]
# `pd.DataFrame.from_dict` gives you more control over the conversion process, so you can provide more options if things don't look how you expect them to.
#
# As a side note, we do have some data structures in here that don't make a lot of sense in a tabular format. Look at `worktypes` at the very end. That's a list, and each cell has list data in it. We won't be able to do much with that in Excel or some other tabular data processing tool, but it also won't break anything for us. It just looks weird. Within the dataframe, they still work like lists though, so you can access the data while you're still in Python if you're clever about it.
#
# ### Exporting
#
# From here, our export process is really easy. We just say "Hey you! Be a CSV file now!", and so it shall be.

# %%
df = pd.DataFrame(unknown_records)

# %%
df.to_csv("unknown_ham_records.csv",index=None)

# %% [markdown]
# # Data collected!
#
# Now we've got some interesting data and exported it. We could throw it at a program like Tableau or Excel to visualize it or further explore it. We could also continue to explore it in Python. Another options would be to remix it into an Omeka site. This is a good option if you're interested in exploring other RESTful methods, like `POST`, `DELETE`, or `UPDATE.` Check out the `Omeka` notebook for more information on how to pull off a big data heist!
#
# *Not a real heist, we are using freely available data that the museum has generously made available. Please do not steal any physical art.*
