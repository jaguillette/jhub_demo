# %% [markdown]
# # Working with APIs in Python
#
# You may have heard of an "API", and you may even have a notion that APIs might be a tool for getting access to interesting information, but they're difficult to use without any coding. With a Jupyter notebook, you still need to write code, but you don't need to write one perfect script to do exactly what you want the first time around. You can experiment and look at what each line of code does.
#
# As an example, the Harvard Art Museums provide access to a ton of information about their collections, available through a pretty simple API.
#
# Here's some [API documentation](https://github.com/harvardartmuseums/api-docs/blob/master/sections/object.md) and a [sample API query](https://api.harvardartmuseums.org/object?q=totalpageviews:0&size=10&apikey=6dd7b080-3635-11ea-851d-67c3f7f3cf76).

# %%
import requests
import random
import csv

# %% [markdown]
# ## Authentication
#
# You'll have to authenticate each request to the Harvard Art Museum API with an API key. Other APIs may require different kinds of authentication (sometimes very complicated auth! Look for libraries at that point), but HAM has some pretty simple authentication, which makes things easy for us.
#
# You can sign up for a key [here](https://www.harvardartmuseums.org/collections/api). Documentation for the entire API is hosted on GitHub and can be viewed [here](https://github.com/harvardartmuseums/api-docs).

# %%
APIKEY = "6dd7b080-3635-11ea-851d-67c3f7f3cf76"

# %% [markdown]
# ## Basic request
#
# We're going to start off with a basic request to the API. This API, like many others, has a variety of endpoints, each with their own url, slightly modified from a base url. We'll worry about the general case in a bit, for now let's look at a basic API request.
#
# In this example, we'll re-create the first example in the [Object endpoint documentation](https://github.com/harvardartmuseums/api-docs/blob/master/sections/object.md), which will give each of you the records for 10 objects that have never been viewed online in the museum's collections.

# %%
url = "https://api.harvardartmuseums.org/object"
parameters = {
    "size":100,
    "apikey":APIKEY,
    "sort":'totalpageviews',
    "sortorder":"desc"
}
R = requests.get(url,params=parameters)
results = R.json()
results
# Out:
# {'info': {'next': 'https://api.harvardartmuseums.org/object?size=100&apikey=6dd7b080-3635-11ea-851d-67c3f7f3cf76&sort=totalpageviews&sortorder=desc&page=2',
#   'page': 1,
#   'pages': 2340,
#   'totalrecords': 233927,
#   'totalrecordsperquery': 100},
#  'records': [{'accessionmethod': 'Bequest',
#    'accessionyear': 1951,
#    'accesslevel': 1,
#    'century': '19th century',
#    'classification': 'Paintings',
#    'classificationid': 26,
#    'colorcount': 10,
#    'colors': [{'color': '#64af7d',
#      'css3': '#5f9ea0',
#      'hue': 'Green',
#      'percent': 0.2979781420765,
#      'spectrum': '#4fb94f'},
#     {'color': '#64c896',
#      'css3': '#66cdaa',
#      'hue': 'Green',
#      'percent': 0.21289617486339,
#      'spectrum': '#47b853'},
#     {'color': '#323219',
#      'css3': '#2f4f4f',
#      'hue': 'Brown',
#      'percent': 0.19814207650273,
#      'spectrum': '#3db657'},
#     {'color': '#7d7d4b',
#      'css3': '#696969',
#      'hue': 'Green',
#      'percent': 0.056775956284153,
#      'spectrum': '#6cbd45'},
#     {'color': '#969664',
#      'css3': '#808080',
#      'hue': 'Green',
#      'percent': 0.043715846994536,
#      'spectrum': '#84c441'},
#     {'color': '#afaf7d',
#      'css3': '#bdb76b',
#      'hue': 'Green',
#      'percent': 0.042622950819672,
#      'spectrum': '#9ecb3b'},
#     {'color': '#4b9664',
#      'css3': '#2e8b57',
#      'hue': 'Green',
#      'percent': 0.036885245901639,
#      'spectrum': '#3db657'},
#     {'color': '#191919',
#      'css3': '#000000',
#      'hue': 'Grey',
#      'percent': 0.034972677595628,
#      'spectrum': '#1eb264'},
#     {'color': '#644b19',
#      'css3': '#8b4513',
#      'hue': 'Orange',
#      'percent': 0.032295081967213,
#      'spectrum': '#64bc46'},
#     {'color': '#647d64',
#      'css3': '#696969',
#      'hue': 'Green',
#      'percent': 0.018032786885246,
#      'spectrum': '#4fb94f'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest from the Collection of Maurice Wertheim, Class of 1906',
#    'culture': 'Dutch',
#    'datebegin': 1888,
#    'dated': '1888',
#    'dateend': 1888,
#    'dateoffirstpageview': '2009-05-12',
#    'dateoflastpageview': '2020-01-13',
#    'department': 'Department of Paintings, Sculpture & Decorative Arts',
#    'description': None,
#    'dimensions': '61.5 x 50.3 cm (24 3/16 x 19 13/16 in.)\r\nframed: 90.4 x 79.7 x 8.3 cm (35 9/16 x 31 3/8 x 3 1/4 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 26,
#    'groupcount': 3,
#    'id': 299843,
#    'imagecount': 6,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC251942_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 47174896,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/47174896',
#      'imageid': 429030,
#      'publiccaption': None,
#      'renditionnumber': 'DDC251942',
#      'width': 2087},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC000072_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 18737483,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18737483',
#      'imageid': 185978,
#      'publiccaption': None,
#      'renditionnumber': 'DDC000072',
#      'width': 2088},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC251934_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 47174892,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/47174892',
#      'imageid': 429028,
#      'publiccaption': None,
#      'renditionnumber': 'DDC251934',
#      'width': 2259},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:30033_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 4,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 43182083,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43182083',
#      'imageid': 25781,
#      'publiccaption': None,
#      'renditionnumber': '30033',
#      'width': 844},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:50493_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 5,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 43183405,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43183405',
#      'imageid': 19801,
#      'publiccaption': None,
#      'renditionnumber': '50493',
#      'width': 2082},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:50849_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 6,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 43183422,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43183422',
#      'imageid': 42292,
#      'publiccaption': None,
#      'renditionnumber': '50849',
#      'width': 2093}],
#    'labeltext': 'In early 1888, Van Gogh moved to Arles in the south of France, where he hoped to establish an art colony. Believing that painting could be reinvented through the genre of portraiture, he encouraged his fellow artists to paint themselves, and then to exchange the canvases. After receiving self-portraits from Emile Bernard and Gauguin, who were working together in Brittany at the time, Van Gogh inscribed this painting “To my friend Paul Gauguin,” and sent it to him. He described the process of creating his arresting likeness in several letters to his brother Theo, an art dealer in Paris, explaining how he manipulated his features in response to Japanese prints, changed the contours of his jacket for coloristic effect, and painted the background “pale veronese green” without any shadows. Shortly after he sent the work to Gauguin, however, their friendship deteriorated, and Gauguin sold it for three hundred francs.',
#    'lastupdate': '2020-01-14T06:09:36-0500',
#    'markscount': 22,
#    'mediacount': 0,
#    'medium': 'Oil on canvas',
#    'objectid': 299843,
#    'objectnumber': '1951.65',
#    'people': [{'alphasort': 'Gogh, Vincent van',
#      'birthplace': 'Groot Zundert (Zundert), The Netherlands',
#      'culture': 'Dutch',
#      'deathplace': 'Auvers-sur-Oise, France',
#      'displaydate': '1853 - 1890',
#      'displayname': 'Vincent van Gogh',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Vincent van Gogh',
#      'personid': 22730,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC251942_dynmc',
#    'provenance': 'Vincent van Gogh, Arles, (1888,) gift;  to Paul Gauguin, (1888-1897) sold. [Ambroise Vollard, Paris.] [Paul Cassirer Gallery, Berlin.] Dr. Hugo von Tschudi, Berlin, (1906-1911), by descent; to his widow, Angela von Tschudi, Munich (1911-1919),  to Neue Staatsgalerie, Munich (1919-1938); removed from the collection by the National Socialist (Nazi) authorities in 1938, consigned; to [Theodor Fischer Gallery, Lucerne, Switzerland, for sale June 30, 1939, lot 45]; to Maurice Wertheim (1939-1951) bequest; to Fogg Art Museum, 1951.\r\n\r\n \r\n\r\nNotes:\r\nGauguin sold the painting for Fr 300\r\nHugo von Tschudi bought the painting for the Nationalgalerie, Berlin, with funds from sponsors, but did not submit it to the Kaiser for pre-approval. He took the painting to Munich when he assumed a post there.\r\nAccording to Stephanie Barron, the van Gogh was removed from the Neue Staatsgalerie on March 27, 1938 and stored at Schloss Niederschönhausen in August of that year. (Barron, 1991, pp. 135-146)\r\n',
#    'publicationcount': 206,
#    'rank': 466,
#    'relatedcount': 2,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/299843',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': 'red paint, l.r.: Vincent/Arles',
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Self-Portrait Dedicated to Paul Gauguin',
#    'titlescount': 1,
#    'totalpageviews': 31749,
#    'totaluniquepageviews': 25512,
#    'url': 'https://www.harvardartmuseums.org/collections/object/299843',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]},
#   {'accessionmethod': 'Bequest',
#    'accessionyear': 1951,
#    'accesslevel': 1,
#    'century': '19th century',
#    'classification': 'Paintings',
#    'classificationid': 26,
#    'colorcount': 8,
#    'colors': [{'color': '#7d96af',
#      'css3': '#778899',
#      'hue': 'Blue',
#      'percent': 0.19830601092896,
#      'spectrum': '#7069af'},
#     {'color': '#4b647d',
#      'css3': '#696969',
#      'hue': 'Blue',
#      'percent': 0.18808743169399,
#      'spectrum': '#536fb5'},
#     {'color': '#96afaf',
#      'css3': '#a9a9a9',
#      'hue': 'Blue',
#      'percent': 0.15650273224044,
#      'spectrum': '#7b65ad'},
#     {'color': '#193232',
#      'css3': '#2f4f4f',
#      'hue': 'Green',
#      'percent': 0.1316393442623,
#      'spectrum': '#1eb264'},
#     {'color': '#647d96',
#      'css3': '#708090',
#      'hue': 'Blue',
#      'percent': 0.11136612021858,
#      'spectrum': '#656cb2'},
#     {'color': '#afafc8',
#      'css3': '#c0c0c0',
#      'hue': 'Blue',
#      'percent': 0.10060109289617,
#      'spectrum': '#8761aa'},
#     {'color': '#4b4b4b',
#      'css3': '#2f4f4f',
#      'hue': 'Grey',
#      'percent': 0.058688524590164,
#      'spectrum': '#3db657'},
#     {'color': '#324b64',
#      'css3': '#2f4f4f',
#      'hue': 'Blue',
#      'percent': 0.054808743169399,
#      'spectrum': '#4072b8'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest from the Collection of Maurice Wertheim, Class of 1906',
#    'culture': 'French',
#    'datebegin': 1877,
#    'dated': '1877',
#    'dateend': 1877,
#    'dateoffirstpageview': '2009-05-12',
#    'dateoflastpageview': '2020-01-13',
#    'department': 'Department of Paintings, Sculpture & Decorative Arts',
#    'description': None,
#    'dimensions': '83 x 101.3 cm (32 11/16 x 39 7/8 in.)\r\nframed: 110.3 x 127.5 x 9.5 cm (43 7/16 x 50 3/16 x 3 3/4 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 24,
#    'groupcount': 1,
#    'id': 228649,
#    'imagecount': 3,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC231456_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 2074,
#      'idsid': 45451171,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45451171',
#      'imageid': 417413,
#      'publiccaption': None,
#      'renditionnumber': 'DDC231456',
#      'width': 2550},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC245539_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 853,
#      'idsid': 45451173,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/45451173',
#      'imageid': 417415,
#      'publiccaption': 'Framed',
#      'renditionnumber': 'DDC245539',
#      'width': 1024},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS30127_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 813,
#      'idsid': 20673617,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20673617',
#      'imageid': 7477,
#      'publiccaption': None,
#      'renditionnumber': '30127',
#      'width': 1024}],
#    'labeltext': 'This is the largest in Monet’s series of twelve paintings of the Saint-Lazare train station in Paris, a subject favored by many impressionist painters. While completing the series, Monet relocated from the town of Argenteuil to an apartment near the station in Paris. He worked on all the paintings at the same time, and sometimes he leaned the stretched canvases against each other while the paint was still wet. This caused the cork spacers on the backs of the stretchers to be pressed into the adjacent paintings, creating circular indentations in the surface that are visible along the top edge of this work. Monet’s thick build-up of pigments here is a virtuosic example of his approach to painting during this period, when he juxtaposed multitudinous hues in mounds of impasto that would blend into a coherent whole only when viewed from a distance. This technique reportedly led Cézanne to declare, “Monet is only an eye, but my God what an eye!”',
#    'lastupdate': '2020-01-14T06:07:22-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Oil on canvas',
#    'objectid': 228649,
#    'objectnumber': '1951.53',
#    'people': [{'alphasort': 'Monet, Claude',
#      'birthplace': 'Paris, France',
#      'culture': 'French',
#      'deathplace': 'Giverny, France',
#      'displaydate': '1840 - 1926',
#      'displayname': 'Claude Monet',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Claude Monet',
#      'personid': 27651,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC231456_dynmc',
#    'provenance': 'Claude Monet, Painted, 1877, sold: to Ernest Hoschedé, 1877, sold; to Charles Deudon, 1877 [1]. [Paul Rosenberg, Paris (by 1919)]. Mme. Emile Staub-Terlinden, Mannedorf, Switzerland, (by 1923-at least 1938) [2], sold; [to Wildenstein and Co., New York,(c. 1942-1945) ] sold; to  Maurice Wertheim (1945-1951), bequest; to Fogg Art Museum, 1951.\r\n\r\nNotes:\r\n[1] Distel cites Monet notebook on sale to Deudon "pour le compte de M. Hoschedé," who had gone bankrupt.\r\n\r\n[2] Seligmann archives note presence of this painting in Staub-Terlinden\'s home during 1930 visit. Staub-Terlinden put paintings on deposit with Wildenstein some time after 1938 exhibition, Wildenstein purchased c. 1942-43, per documents in Foreign Funds Control Investigative Reports.',
#    'publicationcount': 131,
#    'rank': 80141,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/228649',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': 'l.l.: Claude Monet 77',
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'The Gare Saint-Lazare: Arrival of a Train',
#    'titlescount': 2,
#    'totalpageviews': 23634,
#    'totaluniquepageviews': 19060,
#    'url': 'https://www.harvardartmuseums.org/collections/object/228649',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]},
#   {'accessionmethod': 'Bequest',
#    'accessionyear': 1960,
#    'accesslevel': 1,
#    'century': '14th century',
#    'classification': 'Manuscripts',
#    'classificationid': 185,
#    'colorcount': 8,
#    'colors': [{'color': '#c8af96',
#      'css3': '#d2b48c',
#      'hue': 'Brown',
#      'percent': 0.25104938271605,
#      'spectrum': '#e66c64'},
#     {'color': '#af967d',
#      'css3': '#bc8f8f',
#      'hue': 'Brown',
#      'percent': 0.20604938271605,
#      'spectrum': '#c25687'},
#     {'color': '#7d6464',
#      'css3': '#696969',
#      'hue': 'Brown',
#      'percent': 0.15413580246914,
#      'spectrum': '#8e5ea7'},
#     {'color': '#e1c8af',
#      'css3': '#f5deb3',
#      'hue': 'Orange',
#      'percent': 0.12364197530864,
#      'spectrum': '#e9715f'},
#     {'color': '#644b4b',
#      'css3': '#696969',
#      'hue': 'Brown',
#      'percent': 0.11753086419753,
#      'spectrum': '#8362aa'},
#     {'color': '#967d64',
#      'css3': '#808080',
#      'hue': 'Brown',
#      'percent': 0.1129012345679,
#      'spectrum': '#b65590'},
#     {'color': '#4b647d',
#      'css3': '#696969',
#      'hue': 'Blue',
#      'percent': 0.023395061728395,
#      'spectrum': '#536fb5'},
#     {'color': '#964b32',
#      'css3': '#a0522d',
#      'hue': 'Orange',
#      'percent': 0.011296296296296,
#      'spectrum': '#d0577c'}],
#    'commentary': None,
#    'contact': 'am_asianmediterranean@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Bequest of Abby Aldrich Rockefeller',
#    'culture': 'Persian',
#    'datebegin': 1330,
#    'dated': 'c. 1335',
#    'dateend': 1340,
#    'dateoffirstpageview': '2009-06-05',
#    'dateoflastpageview': '2020-01-13',
#    'department': 'Department of Islamic & Later Indian Art',
#    'description': 'This folio is from a celebrated copy of the text known as the Great Ilkhanid Shahnama, one of the most complex masterpieces of Persian art. Because of its lavish production, it is assumed to have been commissioned by a high-ranking member of the Ilkhanid court and produced at the court scriptorium. The fifty-seven surviving illustrations reflect the intense interest in historical chronicles and the experimental approach to painting of the Ilkhanid period (1256–1335). The eclectic paintings reveal the cosmopolitanism of the Ilkhanid court in Tabriz, which teemed with merchants, missionaries, and diplomats from as far away as Europe and China. Here the Iranian king Bahram Gur wears a robe made of European fabric to slay a fearsome horned wolf in a setting marked by the conventions of Chinese landscape painting.',
#    'dimensions': 'folio: 41.5 x 30 cm (16 5/16 x 11 13/16 in.)',
#    'division': 'Asian and Mediterranean Art',
#    'edition': None,
#    'exhibitioncount': 7,
#    'groupcount': 2,
#    'id': 169542,
#    'imagecount': 3,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:770435',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 469446516,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/469446516',
#      'imageid': 500862,
#      'publiccaption': 'verso',
#      'renditionnumber': '770435',
#      'width': 1875},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:770434',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1824,
#      'idsid': 469446512,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/469446512',
#      'imageid': 500861,
#      'publiccaption': 'detail of verso',
#      'renditionnumber': '770434',
#      'width': 2550},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:770445',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 469454932,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/469454932',
#      'imageid': 500872,
#      'publiccaption': 'recto',
#      'renditionnumber': '770445',
#      'width': 1853}],
#    'labeltext': None,
#    'lastupdate': '2020-01-14T06:05:23-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Ink, colors, gold, and silver on paper',
#    'objectid': 169542,
#    'objectnumber': '1960.190',
#    'peoplecount': 0,
#    'period': 'Ilkhanid period',
#    'periodid': 2583,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:770435',
#    'provenance': 'Abby Aldrich Rockefeller, New York, NY, (by 1948), bequest; to Fogg Art Museum, 1960.',
#    'publicationcount': 16,
#    'rank': 465,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/169542',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Bahram Gur Fights the Horned Wolf (painting, verso; text, recto), illustrated folio from a manuscript of the Great Ilkhanid Shahnama (Book of Kings)',
#    'titlescount': 2,
#    'totalpageviews': 16994,
#    'totaluniquepageviews': 14314,
#    'url': 'https://www.harvardartmuseums.org/collections/object/169542',
#    'verificationlevel': 3,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'worktypes': [{'worktype': 'manuscript folio', 'worktypeid': '210'}]},
#   {'accessionmethod': 'Bequest',
#    'accessionyear': 1943,
#    'accesslevel': 1,
#    'century': '19th century',
#    'classification': 'Paintings',
#    'classificationid': 26,
#    'colorcount': 10,
#    'colors': [{'color': '#321919',
#      'css3': '#000000',
#      'hue': 'Brown',
#      'percent': 0.40401234567901,
#      'spectrum': '#3db657'},
#     {'color': '#4b4b32',
#      'css3': '#556b2f',
#      'hue': 'Green',
#      'percent': 0.19111111111111,
#      'spectrum': '#4ab851'},
#     {'color': '#7d644b',
#      'css3': '#696969',
#      'hue': 'Yellow',
#      'percent': 0.13827160493827,
#      'spectrum': '#b25593'},
#     {'color': '#c8af7d',
#      'css3': '#d2b48c',
#      'hue': 'Brown',
#      'percent': 0.061296296296296,
#      'spectrum': '#e9715f'},
#     {'color': '#967d64',
#      'css3': '#808080',
#      'hue': 'Brown',
#      'percent': 0.058086419753086,
#      'spectrum': '#b65590'},
#     {'color': '#af967d',
#      'css3': '#bc8f8f',
#      'hue': 'Brown',
#      'percent': 0.055185185185185,
#      'spectrum': '#c25687'},
#     {'color': '#7d3219',
#      'css3': '#8b4513',
#      'hue': 'Orange',
#      'percent': 0.045432098765432,
#      'spectrum': '#d0577c'},
#     {'color': '#af7d4b',
#      'css3': '#cd853f',
#      'hue': 'Yellow',
#      'percent': 0.026543209876543,
#      'spectrum': '#e9715f'},
#     {'color': '#fac896',
#      'css3': '#ffdead',
#      'hue': 'Orange',
#      'percent': 0.012469135802469,
#      'spectrum': '#ef7a55'},
#     {'color': '#af4b19',
#      'css3': '#a0522d',
#      'hue': 'Red',
#      'percent': 0.0059876543209877,
#      'spectrum': '#e86e61'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest of Grenville L. Winthrop',
#    'culture': 'French',
#    'datebegin': 1839,
#    'dated': '1839-1840',
#    'dateend': 1840,
#    'dateoffirstpageview': '2009-05-13',
#    'dateoflastpageview': '2020-01-13',
#    'department': 'Department of Paintings, Sculpture & Decorative Arts',
#    'description': None,
#    'dimensions': '72.1 x 100.3 cm (28 3/8 x 39 1/2 in.)\r\nframe: 94.6 x 122.6 x 7.6 cm (37 1/4 x 48 1/4 x 3 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 18,
#    'groupcount': 2,
#    'id': 299806,
#    'imagecount': 2,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51355_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1843,
#      'idsid': 17386642,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17386642',
#      'imageid': 52851,
#      'publiccaption': None,
#      'renditionnumber': '51355',
#      'width': 2550},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:10579_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1830,
#      'idsid': 43181266,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43181266',
#      'imageid': 5651,
#      'publiccaption': None,
#      'renditionnumber': '10579',
#      'width': 2550}],
#    'labeltext': 'The central figure of the odalisque (a concubine in a harem) represents Ingres’s reinterpretation of the Western classical tradition of the female nude in the modern context of the Middle Eastern “other.” Though Ingres had never traveled outside Europe, he became fascinated by writings about Turkish society, mixing details from travel writing with his own fantasies. Period critics admired the way Ingres depicted the skin of the three different figures, praising how “the variety and nature of the races has been understood and expressed by the artist.” One commentator sorted the figures by skin type, contrasting the “white favorite” prone at the center of the painting, the “young Abyssinian slave . . . tawny like bronze” playing music at her side, and the “black eunuch” in the background. With her languid, available pose and state of undress, the white odalisque is offered as the sexual prize for the presumed male proprietor of this lavish interior—and by proxy, the viewer.',
#    'lastupdate': '2020-01-14T06:09:36-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Oil on canvas',
#    'objectid': 299806,
#    'objectnumber': '1943.251',
#    'people': [{'alphasort': 'Ingres, Jean-Auguste-Dominique',
#      'birthplace': 'Montauban',
#      'culture': 'French',
#      'deathplace': 'Paris',
#      'displaydate': '1780 - 1867',
#      'displayname': 'Jean-Auguste-Dominique Ingres',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Jean-Auguste-Dominique Ingres',
#      'personid': 26693,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51355_dynmc',
#    'provenance': "Jean-Auguste-Dominique Ingres, sold to Charles Marcotte d'Argenteuil, 1840, by descent; to Louis-Marie-Joseph Marcotte, his son, offered for sale [through Ingres sale, Hôtel Druot, Paris, April 27, 1867, lot 17]; bought in by Marcotte, sold; to Louis Aguillon, the brother-in-law of Louis-Marie-Joseph Marcotte, by descent; to Louis Marcotte de Quivières, sold [through de Quivières sale, Hôtel Drouot, Paris, 1875, lot 11]; to Guilhermony [1]. Gustave Pereire, Paris, 1911, by descent; to his wife, Mme. Henriette Pereire. Carroll S. Tyson, Philadelphia. [Wildenstein & Co., New York], sold; to Grenville Lindall Winthrop, 1935, bequest; to Fogg Art Museum, 1943\r\n\r\nNotes\r\n[1] The spelling of Guilhermony varies; also found as Guilhermy\r\n\r\n",
#    'publicationcount': 266,
#    'rank': 464,
#    'relatedcount': 3,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/299806',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': 'l.l.: J. Ingres / Rom. 1839',
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Odalisque, Slave, and Eunuch',
#    'titlescount': 2,
#    'totalpageviews': 15370,
#    'totaluniquepageviews': 12118,
#    'url': 'https://www.harvardartmuseums.org/collections/object/299806',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]},
#   {'accessionmethod': 'Bequest',
#    'accessionyear': 1966,
#    'accesslevel': 1,
#    'century': '18th century',
#    'classification': 'Paintings',
#    'classificationid': 26,
#    'colorcount': 10,
#    'colors': [{'color': '#7d7d64',
#      'css3': '#808080',
#      'hue': 'Yellow',
#      'percent': 0.34745098039216,
#      'spectrum': '#6cbd45'},
#     {'color': '#4b4b32',
#      'css3': '#556b2f',
#      'hue': 'Green',
#      'percent': 0.29344537815126,
#      'spectrum': '#4ab851'},
#     {'color': '#64644b',
#      'css3': '#696969',
#      'hue': 'Green',
#      'percent': 0.1127731092437,
#      'spectrum': '#59ba4a'},
#     {'color': '#afafaf',
#      'css3': '#a9a9a9',
#      'hue': 'Grey',
#      'percent': 0.08733893557423,
#      'spectrum': '#8c5fa8'},
#     {'color': '#4b3219',
#      'css3': '#556b2f',
#      'hue': 'Brown',
#      'percent': 0.079271708683473,
#      'spectrum': '#4ab851'},
#     {'color': '#969696',
#      'css3': '#a9a9a9',
#      'hue': 'Grey',
#      'percent': 0.056526610644258,
#      'spectrum': '#8761aa'},
#     {'color': '#c8c8c8',
#      'css3': '#c0c0c0',
#      'hue': 'Grey',
#      'percent': 0.018207282913165,
#      'spectrum': '#8c5fa8'},
#     {'color': '#4b647d',
#      'css3': '#696969',
#      'hue': 'Blue',
#      'percent': 0.0042577030812325,
#      'spectrum': '#536fb5'},
#     {'color': '#191919',
#      'css3': '#000000',
#      'hue': 'Grey',
#      'percent': 0.0003921568627451,
#      'spectrum': '#1eb264'},
#     {'color': '#967d32',
#      'css3': '#a0522d',
#      'hue': 'Yellow',
#      'percent': 0.00033613445378151,
#      'spectrum': '#86c440'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest of Charles E. Dunlap',
#    'culture': 'French',
#    'datebegin': 1750,
#    'dated': '1750, with later additions',
#    'dateend': 1750,
#    'dateoffirstpageview': '2009-05-12',
#    'dateoflastpageview': '2020-01-13',
#    'department': 'Department of Paintings, Sculpture & Decorative Arts',
#    'description': None,
#    'dimensions': '81.2 × 64.9 cm (31 15/16 × 25 9/16 in.)\r\nframe: 99.8 x 84.5 cm (39 5/16 x 33 1/4 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 9,
#    'groupcount': 2,
#    'id': 303561,
#    'imagecount': 4,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51366_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 17386653,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17386653',
#      'imageid': 19994,
#      'publiccaption': None,
#      'renditionnumber': '51366',
#      'width': 2032},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG259401',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 420781173,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/420781173',
#      'imageid': 461352,
#      'publiccaption': None,
#      'renditionnumber': 'LEG259401',
#      'width': 2181},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:10577_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 43181265,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43181265',
#      'imageid': 921,
#      'publiccaption': None,
#      'renditionnumber': '10577',
#      'width': 829},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:20028_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 4,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 43181886,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43181886',
#      'imageid': 6377,
#      'publiccaption': None,
#      'renditionnumber': '20028',
#      'width': 811}],
#    'labeltext': 'This likeness of the marquise de Pompadour (1721–1764) was originally painted as a rectangular bust-length portrait for her brother, Abel-François Poisson, marquis de Marigny. After being damaged in transit, the portrait was extended on all sides, most likely by Boucher himself, and transformed to portray the marquise at her dressing table. The depiction of the mirror was changed from silver to green lacquer around 1759, when many courtiers surrendered their precious metals to support the war against Britain. About a decade later, the canvas may have been reshaped into an oval to suit contemporary taste.\r\nPompadour was the official mistress of Louis XV beginning in 1745. The king’s portrait on her wrist decorously signifies that bond. The signature and date of 1758 found above the chair are much later additions.',
#    'lastupdate': '2020-01-14T06:09:43-0500',
#    'markscount': 8,
#    'mediacount': 0,
#    'medium': 'Oil on canvas',
#    'objectid': 303561,
#    'objectnumber': '1966.47',
#    'people': [{'alphasort': 'Boucher, François',
#      'birthplace': 'Paris',
#      'culture': 'French',
#      'deathplace': 'Paris',
#      'displaydate': '1703 - 1770',
#      'displayname': 'François Boucher',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'François Boucher',
#      'personid': 29169,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51366_dynmc',
#    'provenance': 'Jeanne-Antoinette Poisson, Marquise de Pompadour, gift; to her brother, M de Vandières, later the Marquis de Marigny (by 1781). [Anonymous sale, Maciet and Haro, March 15, 1875,  lot 11].  Baron Salomon Albert Anselm de Rothschild, Vienna, (c. 1920s), by descent; to his son Baron Louis de Rothschild, Vienna, sold; through [Wildenstein & Co., Paris]; to Baron Maurice de Rothschild, Pregny, Switzerland, (? - until 1952) sold; through [Rosenberg & Stiebel, New York (1952-1953) sold]; to Charles E. Dunlap (1953-1966), gift; to Fogg Art Museum, 1966.\r\n\r\n\r\nNotes:\r\n\r\nMuch of the Louis de Rothschild collection was confiscated during World War II and recuperated afterwards.',
#    'publicationcount': 47,
#    'rank': 463,
#    'relatedcount': 3,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/303561',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Jeanne-Antoinette Poisson, Marquise de Pompadour',
#    'titlescount': 1,
#    'totalpageviews': 13891,
#    'totaluniquepageviews': 11303,
#    'url': 'https://www.harvardartmuseums.org/collections/object/303561',
#    'verificationlevel': 3,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]},
#   {'accessionmethod': 'Bequest',
#    'accessionyear': 1965,
#    'accesslevel': 1,
#    'century': '20th century',
#    'classification': 'Drawings',
#    'classificationid': 21,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_moderncontemporary@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': '© Estate of Pablo Picasso / Artists Rights Society (ARS), New York',
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest of Meta and Paul J. Sachs',
#    'culture': 'Spanish',
#    'datebegin': 1903,
#    'dated': '1903-1904',
#    'dateend': 1904,
#    'dateoffirstpageview': '2009-05-12',
#    'dateoflastpageview': '2020-01-12',
#    'department': 'Department of Drawings',
#    'description': None,
#    'dimensions': '33.8 x 26.7 cm (13 5/16 x 10 1/2 in.)\r\nframed: 54.6 x 44.5 cm (21 1/2 x 17 1/2 in.)',
#    'division': 'Modern and Contemporary Art',
#    'edition': None,
#    'exhibitioncount': 7,
#    'groupcount': 0,
#    'id': 299997,
#    'imagecount': 5,
#    'imagepermissionlevel': 1,
#    'images': [],
#    'labeltext': None,
#    'lastupdate': '2020-01-14T06:09:36-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Black crayon on tan wove paper; verso: black ink',
#    'objectid': 299997,
#    'objectnumber': '1965.318',
#    'people': [{'alphasort': 'Picasso, Pablo Ruiz',
#      'birthplace': 'Malaga, Spain',
#      'culture': 'Spanish',
#      'deathplace': 'Mougins, France',
#      'displaydate': '1881 - 1973',
#      'displayname': 'Pablo Ruiz Picasso',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Pablo Ruiz Picasso',
#      'personid': 28064,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': None,
#    'provenance': 'Charles Vignier, Paris, sold; to Paul J. Sachs, Cambridge, Massachusetts (L. 2091), 1929, bequest; to Fogg Art Museum, 1965.',
#    'publicationcount': 15,
#    'rank': 86150,
#    'relatedcount': 3,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/299997',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'A Mother and Child and Four Studies of Her Right Hand, 1904; verso:  Self-Portrait Standing, 1903',
#    'titlescount': 1,
#    'totalpageviews': 13301,
#    'totaluniquepageviews': 9574,
#    'url': 'https://www.harvardartmuseums.org/collections/object/299997',
#    'verificationlevel': 3,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'worktypes': [{'worktype': 'drawing', 'worktypeid': '125'}]},
#   {'accessionmethod': 'Bequest',
#    'accessionyear': 1951,
#    'accesslevel': 1,
#    'century': '19th century',
#    'classification': 'Paintings',
#    'classificationid': 26,
#    'colorcount': 10,
#    'colors': [{'color': '#96afaf',
#      'css3': '#a9a9a9',
#      'hue': 'Blue',
#      'percent': 0.33357357357357,
#      'spectrum': '#7b65ad'},
#     {'color': '#647d7d',
#      'css3': '#708090',
#      'hue': 'Blue',
#      'percent': 0.27063063063063,
#      'spectrum': '#6c6ab0'},
#     {'color': '#7d9696',
#      'css3': '#778899',
#      'hue': 'Green',
#      'percent': 0.20228228228228,
#      'spectrum': '#7069af'},
#     {'color': '#4b647d',
#      'css3': '#696969',
#      'hue': 'Blue',
#      'percent': 0.11255255255255,
#      'spectrum': '#536fb5'},
#     {'color': '#afc8c8',
#      'css3': '#c0c0c0',
#      'hue': 'Green',
#      'percent': 0.03033033033033,
#      'spectrum': '#8761aa'},
#     {'color': '#64644b',
#      'css3': '#696969',
#      'hue': 'Green',
#      'percent': 0.027027027027027,
#      'spectrum': '#59ba4a'},
#     {'color': '#324b4b',
#      'css3': '#2f4f4f',
#      'hue': 'Grey',
#      'percent': 0.016156156156156,
#      'spectrum': '#2eb45d'},
#     {'color': '#af6432',
#      'css3': '#a0522d',
#      'hue': 'Orange',
#      'percent': 0.0032432432432432,
#      'spectrum': '#e9715f'},
#     {'color': '#c8e1e1',
#      'css3': '#dcdcdc',
#      'hue': 'Green',
#      'percent': 0.0030630630630631,
#      'spectrum': '#8761aa'},
#     {'color': '#af7d4b',
#      'css3': '#cd853f',
#      'hue': 'Yellow',
#      'percent': 0.0011411411411411,
#      'spectrum': '#e9715f'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest from the Collection of Maurice Wertheim, Class of 1906',
#    'culture': 'French',
#    'datebegin': 1875,
#    'dated': '1875',
#    'dateend': 1875,
#    'dateoffirstpageview': '2009-06-09',
#    'dateoflastpageview': '2020-01-13',
#    'department': 'Department of Paintings, Sculpture & Decorative Arts',
#    'description': None,
#    'dimensions': '61.8 x 82.5 cm (24 5/16 x 32 1/2 in.)\r\nframed: 91 x 111.2 x 10.2 cm (35 13/16 x 43 3/4 x 4 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 20,
#    'groupcount': 1,
#    'id': 228650,
#    'imagecount': 4,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC231457_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1887,
#      'idsid': 46080098,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/46080098',
#      'imageid': 417408,
#      'publiccaption': None,
#      'renditionnumber': 'DDC231457',
#      'width': 2550},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC245420_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 834,
#      'idsid': 46080100,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/46080100',
#      'imageid': 417410,
#      'publiccaption': None,
#      'renditionnumber': 'DDC245420',
#      'width': 1024},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS30367_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 827,
#      'idsid': 20673713,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20673713',
#      'imageid': 7533,
#      'publiccaption': None,
#      'renditionnumber': '30367',
#      'width': 1024},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:30464_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 4,
#      'format': 'image/jpeg',
#      'height': 771,
#      'idsid': 17357776,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17357776',
#      'imageid': 26321,
#      'publiccaption': None,
#      'renditionnumber': '30464',
#      'width': 1024}],
#    'labeltext': 'For most of the 1870s, Monet lived in Argenteuil, a town on the Seine only seventeen miles from Paris and accessible to the city by train. He often worked outdoors in his own boat and painted this basin several times, though the lower vantage point of this scene suggests a perspective from the shoreline. Eliminating the factory smokestacks that were in fact visible at this location, Monet instead highlights the area’s picturesque and recreational aspects, including the boat rental area on the left.\r\nImpressionist painters like Monet deliberately eschewed the finished structure and line of academic painting, but the irresolution of this painting has led to its occasional categorization as a “study.” As revealed in x-radiographs, the artist reworked the composition in several areas, removing a sixth paddling duck on the left, for example, by painting over it. The band of lavender brushstrokes along the horizon line is the site of a similar revision.',
#    'lastupdate': '2020-01-14T06:07:22-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Oil on canvas',
#    'objectid': 228650,
#    'objectnumber': '1951.54',
#    'people': [{'alphasort': 'Monet, Claude',
#      'birthplace': 'Paris, France',
#      'culture': 'French',
#      'deathplace': 'Giverny, France',
#      'displaydate': '1840 - 1926',
#      'displayname': 'Claude Monet',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Claude Monet',
#      'personid': 27651,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC231457_dynmc',
#    'provenance': '?J. B. Faure, Paris, 1876. [Durand-Ruel, New York], sold; James F. Sutton, (1893 - 1917) sold; ([his sale, through Durand-Ruel, 1917, no. 137]. Émile Laffon, Paris, sold; [through his sale]; to Paul Rosenberg, New York, sold; to Maurice Wertheim, (1943-1951), bequest; to Fogg Art Museum, 1951.\r\n',
#    'publicationcount': 35,
#    'rank': 80142,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/228650',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': 'l.l. Claude Monet 75',
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Red Boats, Argenteuil',
#    'titlescount': 3,
#    'totalpageviews': 12400,
#    'totaluniquepageviews': 9993,
#    'url': 'https://www.harvardartmuseums.org/collections/object/228650',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]},
#   {'accessionmethod': 'Gift',
#    'accessionyear': 2002,
#    'accesslevel': 1,
#    'century': '16th century',
#    'classification': 'Manuscripts',
#    'classificationid': 185,
#    'colorcount': 0,
#    'commentary': None,
#    'contact': 'am_asianmediterranean@harvard.edu',
#    'contextualtextcount': 1,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, The Norma Jean Calderwood Collection of Islamic Art',
#    'culture': 'Persian',
#    'datebegin': 1562,
#    'dated': '1562',
#    'dateend': 1562,
#    'dateoffirstpageview': '2009-11-08',
#    'dateoflastpageview': '2020-01-13',
#    'department': 'Department of Islamic & Later Indian Art',
#    'description': 'Gayumars was the legendary first king of Iran, associated with the beginning of civilization and an organized social order. He and his people lived in the mountains and wore clothes made of leopard skins. The court was prosperous and his subjects content: animals and humans alike obeyed the king, who was blessed with divine power (farr). Gayumars had a son, Siyamak, whom he adored and who was loved by all save a jealous creature called Ahriman.\r\nThe large and densely detailed illustration shows the king, seated on a tiger skin, attended by his court; like him, they are dressed in leopard pelts. Siyamak sits to the left of Gayumars, and the two are encircled by courtiers and animals. The rocks of their mountain home have human faces, as does a sun that shines from behind a crag in the upper left corner. Near the sun, a demonic figure peers at a bear hurling a rock. Such playful vignettes are characteristic of Persianate painting of the time and can also be found in the illustrations of the Shahnama made for the Safavid ruler Shah Tahmasp. The red demon may represent Ahriman, the enemy of humankind.\r\n\r\n',
#    'dimensions': '37.2 x 23.4 cm (14 5/8 x 9 3/16 in.)',
#    'division': 'Asian and Mediterranean Art',
#    'edition': None,
#    'exhibitioncount': 2,
#    'groupcount': 0,
#    'id': 146520,
#    'imagecount': 2,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:62173_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 17804776,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17804776',
#      'imageid': 54487,
#      'publiccaption': 'recto',
#      'renditionnumber': '62173',
#      'width': 654},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:62174_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 17804777,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17804777',
#      'imageid': 18834,
#      'publiccaption': 'verso',
#      'renditionnumber': '62174',
#      'width': 660}],
#    'labeltext': None,
#    'lastupdate': '2020-01-14T06:04:41-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Ink, opaque watercolor and gold on paper',
#    'objectid': 146520,
#    'objectnumber': '2002.50.150',
#    'peoplecount': 0,
#    'period': 'Safavid period',
#    'periodid': 2363,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:62173_dynmc',
#    'provenance': '[Christies, London, 17 October 1995, lot no. 79]. [Mansour Gallery, London, before 1998], sold; to Stanford and Norma Jean Calderwood, Belmont, MA (by 1998-2002), gift; to Harvard Art Museums, 2002.',
#    'publicationcount': 1,
#    'rank': 122016,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/146520',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Court of Gayumars (painting, recto; text, verso), folio from a manuscript of the Shahnama by Firdawsi',
#    'titlescount': 2,
#    'totalpageviews': 10890,
#    'totaluniquepageviews': 9560,
#    'url': 'https://www.harvardartmuseums.org/collections/object/146520',
#    'verificationlevel': 3,
#    'verificationleveldescription': 'Good. Object is well described and information is vetted',
#    'worktypes': [{'worktype': 'manuscript folio', 'worktypeid': '210'}]},
# ...
#     {'color': '#afaf96',
#      'css3': '#a9a9a9',
#      'hue': 'Green',
#      'percent': 0.0013978494623656,
#      'spectrum': '#8e5ea7'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Grenville L. Winthrop, Class of 1886',
#    'culture': 'British',
#    'datebegin': 1875,
#    'dated': '1875-1877',
#    'dateend': 1877,
#    'dateoffirstpageview': '2009-05-20',
#    'dateoflastpageview': '2020-01-13',
#    'department': 'Department of Paintings, Sculpture & Decorative Arts',
#    'description': None,
#    'dimensions': '111.5 x 93 cm (43 7/8 x 36 5/8 in.)\r\nframed: 142.2 x 122.6 x 8.9 cm (56 x 48 1/4 x 3 1/2 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 10,
#    'groupcount': 1,
#    'id': 230614,
#    'imagecount': 2,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51191_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 17386496,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17386496',
#      'imageid': 16770,
#      'publiccaption': None,
#      'renditionnumber': '51191',
#      'width': 2121},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS37580_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 20863799,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20863799',
#      'imageid': 29485,
#      'publiccaption': None,
#      'renditionnumber': '37580',
#      'width': 807}],
#    'labeltext': 'A Sea-Spell was painted for Rossetti’s patron Frederick Leyland, a ship magnate who owned a large number of paintings by the artist. Rossetti first planned to illustrate lines from Coleridge’s poem Kubla Khan — “A damsel with a dulcimer / In a vision once I saw” — but the subject was ultimately derived from his own poem, inscribed on the frame that he designed. The musician’s “lashing fingers weave the sweet-strung spell” of the siren, a mythological figure whose voice lures sailors to their deaths. Although sirens were traditionally described as women with the bodies or heads of birds, Rossetti’s enchantress retains her human form, surmounted by an avian headdress. The artist evokes all of the senses in his lushly claustrophobic canvas; the siren’s dreamy mien suggests that she, too, has been bewitched by the music and by the fragrance of the surrounding flowers. The subject of the dangerous woman, or “femme fatale,” flourished in the nineteenth century.',
#    'lastupdate': '2020-01-14T06:07:27-0500',
#    'markscount': 2,
#    'mediacount': 0,
#    'medium': 'Oil on canvas',
#    'objectid': 230614,
#    'objectnumber': '1939.92',
#    'people': [{'alphasort': 'Rossetti, Dante Gabriel',
#      'birthplace': 'London, England',
#      'culture': 'British',
#      'deathplace': 'Birchington-on-Sea, England',
#      'displaydate': '1828 - 1882',
#      'displayname': 'Dante Gabriel Rossetti',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'Dante Gabriel Rossetti',
#      'personid': 28374,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51191_dynmc',
#    'provenance': 'Frederick R. Leyland (acquired from the artist?) sold; [Christie, Manson & Wood, London, May 28, 1892, lot 51]; to [Tooth]. T. F. Wigley. David Croal Thomson. William Hulme, Viscount Leverhulme, sold; [Anderson Galleries, New York, February 17-19, 1926, lot 238, repr.]; to [Scott & Fowles, New York] sold; to Grenville L. Winthrop, 1935, gift; to Fogg Art Museum, 1939\r\n',
#    'publicationcount': 35,
#    'rank': 63880,
#    'relatedcount': 1,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/230614',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': 'l.l.: D. G. Rossetti 1877',
#    'standardreferencenumber': 'Surtees 248',
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'A Sea-Spell',
#    'titlescount': 1,
#    'totalpageviews': 2414,
#    'totaluniquepageviews': 1894,
#    'url': 'https://www.harvardartmuseums.org/collections/object/230614',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]},
#   {'accessionmethod': 'Bequest',
#    'accessionyear': 1943,
#    'accesslevel': 1,
#    'century': '19th century',
#    'classification': 'Paintings',
#    'classificationid': 26,
#    'colorcount': 6,
#    'colors': [{'color': '#4b3219',
#      'css3': '#556b2f',
#      'hue': 'Brown',
#      'percent': 0.74252032520325,
#      'spectrum': '#4ab851'},
#     {'color': '#644b32',
#      'css3': '#556b2f',
#      'hue': 'Brown',
#      'percent': 0.17626016260163,
#      'spectrum': '#59ba4a'},
#     {'color': '#7d6432',
#      'css3': '#a0522d',
#      'hue': 'Yellow',
#      'percent': 0.035772357723577,
#      'spectrum': '#6cbd45'},
#     {'color': '#967d4b',
#      'css3': '#a0522d',
#      'hue': 'Brown',
#      'percent': 0.024390243902439,
#      'spectrum': '#7fc241'},
#     {'color': '#af9664',
#      'css3': '#bdb76b',
#      'hue': 'Yellow',
#      'percent': 0.011869918699187,
#      'spectrum': '#e9715f'},
#     {'color': '#c8af7d',
#      'css3': '#d2b48c',
#      'hue': 'Brown',
#      'percent': 0.0091869918699187,
#      'spectrum': '#e9715f'}],
#    'commentary': None,
#    'contact': 'am_europeanamerican@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Fogg Museum, Bequest of Grenville L. Winthrop',
#    'culture': 'British',
#    'datebegin': 1860,
#    'dated': '1860-1862',
#    'dateend': 1862,
#    'dateoffirstpageview': '2009-06-21',
#    'dateoflastpageview': '2020-01-13',
#    'department': 'Department of Paintings, Sculpture & Decorative Arts',
#    'description': None,
#    'dimensions': '191.8 x 107 cm (75 1/2 x 42 1/8 in.)\r\nframed: 217.2 x 127 x 8.3 cm (85 1/2 x 50 x 3 1/4 in.)',
#    'division': 'European and American Art',
#    'edition': None,
#    'exhibitioncount': 15,
#    'groupcount': 0,
#    'id': 230160,
#    'imagecount': 3,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:70764_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 17804275,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17804275',
#      'imageid': 56586,
#      'publiccaption': None,
#      'renditionnumber': '70764',
#      'width': 561},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:20304_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 2,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 43181930,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43181930',
#      'imageid': 126496,
#      'publiccaption': None,
#      'renditionnumber': '20304',
#      'width': 575},
#     {'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51248_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 3,
#      'format': 'image/jpeg',
#      'height': 1024,
#      'idsid': 17386547,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17386547',
#      'imageid': 16789,
#      'publiccaption': None,
#      'renditionnumber': '51248',
#      'width': 560}],
#    'labeltext': None,
#    'lastupdate': '2020-01-14T06:07:26-0500',
#    'markscount': 0,
#    'mediacount': 0,
#    'medium': 'Oil on canvas',
#    'objectid': 230160,
#    'objectnumber': '1943.209',
#    'people': [{'alphasort': 'Watts, George Frederick',
#      'birthplace': 'London, England',
#      'culture': 'British',
#      'deathplace': 'Limnerslease, Compton, England',
#      'displaydate': '1817 - 1904',
#      'displayname': 'George Frederick Watts',
#      'displayorder': 1,
#      'gender': 'male',
#      'name': 'George Frederick Watts',
#      'personid': 29338,
#      'prefix': None,
#      'role': 'Artist'}],
#    'peoplecount': 1,
#    'period': None,
#    'periodid': None,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:70764_dynmc',
#    'provenance': "Eustace Smith, 1873, Sold to Henderson, 1887. Smith was a member of Parliament.\r\nAlexander (the Rt. Hon. Lord Faringdon C. H.) Henderson, Purchased from Smith, 1887, Sold at Sotheby's, London, 1934.\r\nFine Art Society PLC, London, Purchased from Sotheby's London, 1934, Sold to Winthrop, 1934. Purchased at Henderson's sale, June 13, 1934, where it was no. 133; the Fine Art Society paid £820. Sold to Winthrop July 1934 through Frost and Reed and Martin Birnbaum.\r\nGrenville Lindall Winthrop, Purchased from Fine Arts Society, 1934, Bequest to Fogg Art Museum, 1943. Purchase through Frost and Reed and M. Birnbaum, July 1934. Winthrop paid £770 plus Birnbaum's commission. See object file for details of how they failed to acquire the painting at auction, but later bought it from the Fine Arts Society, who had had the successful bid.\r\n",
#    'publicationcount': 42,
#    'rank': 67929,
#    'relatedcount': 0,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/230160',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': None,
#    'techniqueid': None,
#    'title': 'Sir Galahad',
#    'titlescount': 1,
#    'totalpageviews': 2394,
#    'totaluniquepageviews': 1945,
#    'url': 'https://www.harvardartmuseums.org/collections/object/230160',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]},
#   {'accessionmethod': 'Gift',
#    'accessionyear': 1923,
#    'accesslevel': 1,
#    'audio': [{'audioid': 492584,
#      'copyright': 'President and Fellows of Harvard College',
#      'description': 'Visual description by Frances Gallart Marques Frederick Randolph Grace Curatorial Fellow in Ancient Art, Division of Asian and Mediterranean Art. Written August 2018.',
#      'duration': 0,
#      'primaryurl': 'http://media.harvardartmuseums.org/audio/alice/mummy-portrait.mp3',
#      'transcripturl': 'http://media.harvardartmuseums.org/audio/alice/mummy-portrait.txt'},
#     {'audioid': 492584,
#      'copyright': 'President and Fellows of Harvard College',
#      'description': 'Visual description by Frances Gallart Marques Frederick Randolph Grace Curatorial Fellow in Ancient Art, Division of Asian and Mediterranean Art. Written August 2018.',
#      'duration': 0,
#      'primaryurl': 'http://media.harvardartmuseums.org/audio/alice/mummy-portrait.mp3',
#      'transcripturl': 'https://nrs.harvard.edu/urn-3:HUAM:AUD0169transcript'}],
#    'century': '2nd century CE',
#    'classification': 'Paintings',
#    'classificationid': 26,
#    'colorcount': 10,
#    'colors': [{'color': '#000000',
#      'css3': '#000000',
#      'hue': 'Black',
#      'percent': 0.26979166666667,
#      'spectrum': '#1eb264'},
#     {'color': '#4b3232',
#      'css3': '#2f4f4f',
#      'hue': 'Red',
#      'percent': 0.1825,
#      'spectrum': '#4ab851'},
#     {'color': '#321919',
#      'css3': '#000000',
#      'hue': 'Brown',
#      'percent': 0.14201388888889,
#      'spectrum': '#3db657'},
#     {'color': '#967d64',
#      'css3': '#808080',
#      'hue': 'Brown',
#      'percent': 0.093680555555556,
#      'spectrum': '#b65590'},
#     {'color': '#af967d',
#      'css3': '#bc8f8f',
#      'hue': 'Brown',
#      'percent': 0.078333333333333,
#      'spectrum': '#c25687'},
#     {'color': '#96644b',
#      'css3': '#a0522d',
#      'hue': 'Brown',
#      'percent': 0.076736111111111,
#      'spectrum': '#c25687'},
#     {'color': '#644b4b',
#      'css3': '#696969',
#      'hue': 'Brown',
#      'percent': 0.041041666666667,
#      'spectrum': '#8362aa'},
#     {'color': '#7d4b32',
#      'css3': '#8b4513',
#      'hue': 'Brown',
#      'percent': 0.039236111111111,
#      'spectrum': '#c25687'},
#     {'color': '#af7d4b',
#      'css3': '#cd853f',
#      'hue': 'Yellow',
#      'percent': 0.030555555555556,
#      'spectrum': '#e9715f'},
#     {'color': '#c89664',
#      'css3': '#bdb76b',
#      'hue': 'Brown',
#      'percent': 0.024583333333333,
#      'spectrum': '#ed7758'}],
#    'commentary': "Wooden panel portraits such as this would have been set into mummy wrappings, covering the face of the deceased. The images may or may not have been painted before the sitter's death and were often idealized representations. The shape of this portrait, which is trimmed to follow the contour of the head and shoulders, is consistent with panels that come from Antinoopolis, a city founded by the Emperor Hadrian [1].\r\n\r\n1. For similar panel shape and hairstyle see Louvre inv. P 217. (Zaloscer, fig. 25).",
#    'contact': 'am_asianmediterranean@harvard.edu',
#    'contextualtextcount': 0,
#    'copyright': None,
#    'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Gift of Dr. Denman W. Ross',
#    'culture': 'Egyptian',
#    'datebegin': 125,
#    'dated': 'c. 130-140 CE',
#    'dateend': 135,
#    'dateoffirstpageview': '2009-05-19',
#    'dateoflastpageview': '2020-01-13',
#    'department': 'Department of Ancient and Byzantine Art & Numismatics',
#    'description': 'This highly naturalistic mummy portrait depicts a young woman with deep brown eyes, arched brows, and a long pointed nose. Her dark hair is pulled back with only a row of small curls framing her forehead. Her jewelry is simple: small gold double-hooped earrings, each with a pendant pearl. She wears a deep purple tunic with green shoulder bands and maroon clasps all over a white undergarment, visible only at the neckline. \r\n\r\n\r\n',
#    'dimensions': '35.3 cm h x 22.5 cm w x 2 cm d (13 7/8 x 8 7/8 x 13/16 in.)',
#    'division': 'Asian and Mediterranean Art',
#    'edition': None,
#    'exhibitioncount': 6,
#    'groupcount': 2,
#    'id': 219609,
#    'imagecount': 1,
#    'imagepermissionlevel': 0,
#    'images': [{'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:70813_dynmc',
#      'copyright': 'President and Fellows of Harvard College',
#      'displayorder': 1,
#      'format': 'image/jpeg',
#      'height': 2550,
#      'idsid': 17804324,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17804324',
#      'imageid': 56598,
#      'publiccaption': None,
#      'renditionnumber': '70813',
#      'width': 1638}],
#    'labeltext': None,
#    'lastupdate': '2020-01-14T06:07:03-0500',
#    'markscount': 0,
#    'mediacount': 1,
#    'medium': 'Encaustic on linden wood',
#    'objectid': 219609,
#    'objectnumber': '1923.60',
#    'peoplecount': 0,
#    'period': 'Roman Imperial period, Middle',
#    'periodid': 632,
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:70813_dynmc',
#    'provenance': 'Denman Waldo Ross, Cambridge, MA, (by 1923), gift; to Fogg Art Museum, 1923.',
#    'publicationcount': 12,
#    'rank': 435,
#    'relatedcount': 5,
#    'seeAlso': [{'format': 'application/json',
#      'id': 'https://iiif.harvardartmuseums.org/manifests/object/219609',
#      'profile': 'http://iiif.io/api/presentation/2/context.json',
#      'type': 'IIIF Manifest'}],
#    'signed': None,
#    'standardreferencenumber': None,
#    'state': None,
#    'style': None,
#    'technique': 'Painted',
#    'techniqueid': 2125,
#    'title': 'Mummy Portrait of a Woman with Earrings',
#    'titlescount': 1,
#    'totalpageviews': 2375,
#    'totaluniquepageviews': 1879,
#    'url': 'https://www.harvardartmuseums.org/collections/object/219609',
#    'verificationlevel': 4,
#    'verificationleveldescription': 'Best. Object is extensively researched, well described and information is vetted',
#    'worktypes': [{'worktype': 'painting', 'worktypeid': '242'}]}]}

# %%
from IPython.core.display import display, HTML

records = results['records']
htmlOutput = "<table><tr><th>Views</th><th>Title</th></tr>"
for record in records:
    htmlOutput += f"<tr><td>{record['totalpageviews']}</td><td><a href=\"{record['url']}\" target='blank'>{record['title']}</a></td></tr>"
htmlOutput += "</table>"
display(HTML(htmlOutput))
# Out:
# <table><tr><th>Views</th><th>Title</th></tr><tr><td>31749</td><td><a href="https://www.harvardartmuseums.org/collections/object/299843" target='blank'>Self-Portrait Dedicated to Paul Gauguin</a></td></tr><tr><td>23634</td><td><a href="https://www.harvardartmuseums.org/collections/object/228649" target='blank'>The Gare Saint-Lazare: Arrival of a Train</a></td></tr><tr><td>16994</td><td><a href="https://www.harvardartmuseums.org/collections/object/169542" target='blank'>Bahram Gur Fights the Horned Wolf (painting, verso; text, recto), illustrated folio from a manuscript of the Great Ilkhanid Shahnama (Book of Kings)</a></td></tr><tr><td>15370</td><td><a href="https://www.harvardartmuseums.org/collections/object/299806" target='blank'>Odalisque, Slave, and Eunuch</a></td></tr><tr><td>13891</td><td><a href="https://www.harvardartmuseums.org/collections/object/303561" target='blank'>Jeanne-Antoinette Poisson, Marquise de Pompadour</a></td></tr><tr><td>13301</td><td><a href="https://www.harvardartmuseums.org/collections/object/299997" target='blank'>A Mother and Child and Four Studies of Her Right Hand, 1904; verso:  Self-Portrait Standing, 1903</a></td></tr><tr><td>12400</td><td><a href="https://www.harvardartmuseums.org/collections/object/228650" target='blank'>Red Boats, Argenteuil</a></td></tr><tr><td>10890</td><td><a href="https://www.harvardartmuseums.org/collections/object/146520" target='blank'>Court of Gayumars (painting, recto; text, verso), folio from a manuscript of the Shahnama by Firdawsi</a></td></tr><tr><td>9456</td><td><a href="https://www.harvardartmuseums.org/collections/object/299819" target='blank'>Light Prop for an Electric Stage (Light-Space Modulator)</a></td></tr><tr><td>9035</td><td><a href="https://www.harvardartmuseums.org/collections/object/304344" target='blank'>Self-Portrait in Tuxedo</a></td></tr><tr><td>8533</td><td><a href="https://www.harvardartmuseums.org/collections/object/299993" target='blank'>Mother and Child</a></td></tr><tr><td>8288</td><td><a href="https://www.harvardartmuseums.org/collections/object/229060" target='blank'>The Hangover (Suzanne Valadon)</a></td></tr><tr><td>8142</td><td><a href="https://www.harvardartmuseums.org/collections/object/303496" target='blank'>The Rehearsal</a></td></tr><tr><td>7399</td><td><a href="https://www.harvardartmuseums.org/collections/object/228744" target='blank'>Three Pairs of Shoes</a></td></tr><tr><td>7173</td><td><a href="https://www.harvardartmuseums.org/collections/object/303729" target='blank'>Spring Bouquet</a></td></tr><tr><td>7145</td><td><a href="https://www.harvardartmuseums.org/collections/object/299849" target='blank'>Pear Tree</a></td></tr><tr><td>7079</td><td><a href="https://www.harvardartmuseums.org/collections/object/299926" target='blank'>The Apparition</a></td></tr><tr><td>6940</td><td><a href="https://www.harvardartmuseums.org/collections/object/299923" target='blank'>Mystic Crucifixion</a></td></tr><tr><td>6088</td><td><a href="https://www.harvardartmuseums.org/collections/object/222353" target='blank'>Grazing Horses IV</a></td></tr><tr><td>6073</td><td><a href="https://www.harvardartmuseums.org/collections/object/299794" target='blank'>The Breakfast Table</a></td></tr><tr><td>5801</td><td><a href="https://www.harvardartmuseums.org/collections/object/230417" target='blank'>Nocturne in Grey and Gold: Chelsea Snow</a></td></tr><tr><td>5770</td><td><a href="https://www.harvardartmuseums.org/collections/object/299807" target='blank'>Raphael and the Fornarina</a></td></tr><tr><td>5672</td><td><a href="https://www.harvardartmuseums.org/collections/object/231830" target='blank'>Portrait of an Old Man</a></td></tr><tr><td>5509</td><td><a href="https://www.harvardartmuseums.org/collections/object/303976" target='blank'>Rocky Mountains, "Lander's Peak"</a></td></tr><tr><td>5426</td><td><a href="https://www.harvardartmuseums.org/collections/object/299805" target='blank'>The Blessed Damozel</a></td></tr><tr><td>5314</td><td><a href="https://w ...

# %%
colors = []
for entry in records:
    if "colors" in entry:
        for c in entry['colors']:
            if c['color'] not in colors:
                colors.append(c['color'])
            else:
                print(f"{c['color']} is a repeat")
# Out:
# #4b647d is a repeat
# #967d64 is a repeat
# #af967d is a repeat
# #4b4b32 is a repeat
# #4b647d is a repeat
# #191919 is a repeat
# #96afaf is a repeat
# #4b647d is a repeat
# #64644b is a repeat
# #af7d4b is a repeat
# #c8c8c8 is a repeat
# #afafaf is a repeat
# #4b4b4b is a repeat
# #969696 is a repeat
# #191919 is a repeat
# #191919 is a repeat
# #afafaf is a repeat
# #323232 is a repeat
# #969696 is a repeat
# #c8c8c8 is a repeat
# #7d7d7d is a repeat
# #4b4b4b is a repeat
# #646464 is a repeat
# #324b64 is a repeat
# #4b4b4b is a repeat
# #af967d is a repeat
# #c8af7d is a repeat
# #7d7d64 is a repeat
# #7d644b is a repeat
# #646464 is a repeat
# #323232 is a repeat
# #7d3219 is a repeat
# #4b4b32 is a repeat
# #644b4b is a repeat
# #7d7d64 is a repeat
# #191919 is a repeat
# #96967d is a repeat
# #e1e1e1 is a repeat
# #7dafaf is a repeat
# #321919 is a repeat
# #323232 is a repeat
# #64644b is a repeat
# #7d7d64 is a repeat
# #af967d is a repeat
# #c8c8af is a repeat
# #64644b is a repeat
# #7d7d64 is a repeat
# #4b4b4b is a repeat
# #969696 is a repeat
# #323232 is a repeat
# #afaf96 is a repeat
# #c8c8c8 is a repeat
# #647d64 is a repeat
# #96967d is a repeat
# #c8c8af is a repeat
# #e1e1e1 is a repeat
# #964b32 is a repeat
# #4b3219 is a repeat
# #afaf7d is a repeat
# #e1c896 is a repeat
# #323219 is a repeat
# #7d644b is a repeat
# #644b32 is a repeat
# #647d64 is a repeat
# #afaf7d is a repeat
# #967d4b is a repeat
# #96967d is a repeat
# #c86432 is a repeat
# #af4b19 is a repeat
# #191932 is a repeat
# #191919 is a repeat
# #4b4b4b is a repeat
# #c8c8c8 is a repeat
# #96967d is a repeat
# #7d7d7d is a repeat
# #afafaf is a repeat
# #e1e1e1 is a repeat
# #646464 is a repeat
# #644b32 is a repeat
# #323232 is a repeat
# #7d7d64 is a repeat
# #646464 is a repeat
# #4b4b32 is a repeat
# #191919 is a repeat
# #c8af7d is a repeat
# #321919 is a repeat
# #4b4b32 is a repeat
# #966432 is a repeat
# #af7d4b is a repeat
# #af3219 is a repeat
# #96967d is a repeat
# #c8c8af is a repeat
# #191919 is a repeat
# #644b32 is a repeat
# #4b3232 is a repeat
# #64644b is a repeat
# #321919 is a repeat
# #646464 is a repeat
# #7d7d64 is a repeat
# #4b3219 is a repeat
# #afaf96 is a repeat
# #644b32 is a repeat
# #969696 is a repeat
# #af967d is a repeat
# #321919 is a repeat
# #7d6432 is a repeat
# #644b19 is a repeat
# #967d4b is a repeat
# #fac896 is a repeat
# #4b4b4b is a repeat
# #646464 is a repeat
# #323232 is a repeat
# #191919 is a repeat
# #96967d is a repeat
# #afaf96 is a repeat
# #c8c8af is a repeat
# #191919 is a repeat
# #323232 is a repeat
# #64644b is a repeat
# #7d7d64 is a repeat
# #969696 is a repeat
# #afafaf is a repeat
# #c8c8c8 is a repeat
# #c8e1e1 is a repeat
# #19324b is a repeat
# #7d7d7d is a repeat
# #969696 is a repeat
# #646464 is a repeat
# #afafaf is a repeat
# #c8c8c8 is a repeat
# #4b4b32 is a repeat
# #e1e1c8 is a repeat
# #323219 is a repeat
# #000000 is a repeat
# #323232 is a repeat
# #191919 is a repeat
# #646464 is a repeat
# #647d7d is a repeat
# #967d64 is a repeat
# #7d644b is a repeat
# #323232 is a repeat
# #191919 is a repeat
# #7d644b is a repeat
# #967d64 is a repeat
# #644b32 is a repeat
# #96967d is a repeat
# #e1e1c8 is a repeat
# #af7d4b is a repeat
# #afaf96 is a repeat
# #644b32 is a repeat
# #7d6432 is a repeat
# #967d64 is a repeat
# #4b3219 is a repeat
# #c8c8c8 is a repeat
# #af967d is a repeat
# #e1e1e1 is a repeat
# #afafaf is a repeat
# #c8af96 is a repeat
# #323232 is a repeat
# #644b32 is a repeat
# #7d644b is a repeat
# #af9664 is a repeat
# #afafaf is a repeat
# #966432 is a repeat
# #c8967d is a repeat
# #c8af96 is a repeat
# #969696 is a repeat
# #c8c8c8 is a repeat
# #4b4b32 is a repeat
# #7d9696 is a repeat
# #7d644b is a repeat
# #c8c8c8 is a repeat
# #afafaf is a repeat
# #323219 is a repeat
# #967d64 is a repeat
# #af9664 is a repeat
# #e1e1c8 is a repeat
# #323232 is a repeat
# #321919 is a repeat
# #644b32 is a repeat
# #7d644b is a repeat
# #967d4b is a repeat
# #af9664 is a repeat
# #c8af7d is a repeat
# #323219 is a repeat
# #644b32 is a repeat
# #967d4b is a repeat
# #af967d is a repeat
# #c8c8c8 is a repeat
# #afafaf is a repeat
# #c8af96 is a repeat
# #e1e1c8 is a repeat
# #7d7d7d is a repeat
# #4b4b4b is a repeat
# #646464 is a repeat
# #96967d is a repeat
# #afaf96 is a repeat
# #323232 is a repeat
# #c8c8af is a repeat
# #191919 is a repeat
# #321919 is a repeat
# #af964b is a repeat
# #967d32 is a repeat
# #c8af64 is a repeat
# #644b32 is a repeat
# #7d6432 is a repeat
# #e1c87d is a repeat
# #191919 is a repeat
# #323232 is a repeat
# #644b32 is a repeat
# #000000 is a repeat
# #7d644b is a repeat
# #967d64 is a repeat
# #af967d is a repeat
# #afaf96 is a repeat
# #190000 is a repeat
# #c8c8af is a repeat
# #191919 is a repeat
# #4b4b4b is a repeat
# #323232 is a repeat
# #646464 is a repeat
# #7d7d7d is a repeat
# #96967d is a repeat
# #afaf96 is a repeat
# #e1c896 is a repeat
# #7d7d64 is a repeat
# #323232 is a repeat
# #96967d is a repeat
# #afaf96 is a repeat
# #4b4b4b is a repeat
# #64644b is a repeat
# #c8c8af is a repeat
# #7d7d7d is a repeat
# #969696 is a repeat
# #646464 is a repeat
# #644b4b is a repeat
# #afaf96 is a repeat
# #191919 is a repeat
# #fafafa is a repeat
# #e1e1e1 is a repeat
# #c8c8c8 is a repeat
# #afafaf is a repeat
# #969696 is a repeat
# #7d7d7d is a repeat
# #646464 is a repeat
# #4b4b4b is a repeat
# #323232 is a repeat
# #191919 is a repeat
# #c8c8c8 is a repeat
# #afafaf is a repeat
# #969696 is a repeat
# #e1e1c8 is a repeat
# #af9664 is a repeat
# #7d7d7d is a repeat
# #c8af64 is a repeat
# #967d4b is a repeat
# #7d96af is a repeat
# #96afc8 is a repeat
# #647d7d is a repeat
# #4b4b4b is a repeat
# #323232 is a repeat
# #646464 is a repeat
# #191919 is a repeat
# #190000 is a repeat
# #4b4b4b is a repeat
# #323232 is a repeat
# #7d7d7d is a repeat
# #969696 is a repeat
# #96afaf is a repeat
# #191919 is a repeat
# #e1e1e1 is a repeat
# #c8c8c8 is a repeat
# #7d7d7d is a repeat
# #644b32 is a repeat
# #646464 is a repeat
# #7d6432 is a repeat
# #afafaf is a repeat
# #4b3219 is a repeat
# #967d4b is a repeat
# #af9664 is a repeat
# #969696 is a repeat
# #c8af7d is a repeat
# #7d7d7d is a repeat
# #969696 is a repeat
# #afafaf is a repeat
# #c8c8c8 is a repeat
# #7d6464 is a repeat
# #644b4b is a repeat
# #967d64 is a repeat
# #af967d is a repeat
# #4b3232 is a repeat
# #c8af96 is a repeat
# #4b4b32 is a repeat
# #64644b is a repeat
# #7d7d64 is a repeat
# #af9664 is a repeat
# #967d4b is a repeat
# #c8af7d is a repeat
# #e1c896 is a repeat
# #afafaf is a repeat
# #969696 is a repeat
# #323232 is a repeat
# #7d4b32 is a repeat
# #191919 is a repeat
# #7d7d7d is a repeat
# #4b4b4b is a repeat
# #96644b is a repeat
# #646464 is a repeat
# #c8967d is a repeat
# #323219 is a repeat
# #644b32 is a repeat
# #7d6432 is a repeat
# #7d7d64 is a repeat
# #c8c8af is a repeat
# #96af96 is a repeat
# #323232 is a repeat
# #191919 is a repeat
# #324b4b is a repeat
# #000000 is a repeat
# #190000 is a repeat
# #96967d is a repeat
# #afaf96 is a repeat
# #c8afaf is a repeat
# #969696 is a repeat
# #c8c8c8 is a repeat
# #7d7d7d is a repeat
# #7d6464 is a repeat
# #4b4b4b is a repeat
# #191919 is a repeat
# #4b3232 is a repeat
# #323219 is a repeat
# #191919 is a repeat
# #7d7d7d is a repeat
# #4b4b32 is a repeat
# #646464 is a repeat
# #96967d is a repeat
# #af9664 is a repeat
# #323232 is a repeat
# #c8c8af is a repeat
# #7d644b is a repeat
# #644b4b is a repeat
# #4b3219 is a repeat
# #321919 is a repeat
# #e1e1e1 is a repeat
# #fafafa is a repeat
# #e1c8c8 is a repeat
# #967d64 is a repeat
# #c8af96 is a repeat
# #969696 is a repeat
# #afaf96 is a repeat
# #c8afaf is a repeat
# #af967d is a repeat
# #7d7d7d is a repeat
# #967d64 is a repeat
# #7d644b is a repeat
# #644b32 is a repeat
# #4b3219 is a repeat
# #191919 is a repeat
# #644b32 is a repeat
# #7d6432 is a repeat
# #4b3219 is a repeat
# #967d4b is a repeat
# #af9664 is a repeat
# #c8af7d is a repeat
# #c8c8af is a repeat
# #000000 is a repeat
# #fafafa is a repeat
# #4b4b4b is a repeat
# #646464 is a repeat
# #e1e1e1 is a repeat
# #323232 is a repeat
# #7d7d7d is a repeat
# #191919 is a repeat
# #afafaf is a repeat
# #c8c8c8 is a repeat
# #000000 is a repeat
# #321900 is a repeat
# #321919 is a repeat
# #644b19 is a repeat
# #7d6432 is a repeat
# #c8af7d is a repeat
# #967d4b is a repeat
# #323219 is a repeat
# #4b3232 is a repeat
# #7d7d64 is a repeat
# #64644b is a repeat
# #c8af96 is a repeat
# #c89664 is a repeat
# #c8c8af is a repeat
# #e1e1c8 is a repeat
# #967d64 is a repeat
# #96644b is a repeat
# #af967d is a repeat
# #7d4b32 is a repeat
# #c8af96 is a repeat
# #323232 is a repeat
# #96afc8 is a repeat
# #e1c8af is a repeat
# #e1e1c8 is a repeat
# #321919 is a repeat
# #4b3219 is a repeat
# #966432 is a repeat
# #af7d32 is a repeat
# #af967d is a repeat
# #c8af96 is a repeat
# #e1c896 is a repeat
# #000000 is a repeat
# #fae1e1 is a repeat
# #af964b is a repeat
# #966432 is a repeat
# #c89664 is a repeat
# #644b32 is a repeat
# #7d4b19 is a repeat
# #191919 is a repeat
# #4b4b4b is a repeat
# #7d7d7d is a repeat
# #323232 is a repeat
# #c8afaf is a repeat
# #af9696 is a repeat
# #e1c8c8 is a repeat
# #e1e1e1 is a repeat
# #afaf96 is a repeat
# #4b4b4b is a repeat
# #191919 is a repeat
# #323219 is a repeat
# #4b3232 is a repeat
# #7d644b is a repeat
# #644b32 is a repeat
# #967d64 is a repeat
# #c8af96 is a repeat
# #af967d is a repeat
# #c8c8af is a repeat
# #e1e1c8 is a repeat
# #af1932 is a repeat
# #c83232 is a repeat
# #c8c8c8 is a repeat
# #c8c8c8 is a repeat
# #afafaf is a repeat
# #4b4b4b is a repeat
# #323232 is a repeat
# #646464 is a repeat
# #191919 is a repeat
# #7d7d7d is a repeat
# #969696 is a repeat
# #e1e1e1 is a repeat
# #000000 is a repeat
# #4b4b4b is a repeat
# #646464 is a repeat
# #7d7d7d is a repeat
# #969696 is a repeat
# #c8af96 is a repeat
# #c8c8c8 is a repeat
# #e1e1e1 is a repeat
# #7d644b is a repeat
# #644b32 is a repeat
# #967d4b is a repeat
# #af9664 is a repeat
# #323219 is a repeat
# #c8af7d is a repeat
# #c8c8c8 is a repeat
# #4b4b4b is a repeat
# #e1e1e1 is a repeat
# #afafaf is a repeat
# #646464 is a repeat
# #969696 is a repeat
# #7d7d7d is a repeat
# #4b3232 is a repeat
# #321919 is a repeat
# #af9664 is a repeat
# #afafaf is a repeat
# #c8c8c8 is a repeat
# #7d7d7d is a repeat
# #64644b is a repeat
# #644b32 is a repeat
# #7d9696 is a repeat
# #323232 is a repeat
# #96967d is a repeat
# #4b7d96 is a repeat
# #32647d is a repeat
# #c8c8c8 is a repeat
# #afafaf is a repeat
# #967d4b is a repeat
# #7d6432 is a repeat
# #af9664 is a repeat
# #644b32 is a repeat
# #c8af64 is a repeat
# #969696 is a repeat
# #646464 is a repeat
# #4b3219 is a repeat
# #323232 is a repeat
# #4b4b4b is a repeat
# #646464 is a repeat
# #7d7d7d is a repeat
# #191919 is a repeat
# #afafaf is a repeat
# #7d644b is a repeat
# #969696 is a repeat
# #7d4b32 is a repeat
# #967d64 is a repeat
# #64644b is a repeat
# #4b4b32 is a repeat
# #967d64 is a repeat
# #fafafa is a repeat
# #af9664 is a repeat
# #963232 is a repeat
# #e1e1e1 is a repeat
# #c8af7d is a repeat
# #c8c8c8 is a repeat
# #afafaf is a repeat
# #e1e1c8 is a repeat
# #c8c8af is a repeat
# #afaf96 is a repeat
# #96967d is a repeat
# #7d7d64 is a repeat
# #c8967d is a repeat
# #4b4b4b is a repeat
# #191919 is a repeat
# #323219 is a repeat
# #964b32 is a repeat
# #af967d is a repeat
# #7d644b is a repeat
# #c8af96 is a repeat
# #e1c8af is a repeat
# #967d64 is a repeat
# #190000 is a repeat
# #967d64 is a repeat
# #7d644b is a repeat
# #4b3232 is a repeat
# #644b32 is a repeat
# #969696 is a repeat
# #c8af96 is a repeat
# #af967d is a repeat
# #c8c8af is a repeat
# #323232 is a repeat
# #191919 is a repeat
# #afaf7d is a repeat
# #969664 is a repeat
# #c8afaf is a repeat
# #afaf96 is a repeat
# #af967d is a repeat
# #967d64 is a repeat
# #7d644b is a repeat
# #4b3232 is a repeat
# #644b32 is a repeat
# #e1c8c8 is a repeat
# #af7d4b is a repeat
# #fafafa is a repeat
# #c8964b is a repeat
# #323232 is a repeat
# #191919 is a repeat
# #644b32 is a repeat
# #324b4b is a repeat
# #e1e1e1 is a repeat
# #7d4b19 is a repeat
# #c8c8af is a repeat
# #324b32 is a repeat
# #4b644b is a repeat
# #afafaf is a repeat
# #7d7d64 is a repeat
# #96967d is a repeat
# #c8af64 is a repeat
# #e1e1c8 is a repeat
# #4b3232 is a repeat
# #64644b is a repeat
# #7d7d64 is a repeat
# #323219 is a repeat
# #af967d is a repeat
# #c8c8c8 is a repeat
# #afafaf is a repeat
# #e1e1c8 is a repeat
# #96967d is a repeat
# #967d64 is a repeat
# #c8c8af is a repeat
# #644b4b is a repeat
# #7d644b is a repeat
# #4b3232 is a repeat
# #e1e1e1 is a repeat
# #000000 is a repeat
# #afafaf is a repeat
# #af4b19 is a repeat
# #c8af64 is a repeat
# #4b4b32 is a repeat
# #7d644b is a repeat
# #967d64 is a repeat
# #af967d is a repeat
# #c8af7d is a repeat
# #969696 is a repeat
# #191919 is a repeat
# #afafaf is a repeat
# #7d7d7d is a repeat
# #323232 is a repeat
# #646464 is a repeat
# #644b32 is a repeat
# #4b3219 is a repeat
# #4b4b4b is a repeat
# #966432 is a repeat
# #c8c8c8 is a repeat
# #321919 is a repeat
# #323232 is a repeat
# #4b4b4b is a repeat
# #646464 is a repeat
# #afafaf is a repeat
# #969696 is a repeat
# #7d7d7d is a repeat
# #967d64 is a repeat
# #af967d is a repeat
# #191919 is a repeat
# #323219 is a repeat
# #000000 is a repeat
# #644b32 is a repeat
# #7d7d4b is a repeat
# #969664 is a repeat
# #afaf7d is a repeat
# #af967d is a repeat
# #967d64 is a repeat
# #64644b is a repeat
# #c8afaf is a repeat
# #4b4b4b is a repeat
# #e1c8c8 is a repeat
# #fae1e1 is a repeat
# #323232 is a repeat
# #7d4b32 is a repeat
# #643219 is a repeat
# #96644b is a repeat
# #c89664 is a repeat
# #af7d4b is a repeat
# #e1af7d is a repeat
# #fac896 is a repeat
# #7d7d64 is a repeat
# #96967d is a repeat
# #afaf96 is a repeat
# #4b3219 is a repeat
# #644b32 is a repeat
# #7d6432 is a repeat
# #967d4b is a repeat
# #af9664 is a repeat
# #c8af7d is a repeat
# #000000 is a repeat
# #4b3232 is a repeat
# #321919 is a repeat
# #967d64 is a repeat
# #af967d is a repeat
# #96644b is a repeat
# #644b4b is a repeat
# #7d4b32 is a repeat
# #af7d4b is a repeat
# #c89664 is a repeat

# %%
len(colors)
# Out:
# 400

# %%
random.shuffle(colors)
htmlOutput = '<table style="-webkit-text-stroke: 1.5px #000000; color:#ffffff; font-size:26px; font-family:Impact;"><tr>'
counter = 0
num_columns = 8
for c in colors:
    htmlOutput += f'<td style="background-color:{c}; padding:25px;">{c}</td>'
    if counter >= num_columns - 1:
        htmlOutput += "</tr><tr>"
        counter = 0
    else:
        counter += 1
htmlOutput += "</tr></table>"
display(HTML(htmlOutput))
# Out:
# <table style="-webkit-text-stroke: 1.5px #000000; color:#ffffff; font-size:26px; font-family:Impact;"><tr><td style="background-color:#fae1af; padding:25px;">#fae1af</td><td style="background-color:#641964; padding:25px;">#641964</td><td style="background-color:#4b7de1; padding:25px;">#4b7de1</td><td style="background-color:#c84b32; padding:25px;">#c84b32</td><td style="background-color:#19197d; padding:25px;">#19197d</td><td style="background-color:#faaf32; padding:25px;">#faaf32</td><td style="background-color:#fae196; padding:25px;">#fae196</td><td style="background-color:#960000; padding:25px;">#960000</td></tr><tr><td style="background-color:#af0019; padding:25px;">#af0019</td><td style="background-color:#e1e17d; padding:25px;">#e1e17d</td><td style="background-color:#64af7d; padding:25px;">#64af7d</td><td style="background-color:#af9696; padding:25px;">#af9696</td><td style="background-color:#006464; padding:25px;">#006464</td><td style="background-color:#4b6464; padding:25px;">#4b6464</td><td style="background-color:#e19619; padding:25px;">#e19619</td><td style="background-color:#e1e1af; padding:25px;">#e1e1af</td></tr><tr><td style="background-color:#969696; padding:25px;">#969696</td><td style="background-color:#7d1919; padding:25px;">#7d1919</td><td style="background-color:#4b0000; padding:25px;">#4b0000</td><td style="background-color:#4b7dc8; padding:25px;">#4b7dc8</td><td style="background-color:#af9664; padding:25px;">#af9664</td><td style="background-color:#197d7d; padding:25px;">#197d7d</td><td style="background-color:#e16419; padding:25px;">#e16419</td><td style="background-color:#003232; padding:25px;">#003232</td></tr><tr><td style="background-color:#964b32; padding:25px;">#964b32</td><td style="background-color:#7d0000; padding:25px;">#7d0000</td><td style="background-color:#c86432; padding:25px;">#c86432</td><td style="background-color:#c84b4b; padding:25px;">#c84b4b</td><td style="background-color:#c83232; padding:25px;">#c83232</td><td style="background-color:#fae17d; padding:25px;">#fae17d</td><td style="background-color:#4b7daf; padding:25px;">#4b7daf</td><td style="background-color:#af7d32; padding:25px;">#af7d32</td></tr><tr><td style="background-color:#e1e1e1; padding:25px;">#e1e1e1</td><td style="background-color:#1964af; padding:25px;">#1964af</td><td style="background-color:#fafae1; padding:25px;">#fafae1</td><td style="background-color:#64c896; padding:25px;">#64c896</td><td style="background-color:#e1af4b; padding:25px;">#e1af4b</td><td style="background-color:#af7d7d; padding:25px;">#af7d7d</td><td style="background-color:#fac87d; padding:25px;">#fac87d</td><td style="background-color:#af9619; padding:25px;">#af9619</td></tr><tr><td style="background-color:#644b19; padding:25px;">#644b19</td><td style="background-color:#c8c800; padding:25px;">#c8c800</td><td style="background-color:#c8af96; padding:25px;">#c8af96</td><td style="background-color:#c89632; padding:25px;">#c89632</td><td style="background-color:#6496c8; padding:25px;">#6496c8</td><td style="background-color:#fa004b; padding:25px;">#fa004b</td><td style="background-color:#190019; padding:25px;">#190019</td><td style="background-color:#af6464; padding:25px;">#af6464</td></tr><tr><td style="background-color:#191919; padding:25px;">#191919</td><td style="background-color:#af96c8; padding:25px;">#af96c8</td><td style="background-color:#967d32; padding:25px;">#967d32</td><td style="background-color:#fafa64; padding:25px;">#fafa64</td><td style="background-color:#196496; padding:25px;">#196496</td><td style="background-color:#649664; padding:25px;">#649664</td><td style="background-color:#afaf4b; padding:25px;">#afaf4b</td><td style="background-color:#e1af64; padding:25px;">#e1af64</td></tr><tr><td style="background-color:#7d4b4b; padding:25px;">#7d4b4b</td><td style="background-color:#af4b19; padding:25px;">#af4b19</td><td style="background-color:#e1967d; padding:25px;">#e1967d</td><td style="background-color:#64afaf; padding:25px;">#64 ...

# %%
def color_search(color):
    color = str(color)
    if color[0] != "#":
        color = "#" + color
    Q = {
        "apikey": APIKEY,
        "color": color,
        "size": 10,
        "sort": f"random:{random.randint(0,9999999)}"
    }
    R = requests.get("https://api.harvardartmuseums.org/object", params=Q)
    info  = R.json()['info']
    records = R.json()['records']
    
    for entry in records:
        if "colors" in entry:
            for c in entry['colors']:
                if c['color'] not in colors:
                    colors.append(c['color'])
                    print("new color found")
    
    output = f"<p>Search returned {info['totalrecords']} results. Showing first {info['totalrecordsperquery']}.</p><table>"
    for r in records:
        row = f'<tr><td><a href="{r["url"]}" target="_blank">{r["title"]}</td><td style="width:300px;">'
        for color in r['colors']:
            row += f'<div style="background-color:{color["color"]}; width:{color["percent"] * 100}%; float:left;">&nbsp;</div>'
        row += "</td>"
        try:
            imgUrl = r["images"][0]["iiifbaseuri"].replace("iiif","view")
            row += f'<td><a href="{imgUrl}" target="_blank"><img style="height:100px;" src="{imgUrl}"></img></a></td>'
        except IndexError:
            row += "<td></td>"
        row += "</tr>"
        output += row
    output += "</table>"
    display(HTML(output))
    return 0

# %%
color_search("fae1e1")
# Out:
# new color found
# new color found
# <p>Search returned 1697 results. Showing first 10.</p><table><tr><td><a href="https://www.harvardartmuseums.org/collections/object/296176" target="_blank">Portrait of a Man</td><td style="width:300px;"><div style="background-color:#c8c8af; width:40.346666666667005%; float:left;">&nbsp;</div><div style="background-color:#afaf96; width:20.86%; float:left;">&nbsp;</div><div style="background-color:#e1c8c8; width:18.413333333333%; float:left;">&nbsp;</div><div style="background-color:#7d7d64; width:9.8066666666667%; float:left;">&nbsp;</div><div style="background-color:#96967d; width:9.34%; float:left;">&nbsp;</div><div style="background-color:#fae1e1; width:1.2333333333333%; float:left;">&nbsp;</div></td><td><a href="https://ids.lib.harvard.edu/ids/view/17810849" target="_blank"><img style="height:100px;" src="https://ids.lib.harvard.edu/ids/view/17810849"></img></a></td></tr><tr><td><a href="https://www.harvardartmuseums.org/collections/object/188996" target="_blank">Peasant Couple Feasting</td><td style="width:300px;"><div style="background-color:#e1e1c8; width:38.625%; float:left;">&nbsp;</div><div style="background-color:#e1c8af; width:31.386904761905%; float:left;">&nbsp;</div><div style="background-color:#fae1e1; width:10.238095238095001%; float:left;">&nbsp;</div><div style="background-color:#c8af96; width:6.8869047619048%; float:left;">&nbsp;</div><div style="background-color:#fafafa; width:3.9642857142857%; float:left;">&nbsp;</div><div style="background-color:#af967d; width:3.4761904761905003%; float:left;">&nbsp;</div><div style="background-color:#967d4b; width:2.7142857142857%; float:left;">&nbsp;</div><div style="background-color:#7d6432; width:1.7797619047619%; float:left;">&nbsp;</div><div style="background-color:#644b32; width:0.52380952380952%; float:left;">&nbsp;</div><div style="background-color:#323232; width:0.23214285714286%; float:left;">&nbsp;</div></td><td><a href="https://ids.lib.harvard.edu/ids/view/8376295" target="_blank"><img style="height:100px;" src="https://ids.lib.harvard.edu/ids/view/8376295"></img></a></td></tr><tr><td><a href="https://www.harvardartmuseums.org/collections/object/340011" target="_blank">Bronze Statue of a Genie</td><td style="width:300px;"><div style="background-color:#c8af4b; width:52.784660766962%; float:left;">&nbsp;</div><div style="background-color:#af964b; width:38.34808259587%; float:left;">&nbsp;</div><div style="background-color:#4b4b32; width:4.4483775811209%; float:left;">&nbsp;</div><div style="background-color:#64644b; width:1.8407079646017999%; float:left;">&nbsp;</div><div style="background-color:#323232; width:1.4277286135693001%; float:left;">&nbsp;</div><div style="background-color:#967d4b; width:1.0206489675516%; float:left;">&nbsp;</div><div style="background-color:#fae1e1; width:0.07669616519174%; float:left;">&nbsp;</div><div style="background-color:#e1e1af; width:0.053097345132743%; float:left;">&nbsp;</div></td><td><a href="https://ids.lib.harvard.edu/ids/view/43262356" target="_blank"><img style="height:100px;" src="https://ids.lib.harvard.edu/ids/view/43262356"></img></a></td></tr><tr><td><a href="https://www.harvardartmuseums.org/collections/object/96910" target="_blank">Illustrated Book of Professions with Kyōka (Kyōka Yamato jinbutsu), 1st of 7 Volumes</td><td style="width:300px;"><div style="background-color:#e1e1c8; width:50.115942028986005%; float:left;">&nbsp;</div><div style="background-color:#c8c8af; width:24.330434782609%; float:left;">&nbsp;</div><div style="background-color:#fae1e1; width:7.495652173913%; float:left;">&nbsp;</div><div style="background-color:#af967d; width:7.1014492753623%; float:left;">&nbsp;</div><div style="background-color:#000000; width:5.2289855072464%; float:left;">&nbsp;</div><div style="background-color:#7d6464; width:3.0956521739130003%; float:left;">&nbsp;</div><div style="background-color:#4b3232; width:0.9623188405797101%; float:left;">&nbsp;</div><div style="background-color:#64644b; width:0.87536231884058%; f ...
# 0

# %%
import csv

# %%
with open("colors.csv", 'w') as fp:
    writer = csv.writer(fp)
    for c in colors:
        writer.writerow([c])

# %%
newColors = []
with open("colors.csv", "r") as fp:
    reader = csv.reader(fp)
    for row in reader:
        newColors.append(row[0])

# %%
len(newColors)
# Out:
# 413
